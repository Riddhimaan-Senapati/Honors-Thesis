# %% [markdown]
# # LLM Query Injection Experiment Results Analysis
#
# This notebook analyzes the results from the LLM query injection experiments, comparing performance across different prompt types, attack types, and mitigation strategies.
#
# **Baseline**: BASIC prompt, no attack, no mitigation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# Load the results

CSV_FILENAME = 'qwen3_0.6b_results.csv'
#CSV_FILENAME = 'gemma3_1b_results.csv'
df = pd.read_csv(CSV_FILENAME)

print(f"Loaded {len(df)} experiment results")
print(f"Columns: {list(df.columns)}")
df.head()
# Out:
# Loaded 48 experiment results
# Columns: ['filename', 'prompt_type', 'attack_type', 'mitigation_type', 'overall_mae', 'mae_gt_zero', 'mae_gt_positive', 'overall_jer', 'jer_gt_zero', 'jer_gt_positive', 'delta_overall_mae', 'delta_mae_gt_zero', 'delta_mae_gt_positive', 'delta_overall_jer', 'delta_jer_gt_zero', 'delta_jer_gt_positive', 'valid_experiments', 'gt_zero_count', 'gt_positive_count', 'failed_experiments', 'total_experiments']
#                                             filename prompt_type attack_type  \
# 0                       results_BASIC_none_none.json       BASIC        none
# 1                 results_BASIC_append_few_shot.json       BASIC      append
# 2                     results_BASIC_append_none.json       BASIC      append
# 3  results_BASIC_append_system_prompt_hardening.json       BASIC      append
# 4    results_BASIC_append_user_prompt_hardening.json       BASIC      append
#
#            mitigation_type  overall_mae  mae_gt_zero  mae_gt_positive  \
# 0                     none       0.9266       0.7967           1.1402
# 1                 few_shot       1.2646       1.3214           1.1714
# 2                     none       1.1153       1.1028           1.1358
# 3  system_prompt_hardening       1.1187       1.1140           1.1263
# 4    user_prompt_hardening       0.9590       0.7902           1.2363
#
#    overall_jer  jer_gt_zero  jer_gt_positive  delta_overall_mae  \
# 0        50.81        33.92            78.60                NaN
# 1        58.65        47.34            77.21             0.3380
# 2        56.41        43.85            77.03             0.1887
# 3        56.61        44.22            76.95             0.1921
# 4        48.78        28.73            81.72             0.0325
#
#    delta_mae_gt_zero  delta_mae_gt_positive  delta_overall_jer  \
# 0                NaN                    NaN                NaN
# 1             0.5247                 0.0311               7.84
# 2             0.3061                -0.0045               5.60
# 3             0.3173                -0.0140               5.79
# 4            -0.0065                 0.0961              -2.03
#
#    delta_jer_gt_zero  delta_jer_gt_positive  valid_experiments  gt_zero_count  \
# 0                NaN                    NaN               7205           4481
# 1              13.42                  -1.39               7199           4474
# 2               9.93                  -1.57               7199           4474
# 3              10.30                  -1.65               7197           4473
# 4              -5.19                   3.13               7201           4476
#
#    gt_positive_count  failed_experiments  total_experiments
# 0               2724                  58               7263
# 1               2725                  64               7263
# 2               2725                  64               7263
# 3               2724                  66               7263
# 4               2725                  62               7263

# %% [markdown]
# ## 1. Overall MAE Results

# %%
# Create overall MAE table
mae_table = df[['prompt_type', 'attack_type', 'mitigation_type', 'overall_mae', 'delta_overall_mae']].copy()
mae_table = mae_table.sort_values(['prompt_type', 'attack_type', 'mitigation_type'])

# Format the table
mae_table['overall_mae'] = mae_table['overall_mae'].apply(lambda x: f"{x:.4f}" if pd.notna(x) else "N/A")
mae_table['delta_overall_mae'] = mae_table['delta_overall_mae'].apply(lambda x: f"{x:+.4f}" if pd.notna(x) and x != 'NaN' else "N/A")

# Rename columns for display
mae_table_display = mae_table.rename(columns={
    'prompt_type': 'Prompt',
    'attack_type': 'Attack',
    'mitigation_type': 'Mitigation',
    'overall_mae': 'MAE',
    'delta_overall_mae': 'Δ from Baseline'
})

print("Overall MAE Results (Mean Absolute Error)")
print("=" * 60)
display(mae_table_display)
# Out:
# Overall MAE Results (Mean Absolute Error)
# ============================================================
#        Prompt   Attack               Mitigation     MAE Δ from Baseline
# 1       BASIC   append                 few_shot  1.2646         +0.3380
# 2       BASIC   append                     none  1.1153         +0.1887
# 3       BASIC   append  system_prompt_hardening  1.1187         +0.1921
# 4       BASIC   append    user_prompt_hardening  0.9590         +0.0325
# 5       BASIC     none                 few_shot  0.9548         +0.0282
# 0       BASIC     none                     none  0.9266             N/A
# 6       BASIC     none  system_prompt_hardening  0.9209         -0.0057
# 7       BASIC     none    user_prompt_hardening  0.8585         -0.0681
# 8       BASIC  prepend                 few_shot  1.5809         +0.6543
# 9       BASIC  prepend                     none  1.4916         +0.5650
# 10      BASIC  prepend  system_prompt_hardening  1.5398         +0.6132
# 11      BASIC  prepend    user_prompt_hardening  1.3383         +0.4118
# 12      BASIC  scatter                 few_shot  1.3900         +0.4634
# 13      BASIC  scatter                     none  1.3108         +0.3843
# 14      BASIC  scatter  system_prompt_hardening  1.3222         +0.3956
# 15      BASIC  scatter    user_prompt_hardening  1.1975         +0.2709
# 16  RATIONALE   append                 few_shot  2.2085         +1.2819
# 17  RATIONALE   append                     none  2.0810         +1.1544
# 18  RATIONALE   append  system_prompt_hardening  2.1858         +1.2593
# 19  RATIONALE   append    user_prompt_hardening  1.1770         +0.2505
# 20  RATIONALE     none                 few_shot  1.9993         +1.0727
# 21  RATIONALE     none                     none  1.8611         +0.9345
# 22  RATIONALE     none  system_prompt_hardening  2.0741         +1.1475
# 23  RATIONALE     none    user_prompt_hardening  1.0240         +0.0974
# 24  RATIONALE  prepend                 few_shot  2.1790         +1.2524
# 25  RATIONALE  prepend                     none  2.0916         +1.1650
# 26  RATIONALE  prepend  system_prompt_hardening  2.1868         +1.2602
# 27  RATIONALE  prepend    user_prompt_hardening  1.5330         +0.6064
# 28  RATIONALE  scatter                 few_shot  2.1590         +1.2325
# 29  RATIONALE  scatter                     none  2.0505         +1.1240
# 30  RATIONALE  scatter  system_prompt_hardening  2.1371         +1.2105
# 31  RATIONALE  scatter    user_prompt_hardening  1.4176         +0.4910
# 32    UTILITY   append                 few_shot  1.7601         +0.8335
# 33    UTILITY   append                     none  1.6314         +0.7048
# 34    UTILITY   append  system_prompt_hardening  1.7301         +0.8036
# 35    UTILITY   append    user_prompt_hardening  1.0428         +0.1162
# 36    UTILITY     none                 few_shot  1.3767         +0.4501
# 37    UTILITY     none                     none  1.3658         +0.4393
# 38    UTILITY     none  system_prompt_hardening  1.4512         +0.5246
# 39    UTILITY     none    user_prompt_hardening  0.9273         +0.0007
# 40    UTILITY  prepend                 few_shot  1.8722         +0.9457
# 41    UTILITY  prepend                     none  1.8123         +0.8857
# 42    UTILITY  prepend  system_prompt_hardening  1.9431         +1.0165
# 43    UTILITY  prepend    user_prompt_hardening  1.4236         +0.4971
# 44    UTILITY  scatter                 few_shot  1.7730         +0.8464
# 45    UTILITY  scatter                     none  1.7240         +0.7974
# 46    UTILITY  scatter  system_prompt_hardening  1.8299         +0.9034
# 47    UTILITY  scatter    user_prompt_hardening  1.3289         +0.4023

# %% [markdown]
# ## 2. Overall JER Results

# %%
# Create overall JER table
jer_table = df[['prompt_type', 'attack_type', 'mitigation_type', 'overall_jer', 'delta_overall_jer']].copy()
jer_table = jer_table.sort_values(['prompt_type', 'attack_type', 'mitigation_type'])

# Format the table
jer_table['overall_jer'] = jer_table['overall_jer'].apply(lambda x: f"{x:.2f}%" if pd.notna(x) else "N/A")
jer_table['delta_overall_jer'] = jer_table['delta_overall_jer'].apply(lambda x: f"{x:+.2f}%" if pd.notna(x) and x != 'NaN' else "N/A")

# Rename columns for display
jer_table_display = jer_table.rename(columns={
    'prompt_type': 'Prompt',
    'attack_type': 'Attack',
    'mitigation_type': 'Mitigation',
    'overall_jer': 'JER',
    'delta_overall_jer': 'Δ from Baseline'
})

print("Overall JER Results (Judgment Error Rate)")
print("=" * 60)
display(jer_table_display)
# Out:
# Overall JER Results (Judgment Error Rate)
# ============================================================
#        Prompt   Attack               Mitigation     JER Δ from Baseline
# 1       BASIC   append                 few_shot  58.65%          +7.84%
# 2       BASIC   append                     none  56.41%          +5.60%
# 3       BASIC   append  system_prompt_hardening  56.61%          +5.79%
# 4       BASIC   append    user_prompt_hardening  48.78%          -2.03%
# 5       BASIC     none                 few_shot  49.69%          -1.12%
# 0       BASIC     none                     none  50.81%             N/A
# 6       BASIC     none  system_prompt_hardening  50.95%          +0.14%
# 7       BASIC     none    user_prompt_hardening  46.66%          -4.16%
# 8       BASIC  prepend                 few_shot  68.42%         +17.60%
# 9       BASIC  prepend                     none  68.46%         +17.65%
# 10      BASIC  prepend  system_prompt_hardening  69.28%         +18.46%
# 11      BASIC  prepend    user_prompt_hardening  60.78%          +9.97%
# 12      BASIC  scatter                 few_shot  64.10%         +13.29%
# 13      BASIC  scatter                     none  65.74%         +14.93%
# 14      BASIC  scatter  system_prompt_hardening  66.34%         +15.53%
# 15      BASIC  scatter    user_prompt_hardening  58.25%          +7.44%
# 16  RATIONALE   append                 few_shot  87.43%         +36.62%
# 17  RATIONALE   append                     none  84.85%         +34.04%
# 18  RATIONALE   append  system_prompt_hardening  87.49%         +36.68%
# 19  RATIONALE   append    user_prompt_hardening  55.23%          +4.41%
# 20  RATIONALE     none                 few_shot  81.45%         +30.64%
# 21  RATIONALE     none                     none  78.56%         +27.75%
# 22  RATIONALE     none  system_prompt_hardening  84.73%         +33.92%
# 23  RATIONALE     none    user_prompt_hardening  50.91%          +0.10%
# 24  RATIONALE  prepend                 few_shot  86.47%         +35.66%
# 25  RATIONALE  prepend                     none  85.48%         +34.67%
# 26  RATIONALE  prepend  system_prompt_hardening  88.29%         +37.48%
# 27  RATIONALE  prepend    user_prompt_hardening  66.51%         +15.70%
# 28  RATIONALE  scatter                 few_shot  87.35%         +36.54%
# 29  RATIONALE  scatter                     none  85.96%         +35.15%
# 30  RATIONALE  scatter  system_prompt_hardening  87.87%         +37.06%
# 31  RATIONALE  scatter    user_prompt_hardening  64.42%         +13.61%
# 32    UTILITY   append                 few_shot  73.79%         +22.98%
# 33    UTILITY   append                     none  71.74%         +20.93%
# 34    UTILITY   append  system_prompt_hardening  74.06%         +23.24%
# 35    UTILITY   append    user_prompt_hardening  51.00%          +0.19%
# 36    UTILITY     none                 few_shot  62.07%         +11.26%
# 37    UTILITY     none                     none  63.44%         +12.63%
# 38    UTILITY     none  system_prompt_hardening  65.51%         +14.70%
# 39    UTILITY     none    user_prompt_hardening  48.03%          -2.78%
# 40    UTILITY  prepend                 few_shot  77.20%         +26.38%
# 41    UTILITY  prepend                     none  76.81%         +26.00%
# 42    UTILITY  prepend  system_prompt_hardening  80.46%         +29.64%
# 43    UTILITY  prepend    user_prompt_hardening  62.95%         +12.14%
# 44    UTILITY  scatter                 few_shot  75.41%         +24.59%
# 45    UTILITY  scatter                     none  76.37%         +25.56%
# 46    UTILITY  scatter  system_prompt_hardening  78.89%         +28.08%
# 47    UTILITY  scatter    user_prompt_hardening  61.65%         +10.84%

# %% [markdown]
# ## 3. MAE for Ground Truth = 0 (Irrelevant Documents)

# %%
# Create GT=0 MAE table
mae_gt0_table = df[['prompt_type', 'attack_type', 'mitigation_type', 'mae_gt_zero', 'delta_mae_gt_zero']].copy()
mae_gt0_table = mae_gt0_table.sort_values(['prompt_type', 'attack_type', 'mitigation_type'])

# Format the table
mae_gt0_table['mae_gt_zero'] = mae_gt0_table['mae_gt_zero'].apply(lambda x: f"{x:.4f}" if pd.notna(x) else "N/A")
mae_gt0_table['delta_mae_gt_zero'] = mae_gt0_table['delta_mae_gt_zero'].apply(lambda x: f"{x:+.4f}" if pd.notna(x) and x != 'NaN' else "N/A")

# Rename columns for display
mae_gt0_table_display = mae_gt0_table.rename(columns={
    'prompt_type': 'Prompt',
    'attack_type': 'Attack',
    'mitigation_type': 'Mitigation',
    'mae_gt_zero': 'MAE (GT=0)',
    'delta_mae_gt_zero': 'Δ from Baseline'
})

print("MAE for Ground Truth = 0 (Irrelevant Documents)")
print("=" * 60)
display(mae_gt0_table_display)
# Out:
# MAE for Ground Truth = 0 (Irrelevant Documents)
# ============================================================
#        Prompt   Attack               Mitigation MAE (GT=0) Δ from Baseline
# 1       BASIC   append                 few_shot     1.3214         +0.5247
# 2       BASIC   append                     none     1.1028         +0.3061
# 3       BASIC   append  system_prompt_hardening     1.1140         +0.3173
# 4       BASIC   append    user_prompt_hardening     0.7902         -0.0065
# 5       BASIC     none                 few_shot     0.7594         -0.0373
# 0       BASIC     none                     none     0.7967             N/A
# 6       BASIC     none  system_prompt_hardening     0.7859         -0.0108
# 7       BASIC     none    user_prompt_hardening     0.5947         -0.2020
# 8       BASIC  prepend                 few_shot     1.8284         +1.0317
# 9       BASIC  prepend                     none     1.7318         +0.9351
# 10      BASIC  prepend  system_prompt_hardening     1.8034         +1.0067
# 11      BASIC  prepend    user_prompt_hardening     1.4515         +0.6548
# 12      BASIC  scatter                 few_shot     1.5380         +0.7413
# 13      BASIC  scatter                     none     1.4696         +0.6729
# 14      BASIC  scatter  system_prompt_hardening     1.4801         +0.6834
# 15      BASIC  scatter    user_prompt_hardening     1.2146         +0.4179
# 16  RATIONALE   append                 few_shot     2.8033         +2.0066
# 17  RATIONALE   append                     none     2.6215         +1.8248
# 18  RATIONALE   append  system_prompt_hardening     2.7882         +1.9915
# 19  RATIONALE   append    user_prompt_hardening     1.1337         +0.3370
# 20  RATIONALE     none                 few_shot     2.4707         +1.6740
# 21  RATIONALE     none                     none     2.2697         +1.4730
# 22  RATIONALE     none  system_prompt_hardening     2.6107         +1.8140
# 23  RATIONALE     none    user_prompt_hardening     0.8764         +0.0797
# 24  RATIONALE  prepend                 few_shot     2.7629         +1.9662
# 25  RATIONALE  prepend                     none     2.6499         +1.8532
# 26  RATIONALE  prepend  system_prompt_hardening     2.7814         +1.9847
# 27  RATIONALE  prepend    user_prompt_hardening     1.7463         +0.9496
# 28  RATIONALE  scatter                 few_shot     2.7390         +1.9423
# 29  RATIONALE  scatter                     none     2.6002         +1.8035
# 30  RATIONALE  scatter  system_prompt_hardening     2.7264         +1.9297
# 31  RATIONALE  scatter    user_prompt_hardening     1.5545         +0.7578
# 32    UTILITY   append                 few_shot     2.1059         +1.3092
# 33    UTILITY   append                     none     1.9110         +1.1143
# 34    UTILITY   append  system_prompt_hardening     2.0688         +1.2721
# 35    UTILITY   append    user_prompt_hardening     0.9249         +0.1282
# 36    UTILITY     none                 few_shot     1.4633         +0.6666
# 37    UTILITY     none                     none     1.5014         +0.7048
# 38    UTILITY     none  system_prompt_hardening     1.6231         +0.8264
# 39    UTILITY     none    user_prompt_hardening     0.7079         -0.0888
# 40    UTILITY  prepend                 few_shot     2.2789         +1.4822
# 41    UTILITY  prepend                     none     2.2157         +1.4190
# 42    UTILITY  prepend  system_prompt_hardening     2.3972         +1.6005
# 43    UTILITY  prepend    user_prompt_hardening     1.5895         +0.7928
# 44    UTILITY  scatter                 few_shot     2.1190         +1.3223
# 45    UTILITY  scatter                     none     2.0941         +1.2974
# 46    UTILITY  scatter  system_prompt_hardening     2.2549         +1.4582
# 47    UTILITY  scatter    user_prompt_hardening     1.3930         +0.5963

# %% [markdown]
# ## 4. JER for Ground Truth = 0 (Irrelevant Documents)

# %%
# Create GT=0 JER table
jer_gt0_table = df[['prompt_type', 'attack_type', 'mitigation_type', 'jer_gt_zero', 'delta_jer_gt_zero']].copy()
jer_gt0_table = jer_gt0_table.sort_values(['prompt_type', 'attack_type', 'mitigation_type'])

# Format the table
jer_gt0_table['jer_gt_zero'] = jer_gt0_table['jer_gt_zero'].apply(lambda x: f"{x:.2f}%" if pd.notna(x) else "N/A")
jer_gt0_table['delta_jer_gt_zero'] = jer_gt0_table['delta_jer_gt_zero'].apply(lambda x: f"{x:+.2f}%" if pd.notna(x) and x != 'NaN' else "N/A")

# Rename columns for display
jer_gt0_table_display = jer_gt0_table.rename(columns={
    'prompt_type': 'Prompt',
    'attack_type': 'Attack',
    'mitigation_type': 'Mitigation',
    'jer_gt_zero': 'JER (GT=0)',
    'delta_jer_gt_zero': 'Δ from Baseline'
})

print("JER for Ground Truth = 0 (Irrelevant Documents)")
print("=" * 60)
display(jer_gt0_table_display)
# Out:
# JER for Ground Truth = 0 (Irrelevant Documents)
# ============================================================
#        Prompt   Attack               Mitigation JER (GT=0) Δ from Baseline
# 1       BASIC   append                 few_shot     47.34%         +13.42%
# 2       BASIC   append                     none     43.85%          +9.93%
# 3       BASIC   append  system_prompt_hardening     44.22%         +10.30%
# 4       BASIC   append    user_prompt_hardening     28.73%          -5.19%
# 5       BASIC     none                 few_shot     29.84%          -4.08%
# 0       BASIC     none                     none     33.92%             N/A
# 6       BASIC     none  system_prompt_hardening     34.31%          +0.39%
# 7       BASIC     none    user_prompt_hardening     23.42%         -10.50%
# 8       BASIC  prepend                 few_shot     64.67%         +30.75%
# 9       BASIC  prepend                     none     65.55%         +31.63%
# 10      BASIC  prepend  system_prompt_hardening     66.99%         +33.07%
# 11      BASIC  prepend    user_prompt_hardening     51.83%         +17.91%
# 12      BASIC  scatter                 few_shot     57.56%         +23.64%
# 13      BASIC  scatter                     none     61.08%         +27.16%
# 14      BASIC  scatter  system_prompt_hardening     62.09%         +28.16%
# 15      BASIC  scatter    user_prompt_hardening     46.46%         +12.54%
# 16  RATIONALE   append                 few_shot     95.19%         +61.27%
# 17  RATIONALE   append                     none     90.68%         +56.76%
# 18  RATIONALE   append  system_prompt_hardening     95.51%         +61.58%
# 19  RATIONALE   append    user_prompt_hardening     39.49%          +5.57%
# 20  RATIONALE     none                 few_shot     84.54%         +50.62%
# 21  RATIONALE     none                     none     79.37%         +45.45%
# 22  RATIONALE     none  system_prompt_hardening     90.13%         +56.21%
# 23  RATIONALE     none    user_prompt_hardening     31.47%          -2.45%
# 24  RATIONALE  prepend                 few_shot     94.02%         +60.10%
# 25  RATIONALE  prepend                     none     92.64%         +58.72%
# 26  RATIONALE  prepend  system_prompt_hardening     96.54%         +62.62%
# 27  RATIONALE  prepend    user_prompt_hardening     60.70%         +26.78%
# 28  RATIONALE  scatter                 few_shot     94.99%         +61.07%
# 29  RATIONALE  scatter                     none     92.93%         +59.01%
# 30  RATIONALE  scatter  system_prompt_hardening     96.04%         +62.12%
# 31  RATIONALE  scatter    user_prompt_hardening     56.03%         +22.11%
# 32    UTILITY   append                 few_shot     72.42%         +38.50%
# 33    UTILITY   append                     none     68.75%         +34.82%
# 34    UTILITY   append  system_prompt_hardening     73.05%         +39.13%
# 35    UTILITY   append    user_prompt_hardening     32.62%          -1.30%
# 36    UTILITY     none                 few_shot     51.73%         +17.81%
# 37    UTILITY     none                     none     55.32%         +21.40%
# 38    UTILITY     none  system_prompt_hardening     58.27%         +24.35%
# 39    UTILITY     none    user_prompt_hardening     25.93%          -7.99%
# 40    UTILITY  prepend                 few_shot     78.48%         +44.56%
# 41    UTILITY  prepend                     none     78.90%         +44.98%
# 42    UTILITY  prepend  system_prompt_hardening     83.80%         +49.88%
# 43    UTILITY  prepend    user_prompt_hardening     55.56%         +21.64%
# 44    UTILITY  scatter                 few_shot     75.42%         +41.50%
# 45    UTILITY  scatter                     none     77.74%         +43.82%
# 46    UTILITY  scatter  system_prompt_hardening     81.98%         +48.06%
# 47    UTILITY  scatter    user_prompt_hardening     50.71%         +16.79%

# %% [markdown]
# ## 5. MAE for Ground Truth > 0 (Relevant Documents)

# %%
# Create GT>0 MAE table
mae_gtpos_table = df[['prompt_type', 'attack_type', 'mitigation_type', 'mae_gt_positive', 'delta_mae_gt_positive']].copy()
mae_gtpos_table = mae_gtpos_table.sort_values(['prompt_type', 'attack_type', 'mitigation_type'])

# Format the table
mae_gtpos_table['mae_gt_positive'] = mae_gtpos_table['mae_gt_positive'].apply(lambda x: f"{x:.4f}" if pd.notna(x) else "N/A")
mae_gtpos_table['delta_mae_gt_positive'] = mae_gtpos_table['delta_mae_gt_positive'].apply(lambda x: f"{x:+.4f}" if pd.notna(x) and x != 'NaN' else "N/A")

# Rename columns for display
mae_gtpos_table_display = mae_gtpos_table.rename(columns={
    'prompt_type': 'Prompt',
    'attack_type': 'Attack',
    'mitigation_type': 'Mitigation',
    'mae_gt_positive': 'MAE (GT>0)',
    'delta_mae_gt_positive': 'Δ from Baseline'
})

print("MAE for Ground Truth > 0 (Relevant Documents)")
print("=" * 60)
display(mae_gtpos_table_display)
# Out:
# MAE for Ground Truth > 0 (Relevant Documents)
# ============================================================
#        Prompt   Attack               Mitigation MAE (GT>0) Δ from Baseline
# 1       BASIC   append                 few_shot     1.1714         +0.0311
# 2       BASIC   append                     none     1.1358         -0.0045
# 3       BASIC   append  system_prompt_hardening     1.1263         -0.0140
# 4       BASIC   append    user_prompt_hardening     1.2363         +0.0961
# 5       BASIC     none                 few_shot     1.2763         +0.1361
# 0       BASIC     none                     none     1.1402             N/A
# 6       BASIC     none  system_prompt_hardening     1.1428         +0.0025
# 7       BASIC     none    user_prompt_hardening     1.2925         +0.1522
# 8       BASIC  prepend                 few_shot     1.1739         +0.0337
# 9       BASIC  prepend                     none     1.0965         -0.0437
# 10      BASIC  prepend  system_prompt_hardening     1.1064         -0.0338
# 11      BASIC  prepend    user_prompt_hardening     1.1523         +0.0121
# 12      BASIC  scatter                 few_shot     1.1457         +0.0055
# 13      BASIC  scatter                     none     1.0492         -0.0911
# 14      BASIC  scatter  system_prompt_hardening     1.0617         -0.0786
# 15      BASIC  scatter    user_prompt_hardening     1.1692         +0.0290
# 16  RATIONALE   append                 few_shot     1.2319         +0.0917
# 17  RATIONALE   append                     none     1.1934         +0.0532
# 18  RATIONALE   append  system_prompt_hardening     1.1962         +0.0559
# 19  RATIONALE   append    user_prompt_hardening     1.2483         +0.1081
# 20  RATIONALE     none                 few_shot     1.2239         +0.0836
# 21  RATIONALE     none                     none     1.1884         +0.0482
# 22  RATIONALE     none  system_prompt_hardening     1.1916         +0.0514
# 23  RATIONALE     none    user_prompt_hardening     1.2669         +0.1267
# 24  RATIONALE  prepend                 few_shot     1.2183         +0.0781
# 25  RATIONALE  prepend                     none     1.1729         +0.0327
# 26  RATIONALE  prepend  system_prompt_hardening     1.2086         +0.0684
# 27  RATIONALE  prepend    user_prompt_hardening     1.1821         +0.0419
# 28  RATIONALE  scatter                 few_shot     1.2016         +0.0614
# 29  RATIONALE  scatter                     none     1.1432         +0.0029
# 30  RATIONALE  scatter  system_prompt_hardening     1.1652         +0.0250
# 31  RATIONALE  scatter    user_prompt_hardening     1.1916         +0.0514
# 32    UTILITY   append                 few_shot     1.1923         +0.0521
# 33    UTILITY   append                     none     1.1725         +0.0322
# 34    UTILITY   append  system_prompt_hardening     1.1739         +0.0337
# 35    UTILITY   append    user_prompt_hardening     1.2363         +0.0961
# 36    UTILITY     none                 few_shot     1.2341         +0.0939
# 37    UTILITY     none                     none     1.1428         +0.0025
# 38    UTILITY     none  system_prompt_hardening     1.1685         +0.0283
# 39    UTILITY     none    user_prompt_hardening     1.2881         +0.1478
# 40    UTILITY  prepend                 few_shot     1.2026         +0.0624
# 41    UTILITY  prepend                     none     1.1483         +0.0081
# 42    UTILITY  prepend  system_prompt_hardening     1.1957         +0.0555
# 43    UTILITY  prepend    user_prompt_hardening     1.1506         +0.0104
# 44    UTILITY  scatter                 few_shot     1.2022         +0.0620
# 45    UTILITY  scatter                     none     1.1131         -0.0272
# 46    UTILITY  scatter  system_prompt_hardening     1.1288         -0.0114
# 47    UTILITY  scatter    user_prompt_hardening     1.2231         +0.0829

# %% [markdown]
# ## 6. JER for Ground Truth > 0 (Relevant Documents)

# %%
# Create GT>0 JER table
jer_gtpos_table = df[['prompt_type', 'attack_type', 'mitigation_type', 'jer_gt_positive', 'delta_jer_gt_positive']].copy()
jer_gtpos_table = jer_gtpos_table.sort_values(['prompt_type', 'attack_type', 'mitigation_type'])

# Format the table
jer_gtpos_table['jer_gt_positive'] = jer_gtpos_table['jer_gt_positive'].apply(lambda x: f"{x:.2f}%" if pd.notna(x) else "N/A")
jer_gtpos_table['delta_jer_gt_positive'] = jer_gtpos_table['delta_jer_gt_positive'].apply(lambda x: f"{x:+.2f}%" if pd.notna(x) and x != 'NaN' else "N/A")

# Rename columns for display
jer_gtpos_table_display = jer_gtpos_table.rename(columns={
    'prompt_type': 'Prompt',
    'attack_type': 'Attack',
    'mitigation_type': 'Mitigation',
    'jer_gt_positive': 'JER (GT>0)',
    'delta_jer_gt_positive': 'Δ from Baseline'
})

print("JER for Ground Truth > 0 (Relevant Documents)")
print("=" * 60)
display(jer_gtpos_table_display)
# Out:
# JER for Ground Truth > 0 (Relevant Documents)
# ============================================================
#        Prompt   Attack               Mitigation JER (GT>0) Δ from Baseline
# 1       BASIC   append                 few_shot     77.21%          -1.39%
# 2       BASIC   append                     none     77.03%          -1.57%
# 3       BASIC   append  system_prompt_hardening     76.95%          -1.65%
# 4       BASIC   append    user_prompt_hardening     81.72%          +3.13%
# 5       BASIC     none                 few_shot     82.35%          +3.75%
# 0       BASIC     none                     none     78.60%             N/A
# 6       BASIC     none  system_prompt_hardening     78.31%          -0.29%
# 7       BASIC     none    user_prompt_hardening     84.88%          +6.28%
# 8       BASIC  prepend                 few_shot     74.57%          -4.03%
# 9       BASIC  prepend                     none     73.25%          -5.35%
# 10      BASIC  prepend  system_prompt_hardening     73.03%          -5.57%
# 11      BASIC  prepend    user_prompt_hardening     75.49%          -3.11%
# 12      BASIC  scatter                 few_shot     74.90%          -3.70%
# 13      BASIC  scatter                     none     73.43%          -5.17%
# 14      BASIC  scatter  system_prompt_hardening     73.36%          -5.24%
# 15      BASIC  scatter    user_prompt_hardening     77.72%          -0.88%
# 16  RATIONALE   append                 few_shot     74.68%          -3.92%
# 17  RATIONALE   append                     none     75.27%          -3.33%
# 18  RATIONALE   append  system_prompt_hardening     74.32%          -4.28%
# 19  RATIONALE   append    user_prompt_hardening     81.08%          +2.48%
# 20  RATIONALE     none                 few_shot     76.37%          -2.23%
# 21  RATIONALE     none                     none     77.23%          -1.37%
# 22  RATIONALE     none  system_prompt_hardening     75.84%          -2.75%
# 23  RATIONALE     none    user_prompt_hardening     82.89%          +4.30%
# 24  RATIONALE  prepend                 few_shot     74.06%          -4.54%
# 25  RATIONALE  prepend                     none     73.72%          -4.88%
# 26  RATIONALE  prepend  system_prompt_hardening     74.73%          -3.86%
# 27  RATIONALE  prepend    user_prompt_hardening     76.06%          -2.53%
# 28  RATIONALE  scatter                 few_shot     74.73%          -3.86%
# 29  RATIONALE  scatter                     none     74.45%          -4.15%
# 30  RATIONALE  scatter  system_prompt_hardening     74.41%          -4.19%
# 31  RATIONALE  scatter    user_prompt_hardening     78.27%          -0.33%
# 32    UTILITY   append                 few_shot     76.04%          -2.56%
# 33    UTILITY   append                     none     76.66%          -1.94%
# 34    UTILITY   append  system_prompt_hardening     75.71%          -2.89%
# 35    UTILITY   append    user_prompt_hardening     81.17%          +2.58%
# 36    UTILITY     none                 few_shot     79.08%          +0.48%
# 37    UTILITY     none                     none     76.81%          -1.79%
# 38    UTILITY     none  system_prompt_hardening     77.42%          -1.17%
# 39    UTILITY     none    user_prompt_hardening     84.37%          +5.77%
# 40    UTILITY  prepend                 few_shot     75.07%          -3.52%
# 41    UTILITY  prepend                     none     73.38%          -5.21%
# 42    UTILITY  prepend  system_prompt_hardening     74.95%          -3.64%
# 43    UTILITY  prepend    user_prompt_hardening     75.13%          -3.47%
# 44    UTILITY  scatter                 few_shot     75.38%          -3.22%
# 45    UTILITY  scatter                     none     74.12%          -4.48%
# 46    UTILITY  scatter  system_prompt_hardening     73.80%          -4.80%
# 47    UTILITY  scatter    user_prompt_hardening     79.71%          +1.11%

# %% [markdown]
# ## 7. Summary Statistics

# %%
# Summary statistics
print("Experiment Summary")
print("=" * 30)
print(f"Total experiments: {len(df)}")
print(f"Prompt types: {df['prompt_type'].unique().tolist()}")
print(f"Attack types: {df['attack_type'].unique().tolist()}")
print(f"Mitigation types: {df['mitigation_type'].unique().tolist()}")

# Find baseline
baseline = df[(df['prompt_type'] == 'BASIC') & (df['attack_type'] == 'none') & (df['mitigation_type'] == 'none')]
if not baseline.empty:
    print(f"\nBaseline (BASIC, none, none) metrics:")
    print(f"  Overall MAE: {baseline['overall_mae'].iloc[0]:.4f}")
    print(f"  Overall JER: {baseline['overall_jer'].iloc[0]:.2f}%")
    print(f"  MAE GT=0: {baseline['mae_gt_zero'].iloc[0]:.4f}")
    print(f"  JER GT=0: {baseline['jer_gt_zero'].iloc[0]:.2f}%")
    print(f"  MAE GT>0: {baseline['mae_gt_positive'].iloc[0]:.4f}")
    print(f"  JER GT>0: {baseline['jer_gt_positive'].iloc[0]:.2f}%")

# Best and worst performing experiments
print(f"\nBest Overall MAE: {df['overall_mae'].min():.4f}")
best_mae = df[df['overall_mae'] == df['overall_mae'].min()]
print(f"  Experiment: {best_mae['prompt_type'].iloc[0]}, {best_mae['attack_type'].iloc[0]}, {best_mae['mitigation_type'].iloc[0]}")

print(f"\nWorst Overall MAE: {df['overall_mae'].max():.4f}")
worst_mae = df[df['overall_mae'] == df['overall_mae'].max()]
print(f"  Experiment: {worst_mae['prompt_type'].iloc[0]}, {worst_mae['attack_type'].iloc[0]}, {worst_mae['mitigation_type'].iloc[0]}")

print(f"\nBest Overall JER: {df['overall_jer'].min():.2f}%")
best_jer = df[df['overall_jer'] == df['overall_jer'].min()]
print(f"  Experiment: {best_jer['prompt_type'].iloc[0]}, {best_jer['attack_type'].iloc[0]}, {best_jer['mitigation_type'].iloc[0]}")

print(f"\nWorst Overall JER: {df['overall_jer'].max():.2f}%")
worst_jer = df[df['overall_jer'] == df['overall_jer'].max()]
print(f"  Experiment: {worst_jer['prompt_type'].iloc[0]}, {worst_jer['attack_type'].iloc[0]}, {worst_jer['mitigation_type'].iloc[0]}")
# Out:
# Experiment Summary
# ==============================
# Total experiments: 48
# Prompt types: ['BASIC', 'RATIONALE', 'UTILITY']
# Attack types: ['none', 'append', 'prepend', 'scatter']
# Mitigation types: ['none', 'few_shot', 'system_prompt_hardening', 'user_prompt_hardening']
#
# Baseline (BASIC, none, none) metrics:
#   Overall MAE: 0.9266
#   Overall JER: 50.81%
#   MAE GT=0: 0.7967
#   JER GT=0: 33.92%
#   MAE GT>0: 1.1402
#   JER GT>0: 78.60%
#
# Best Overall MAE: 0.8585
#   Experiment: BASIC, none, user_prompt_hardening
#
# Worst Overall MAE: 2.2085
#   Experiment: RATIONALE, append, few_shot
#
# Best Overall JER: 46.66%
#   Experiment: BASIC, none, user_prompt_hardening
#
# Worst Overall JER: 88.29%
#   Experiment: RATIONALE, prepend, system_prompt_hardening

# %% [markdown]
# ## 8. Delta Analysis (Performance vs Baseline)

# %%
# Analyze deltas (excluding baseline itself)
non_baseline = df[(df['prompt_type'] != 'BASIC') | (df['attack_type'] != 'none') | (df['mitigation_type'] != 'none')]

print("Delta Analysis (Performance vs Baseline)")
print("=" * 40)
print(f"Experiments compared to baseline: {len(non_baseline)}")

# Count improvements vs degradations
mae_improvements = len(non_baseline[non_baseline['delta_overall_mae'] < 0])
mae_degradations = len(non_baseline[non_baseline['delta_overall_mae'] > 0])
jer_improvements = len(non_baseline[non_baseline['delta_overall_jer'] < 0])
jer_degradations = len(non_baseline[non_baseline['delta_overall_jer'] > 0])

print(f"\nMAE Improvements (negative delta): {mae_improvements}")
print(f"MAE Degradations (positive delta): {mae_degradations}")
print(f"JER Improvements (negative delta): {jer_improvements}")
print(f"JER Degradations (positive delta): {jer_degradations}")

# Best improvements
if not non_baseline.empty:
    best_mae_improvement = non_baseline[non_baseline['delta_overall_mae'] == non_baseline['delta_overall_mae'].min()]
    best_jer_improvement = non_baseline[non_baseline['delta_overall_jer'] == non_baseline['delta_overall_jer'].min()]
    
    print(f"\nBest MAE Improvement: {best_mae_improvement['delta_overall_mae'].iloc[0]:.4f}")
    print(f"  Experiment: {best_mae_improvement['prompt_type'].iloc[0]}, {best_mae_improvement['attack_type'].iloc[0]}, {best_mae_improvement['mitigation_type'].iloc[0]}")
    
    print(f"\nBest JER Improvement: {best_jer_improvement['delta_overall_jer'].iloc[0]:.2f}%")
    print(f"  Experiment: {best_jer_improvement['prompt_type'].iloc[0]}, {best_jer_improvement['attack_type'].iloc[0]}, {best_jer_improvement['mitigation_type'].iloc[0]}")
# Out:
# Delta Analysis (Performance vs Baseline)
# ========================================
# Experiments compared to baseline: 47
#
# MAE Improvements (negative delta): 2
# MAE Degradations (positive delta): 45
# JER Improvements (negative delta): 4
# JER Degradations (positive delta): 43
#
# Best MAE Improvement: -0.0681
#   Experiment: BASIC, none, user_prompt_hardening
#
# Best JER Improvement: -4.16%
#   Experiment: BASIC, none, user_prompt_hardening
