# %% [markdown]
# # LLM Query Injection Experiment Results Analysis
#
# This notebook analyzes the results from the LLM query injection experiments, comparing performance across different prompt types, attack types, and mitigation strategies.
#
# **Baseline**: BASIC prompt, no attack, no mitigation

# %%
import pandas as pd
from IPython.display import display
import os
from dotenv import load_dotenv

load_dotenv()

# Set display options
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)

# Load the results

MODEL_NAME = os.getenv("MODEL_NAME")

CSV_FILENAME = f"{MODEL_NAME}_results.csv"
df = pd.read_csv(CSV_FILENAME)

print(f"Loaded {len(df)} experiment results")
print(f"Columns: {list(df.columns)}")
df.head()
# Out:
# Loaded 48 experiment results
# Columns: ['filename', 'prompt_type', 'attack_type', 'mitigation_type', 'overall_mae', 'mae_gt_zero', 'mae_gt_positive', 'overall_jer', 'jer_gt_zero', 'jer_gt_positive', 'delta_overall_mae', 'delta_mae_gt_zero', 'delta_mae_gt_positive', 'delta_overall_jer', 'delta_jer_gt_zero', 'delta_jer_gt_positive', 'valid_experiments', 'gt_zero_count', 'gt_positive_count', 'failed_experiments', 'total_experiments']
#                                             filename prompt_type attack_type  \
# 0                       results_BASIC_none_none.json       BASIC        none
# 1                 results_BASIC_append_few_shot.json       BASIC      append
# 2                     results_BASIC_append_none.json       BASIC      append
# 3  results_BASIC_append_system_prompt_hardening.json       BASIC      append
# 4    results_BASIC_append_user_prompt_hardening.json       BASIC      append
#
#            mitigation_type  overall_mae  mae_gt_zero  mae_gt_positive  \
# 0                     none       1.7711       2.2946           0.9247
# 1                 few_shot       1.7977       2.2985           0.9881
# 2                     none       1.9412       2.5007           1.0365
# 3  system_prompt_hardening       1.7928       2.3080           0.9597
# 4    user_prompt_hardening       2.0705       2.6579           1.1208
#
#    overall_jer  jer_gt_zero  jer_gt_positive  delta_overall_mae  \
# 0        89.46        98.55            74.77                NaN
# 1        88.16        95.50            76.30             0.0266
# 2        89.96        99.08            75.21             0.1701
# 3        89.65        97.65            76.71             0.0216
# 4        88.39        97.26            74.06             0.2994
#
#    delta_mae_gt_zero  delta_mae_gt_positive  delta_overall_jer  \
# 0                NaN                    NaN                NaN
# 1             0.0039                 0.0634              -1.30
# 2             0.2061                 0.1118               0.50
# 3             0.0134                 0.0350               0.19
# 4             0.3633                 0.1960              -1.07
#
#    delta_jer_gt_zero  delta_jer_gt_positive  valid_experiments  gt_zero_count  \
# 0                NaN                    NaN               7021           4338
# 1              -3.04                   1.53               7021           4338
# 2               0.53                   0.45               7021           4338
# 3              -0.90                   1.94               7021           4338
# 4              -1.29                  -0.71               7021           4338
#
#    gt_positive_count  failed_experiments  total_experiments
# 0               2683                   0               7021
# 1               2683                   0               7021
# 2               2683                   0               7021
# 3               2683                   0               7021
# 4               2683                   0               7021

# %% [markdown]
# ## 1. Overall MAE Results

# %%
# Find highest metric and highest delta for Overall MAE
highest_mae = df.loc[df["overall_mae"].idxmax()]
highest_delta_mae = df[df["delta_overall_mae"] != "NaN"].loc[
    df[df["delta_overall_mae"] != "NaN"]["delta_overall_mae"].idxmax()
]
print(f"Highest MAE: {highest_mae['overall_mae']:.4f}")
print(
    f"  Experiment: {highest_mae['prompt_type']}, {highest_mae['attack_type']}, {highest_mae['mitigation_type']}"
)
print(f"\nHighest Δ from Baseline: {highest_delta_mae['delta_overall_mae']:.4f}")
print(
    f"  Experiment: {highest_delta_mae['prompt_type']}, {highest_delta_mae['attack_type']}, {highest_delta_mae['mitigation_type']}"
)
# Out:
# Highest MAE: 2.2931
#   Experiment: UTILITY, prepend, user_prompt_hardening
#
# Highest Δ from Baseline: 0.5220
#   Experiment: UTILITY, prepend, user_prompt_hardening

# %%
# Create overall MAE table
mae_table = df[
    [
        "prompt_type",
        "attack_type",
        "mitigation_type",
        "overall_mae",
        "delta_overall_mae",
    ]
].copy()
mae_table = mae_table.sort_values(["prompt_type", "attack_type", "mitigation_type"])

# Format the table
mae_table["overall_mae"] = mae_table["overall_mae"].apply(
    lambda x: f"{x:.4f}" if pd.notna(x) else "N/A"
)
mae_table["delta_overall_mae"] = mae_table["delta_overall_mae"].apply(
    lambda x: f"{x:+.4f}" if pd.notna(x) and x != "NaN" else "N/A"
)

# Rename columns for display
mae_table_display = mae_table.rename(
    columns={
        "prompt_type": "Prompt",
        "attack_type": "Attack",
        "mitigation_type": "Mitigation",
        "overall_mae": "MAE",
        "delta_overall_mae": "Δ from Baseline",
    }
)

print("Overall MAE Results (Mean Absolute Error)")
print("=" * 60)
display(mae_table_display)
# Out:
# Overall MAE Results (Mean Absolute Error)
# ============================================================
#        Prompt   Attack               Mitigation     MAE Δ from Baseline
# 1       BASIC   append                 few_shot  1.7977         +0.0266
# 2       BASIC   append                     none  1.9412         +0.1701
# 3       BASIC   append  system_prompt_hardening  1.7928         +0.0216
# 4       BASIC   append    user_prompt_hardening  2.0705         +0.2994
# 5       BASIC     none                 few_shot  1.6189         -0.1523
# 0       BASIC     none                     none  1.7711             N/A
# 6       BASIC     none  system_prompt_hardening  1.6642         -0.1070
# 7       BASIC     none    user_prompt_hardening  1.9605         +0.1894
# 8       BASIC  prepend                 few_shot  1.8096         +0.0385
# 9       BASIC  prepend                     none  1.9543         +0.1832
# 10      BASIC  prepend  system_prompt_hardening  1.8871         +0.1159
# 11      BASIC  prepend    user_prompt_hardening  2.1644         +0.3932
# 12      BASIC  scatter                 few_shot  1.7248         -0.0463
# 13      BASIC  scatter                     none  1.8943         +0.1232
# 14      BASIC  scatter  system_prompt_hardening  1.7680         -0.0031
# 15      BASIC  scatter    user_prompt_hardening  2.1181         +0.3470
# 16  RATIONALE   append                 few_shot  1.9721         +0.2010
# 17  RATIONALE   append                     none  2.1795         +0.4083
# 18  RATIONALE   append  system_prompt_hardening  2.0376         +0.2665
# 19  RATIONALE   append    user_prompt_hardening  2.1562         +0.3851
# 20  RATIONALE     none                 few_shot  1.7559         -0.0152
# 21  RATIONALE     none                     none  2.1231         +0.3519
# 22  RATIONALE     none  system_prompt_hardening  1.8916         +0.1205
# 23  RATIONALE     none    user_prompt_hardening  2.0622         +0.2911
# 24  RATIONALE  prepend                 few_shot  2.1162         +0.3451
# 25  RATIONALE  prepend                     none  2.2572         +0.4861
# 26  RATIONALE  prepend  system_prompt_hardening  2.1742         +0.4031
# 27  RATIONALE  prepend    user_prompt_hardening  2.2686         +0.4975
# 28  RATIONALE  scatter                 few_shot  1.8791         +0.1080
# 29  RATIONALE  scatter                     none  2.1950         +0.4239
# 30  RATIONALE  scatter  system_prompt_hardening  2.0158         +0.2447
# 31  RATIONALE  scatter    user_prompt_hardening  2.1850         +0.4139
# 32    UTILITY   append                 few_shot  1.9835         +0.2124
# 33    UTILITY   append                     none  2.1966         +0.4254
# 34    UTILITY   append  system_prompt_hardening  2.0706         +0.2995
# 35    UTILITY   append    user_prompt_hardening  2.1973         +0.4262
# 36    UTILITY     none                 few_shot  1.7868         +0.0157
# 37    UTILITY     none                     none  2.1574         +0.3863
# 38    UTILITY     none  system_prompt_hardening  1.9635         +0.1924
# 39    UTILITY     none    user_prompt_hardening  2.1483         +0.3772
# 40    UTILITY  prepend                 few_shot  2.1373         +0.3662
# 41    UTILITY  prepend                     none  2.2574         +0.4863
# 42    UTILITY  prepend  system_prompt_hardening  2.2025         +0.4314
# 43    UTILITY  prepend    user_prompt_hardening  2.2931         +0.5220
# 44    UTILITY  scatter                 few_shot  1.9603         +0.1891
# 45    UTILITY  scatter                     none  2.2191         +0.4479
# 46    UTILITY  scatter  system_prompt_hardening  2.0903         +0.3192
# 47    UTILITY  scatter    user_prompt_hardening  2.2297         +0.4586

# %% [markdown]
# ## 2. Overall JER Results

# %%
# Find highest metric and highest delta for Overall JER
highest_jer = df.loc[df["overall_jer"].idxmax()]
highest_delta_jer = df[df["delta_overall_jer"] != "NaN"].loc[
    df[df["delta_overall_jer"] != "NaN"]["delta_overall_jer"].idxmax()
]
print(f"Highest JER: {highest_jer['overall_jer']:.2f}%")
print(
    f"  Experiment: {highest_jer['prompt_type']}, {highest_jer['attack_type']}, {highest_jer['mitigation_type']}"
)
print(f"\nHighest Δ from Baseline: {highest_delta_jer['delta_overall_jer']:.2f}%")
print(
    f"  Experiment: {highest_delta_jer['prompt_type']}, {highest_delta_jer['attack_type']}, {highest_delta_jer['mitigation_type']}"
)
# Out:
# Highest JER: 90.30%
#   Experiment: RATIONALE, scatter, system_prompt_hardening
#
# Highest Δ from Baseline: 0.84%
#   Experiment: RATIONALE, scatter, system_prompt_hardening

# %%
# Create overall JER table
jer_table = df[
    [
        "prompt_type",
        "attack_type",
        "mitigation_type",
        "overall_jer",
        "delta_overall_jer",
    ]
].copy()
jer_table = jer_table.sort_values(["prompt_type", "attack_type", "mitigation_type"])

# Format the table
jer_table["overall_jer"] = jer_table["overall_jer"].apply(
    lambda x: f"{x:.2f}%" if pd.notna(x) else "N/A"
)
jer_table["delta_overall_jer"] = jer_table["delta_overall_jer"].apply(
    lambda x: f"{x:+.2f}%" if pd.notna(x) and x != "NaN" else "N/A"
)

# Rename columns for display
jer_table_display = jer_table.rename(
    columns={
        "prompt_type": "Prompt",
        "attack_type": "Attack",
        "mitigation_type": "Mitigation",
        "overall_jer": "JER",
        "delta_overall_jer": "Δ from Baseline",
    }
)

print("Overall JER Results (Judgment Error Rate)")
print("=" * 60)
display(jer_table_display)
# Out:
# Overall JER Results (Judgment Error Rate)
# ============================================================
#        Prompt   Attack               Mitigation     JER Δ from Baseline
# 1       BASIC   append                 few_shot  88.16%          -1.30%
# 2       BASIC   append                     none  89.96%          +0.50%
# 3       BASIC   append  system_prompt_hardening  89.65%          +0.19%
# 4       BASIC   append    user_prompt_hardening  88.39%          -1.07%
# 5       BASIC     none                 few_shot  87.88%          -1.58%
# 0       BASIC     none                     none  89.46%             N/A
# 6       BASIC     none  system_prompt_hardening  89.26%          -0.20%
# 7       BASIC     none    user_prompt_hardening  88.65%          -0.81%
# 8       BASIC  prepend                 few_shot  89.65%          +0.19%
# 9       BASIC  prepend                     none  89.75%          +0.28%
# 10      BASIC  prepend  system_prompt_hardening  89.83%          +0.37%
# 11      BASIC  prepend    user_prompt_hardening  89.69%          +0.23%
# 12      BASIC  scatter                 few_shot  88.41%          -1.05%
# 13      BASIC  scatter                     none  90.23%          +0.77%
# 14      BASIC  scatter  system_prompt_hardening  90.27%          +0.81%
# 15      BASIC  scatter    user_prompt_hardening  89.43%          -0.03%
# 16  RATIONALE   append                 few_shot  89.09%          -0.37%
# 17  RATIONALE   append                     none  89.59%          +0.13%
# 18  RATIONALE   append  system_prompt_hardening  89.72%          +0.26%
# 19  RATIONALE   append    user_prompt_hardening  88.46%          -1.00%
# 20  RATIONALE     none                 few_shot  88.22%          -1.24%
# 21  RATIONALE     none                     none  89.53%          +0.07%
# 22  RATIONALE     none  system_prompt_hardening  89.79%          +0.33%
# 23  RATIONALE     none    user_prompt_hardening  88.36%          -1.10%
# 24  RATIONALE  prepend                 few_shot  89.50%          +0.04%
# 25  RATIONALE  prepend                     none  89.89%          +0.43%
# 26  RATIONALE  prepend  system_prompt_hardening  89.60%          +0.14%
# 27  RATIONALE  prepend    user_prompt_hardening  89.73%          +0.27%
# 28  RATIONALE  scatter                 few_shot  88.75%          -0.71%
# 29  RATIONALE  scatter                     none  89.73%          +0.27%
# 30  RATIONALE  scatter  system_prompt_hardening  90.30%          +0.84%
# 31  RATIONALE  scatter    user_prompt_hardening  88.95%          -0.51%
# 32    UTILITY   append                 few_shot  87.88%          -1.58%
# 33    UTILITY   append                     none  89.29%          -0.17%
# 34    UTILITY   append  system_prompt_hardening  88.61%          -0.85%
# 35    UTILITY   append    user_prompt_hardening  87.77%          -1.69%
# 36    UTILITY     none                 few_shot  87.65%          -1.81%
# 37    UTILITY     none                     none  88.88%          -0.58%
# 38    UTILITY     none  system_prompt_hardening  88.81%          -0.66%
# 39    UTILITY     none    user_prompt_hardening  87.61%          -1.85%
# 40    UTILITY  prepend                 few_shot  89.19%          -0.27%
# 41    UTILITY  prepend                     none  89.70%          +0.24%
# 42    UTILITY  prepend  system_prompt_hardening  89.39%          -0.07%
# 43    UTILITY  prepend    user_prompt_hardening  89.82%          +0.36%
# 44    UTILITY  scatter                 few_shot  88.24%          -1.22%
# 45    UTILITY  scatter                     none  89.39%          -0.07%
# 46    UTILITY  scatter  system_prompt_hardening  89.42%          -0.04%
# 47    UTILITY  scatter    user_prompt_hardening  88.56%          -0.90%

# %% [markdown]
# ## 3. MAE for Ground Truth = 0 (Irrelevant Documents)

# %%
# Find highest metric and highest delta for MAE (GT=0)
highest_mae_gt0 = df.loc[df["mae_gt_zero"].idxmax()]
highest_delta_mae_gt0 = df[df["delta_mae_gt_zero"] != "NaN"].loc[
    df[df["delta_mae_gt_zero"] != "NaN"]["delta_mae_gt_zero"].idxmax()
]
print(f"Highest MAE (GT=0): {highest_mae_gt0['mae_gt_zero']:.4f}")
print(
    f"  Experiment: {highest_mae_gt0['prompt_type']}, {highest_mae_gt0['attack_type']}, {highest_mae_gt0['mitigation_type']}"
)
print(f"\nHighest Δ from Baseline: {highest_delta_mae_gt0['delta_mae_gt_zero']:.4f}")
print(
    f"  Experiment: {highest_delta_mae_gt0['prompt_type']}, {highest_delta_mae_gt0['attack_type']}, {highest_delta_mae_gt0['mitigation_type']}"
)
# Out:
# Highest MAE (GT=0): 2.9373
#   Experiment: UTILITY, prepend, user_prompt_hardening
#
# Highest Δ from Baseline: 0.6427
#   Experiment: UTILITY, prepend, user_prompt_hardening

# %%
# Create GT=0 MAE table
mae_gt0_table = df[
    [
        "prompt_type",
        "attack_type",
        "mitigation_type",
        "mae_gt_zero",
        "delta_mae_gt_zero",
    ]
].copy()
mae_gt0_table = mae_gt0_table.sort_values(
    ["prompt_type", "attack_type", "mitigation_type"]
)

# Format the table
mae_gt0_table["mae_gt_zero"] = mae_gt0_table["mae_gt_zero"].apply(
    lambda x: f"{x:.4f}" if pd.notna(x) else "N/A"
)
mae_gt0_table["delta_mae_gt_zero"] = mae_gt0_table["delta_mae_gt_zero"].apply(
    lambda x: f"{x:+.4f}" if pd.notna(x) and x != "NaN" else "N/A"
)

# Rename columns for display
mae_gt0_table_display = mae_gt0_table.rename(
    columns={
        "prompt_type": "Prompt",
        "attack_type": "Attack",
        "mitigation_type": "Mitigation",
        "mae_gt_zero": "MAE (GT=0)",
        "delta_mae_gt_zero": "Δ from Baseline",
    }
)

print("MAE for Ground Truth = 0 (Irrelevant Documents)")
print("=" * 60)
display(mae_gt0_table_display)
# Out:
# MAE for Ground Truth = 0 (Irrelevant Documents)
# ============================================================
#        Prompt   Attack               Mitigation MAE (GT=0) Δ from Baseline
# 1       BASIC   append                 few_shot     2.2985         +0.0039
# 2       BASIC   append                     none     2.5007         +0.2061
# 3       BASIC   append  system_prompt_hardening     2.3080         +0.0134
# 4       BASIC   append    user_prompt_hardening     2.6579         +0.3633
# 5       BASIC     none                 few_shot     2.0920         -0.2026
# 0       BASIC     none                     none     2.2946             N/A
# 6       BASIC     none  system_prompt_hardening     2.1515         -0.1432
# 7       BASIC     none    user_prompt_hardening     2.5166         +0.2220
# 8       BASIC  prepend                 few_shot     2.3686         +0.0740
# 9       BASIC  prepend                     none     2.5461         +0.2515
# 10      BASIC  prepend  system_prompt_hardening     2.4569         +0.1623
# 11      BASIC  prepend    user_prompt_hardening     2.7882         +0.4935
# 12      BASIC  scatter                 few_shot     2.2254         -0.0692
# 13      BASIC  scatter                     none     2.4394         +0.1448
# 14      BASIC  scatter  system_prompt_hardening     2.2822         -0.0124
# 15      BASIC  scatter    user_prompt_hardening     2.7181         +0.4235
# 16  RATIONALE   append                 few_shot     2.5182         +0.2236
# 17  RATIONALE   append                     none     2.8020         +0.5074
# 18  RATIONALE   append  system_prompt_hardening     2.6155         +0.3209
# 19  RATIONALE   append    user_prompt_hardening     2.7614         +0.4668
# 20  RATIONALE     none                 few_shot     2.2437         -0.0509
# 21  RATIONALE     none                     none     2.7225         +0.4278
# 22  RATIONALE     none  system_prompt_hardening     2.4327         +0.1381
# 23  RATIONALE     none    user_prompt_hardening     2.6413         +0.3467
# 24  RATIONALE  prepend                 few_shot     2.7261         +0.4315
# 25  RATIONALE  prepend                     none     2.9011         +0.6065
# 26  RATIONALE  prepend  system_prompt_hardening     2.8057         +0.5111
# 27  RATIONALE  prepend    user_prompt_hardening     2.9110         +0.6164
# 28  RATIONALE  scatter                 few_shot     2.3912         +0.0966
# 29  RATIONALE  scatter                     none     2.8183         +0.5237
# 30  RATIONALE  scatter  system_prompt_hardening     2.5807         +0.2861
# 31  RATIONALE  scatter    user_prompt_hardening     2.8022         +0.5076
# 32    UTILITY   append                 few_shot     2.5106         +0.2160
# 33    UTILITY   append                     none     2.8209         +0.5263
# 34    UTILITY   append  system_prompt_hardening     2.6413         +0.3467
# 35    UTILITY   append    user_prompt_hardening     2.8061         +0.5115
# 36    UTILITY     none                 few_shot     2.2716         -0.0231
# 37    UTILITY     none                     none     2.7642         +0.4696
# 38    UTILITY     none  system_prompt_hardening     2.5101         +0.2155
# 39    UTILITY     none    user_prompt_hardening     2.7497         +0.4550
# 40    UTILITY  prepend                 few_shot     2.7575         +0.4629
# 41    UTILITY  prepend                     none     2.9059         +0.6113
# 42    UTILITY  prepend  system_prompt_hardening     2.8396         +0.5450
# 43    UTILITY  prepend    user_prompt_hardening     2.9373         +0.6427
# 44    UTILITY  scatter                 few_shot     2.4894         +0.1948
# 45    UTILITY  scatter                     none     2.8479         +0.5533
# 46    UTILITY  scatter  system_prompt_hardening     2.6759         +0.3813
# 47    UTILITY  scatter    user_prompt_hardening     2.8571         +0.5625

# %% [markdown]
# ## 4. JER for Ground Truth = 0 (Irrelevant Documents)

# %%
# Find highest metric and highest delta for JER (GT=0)
highest_jer_gt0 = df.loc[df["jer_gt_zero"].idxmax()]
highest_delta_jer_gt0 = df[df["delta_jer_gt_zero"] != "NaN"].loc[
    df[df["delta_jer_gt_zero"] != "NaN"]["delta_jer_gt_zero"].idxmax()
]
print(f"Highest JER (GT=0): {highest_jer_gt0['jer_gt_zero']:.2f}%")
print(
    f"  Experiment: {highest_jer_gt0['prompt_type']}, {highest_jer_gt0['attack_type']}, {highest_jer_gt0['mitigation_type']}"
)
print(f"\nHighest Δ from Baseline: {highest_delta_jer_gt0['delta_jer_gt_zero']:.2f}%")
print(
    f"  Experiment: {highest_delta_jer_gt0['prompt_type']}, {highest_delta_jer_gt0['attack_type']}, {highest_delta_jer_gt0['mitigation_type']}"
)
# Out:
# Highest JER (GT=0): 100.00%
#   Experiment: RATIONALE, prepend, none
#
# Highest Δ from Baseline: 1.45%
#   Experiment: RATIONALE, prepend, none

# %%
# Create GT=0 JER table
jer_gt0_table = df[
    [
        "prompt_type",
        "attack_type",
        "mitigation_type",
        "jer_gt_zero",
        "delta_jer_gt_zero",
    ]
].copy()
jer_gt0_table = jer_gt0_table.sort_values(
    ["prompt_type", "attack_type", "mitigation_type"]
)

# Format the table
jer_gt0_table["jer_gt_zero"] = jer_gt0_table["jer_gt_zero"].apply(
    lambda x: f"{x:.2f}%" if pd.notna(x) else "N/A"
)
jer_gt0_table["delta_jer_gt_zero"] = jer_gt0_table["delta_jer_gt_zero"].apply(
    lambda x: f"{x:+.2f}%" if pd.notna(x) and x != "NaN" else "N/A"
)

# Rename columns for display
jer_gt0_table_display = jer_gt0_table.rename(
    columns={
        "prompt_type": "Prompt",
        "attack_type": "Attack",
        "mitigation_type": "Mitigation",
        "jer_gt_zero": "JER (GT=0)",
        "delta_jer_gt_zero": "Δ from Baseline",
    }
)

print("JER for Ground Truth = 0 (Irrelevant Documents)")
print("=" * 60)
display(jer_gt0_table_display)
# Out:
# JER for Ground Truth = 0 (Irrelevant Documents)
# ============================================================
#        Prompt   Attack               Mitigation JER (GT=0) Δ from Baseline
# 1       BASIC   append                 few_shot     95.50%          -3.04%
# 2       BASIC   append                     none     99.08%          +0.53%
# 3       BASIC   append  system_prompt_hardening     97.65%          -0.90%
# 4       BASIC   append    user_prompt_hardening     97.26%          -1.29%
# 5       BASIC     none                 few_shot     95.27%          -3.27%
# 0       BASIC     none                     none     98.55%             N/A
# 6       BASIC     none  system_prompt_hardening     97.21%          -1.34%
# 7       BASIC     none    user_prompt_hardening     97.42%          -1.13%
# 8       BASIC  prepend                 few_shot     99.26%          +0.71%
# 9       BASIC  prepend                     none     99.82%          +1.27%
# 10      BASIC  prepend  system_prompt_hardening     99.54%          +0.99%
# 11      BASIC  prepend    user_prompt_hardening     99.47%          +0.92%
# 12      BASIC  scatter                 few_shot     96.08%          -2.47%
# 13      BASIC  scatter                     none     98.96%          +0.41%
# 14      BASIC  scatter  system_prompt_hardening     98.13%          -0.41%
# 15      BASIC  scatter    user_prompt_hardening     98.46%          -0.09%
# 16  RATIONALE   append                 few_shot     97.53%          -1.01%
# 17  RATIONALE   append                     none     99.52%          +0.97%
# 18  RATIONALE   append  system_prompt_hardening     99.08%          +0.53%
# 19  RATIONALE   append    user_prompt_hardening     97.88%          -0.67%
# 20  RATIONALE     none                 few_shot     96.10%          -2.44%
# 21  RATIONALE     none                     none     99.29%          +0.74%
# 22  RATIONALE     none  system_prompt_hardening     99.17%          +0.62%
# 23  RATIONALE     none    user_prompt_hardening     97.44%          -1.11%
# 24  RATIONALE  prepend                 few_shot     99.54%          +0.99%
# 25  RATIONALE  prepend                     none    100.00%          +1.45%
# 26  RATIONALE  prepend  system_prompt_hardening     99.98%          +1.43%
# 27  RATIONALE  prepend    user_prompt_hardening     99.65%          +1.11%
# 28  RATIONALE  scatter                 few_shot     96.47%          -2.07%
# 29  RATIONALE  scatter                     none     99.45%          +0.90%
# 30  RATIONALE  scatter  system_prompt_hardening     99.38%          +0.83%
# 31  RATIONALE  scatter    user_prompt_hardening     98.18%          -0.37%
# 32    UTILITY   append                 few_shot     95.07%          -3.48%
# 33    UTILITY   append                     none     98.82%          +0.28%
# 34    UTILITY   append  system_prompt_hardening     97.26%          -1.29%
# 35    UTILITY   append    user_prompt_hardening     96.45%          -2.10%
# 36    UTILITY     none                 few_shot     94.58%          -3.96%
# 37    UTILITY     none                     none     98.27%          -0.28%
# 38    UTILITY     none  system_prompt_hardening     97.05%          -1.50%
# 39    UTILITY     none    user_prompt_hardening     96.47%          -2.07%
# 40    UTILITY  prepend                 few_shot     99.10%          +0.55%
# 41    UTILITY  prepend                     none     99.84%          +1.29%
# 42    UTILITY  prepend  system_prompt_hardening     99.59%          +1.04%
# 43    UTILITY  prepend    user_prompt_hardening     99.35%          +0.81%
# 44    UTILITY  scatter                 few_shot     95.46%          -3.09%
# 45    UTILITY  scatter                     none     98.96%          +0.41%
# 46    UTILITY  scatter  system_prompt_hardening     98.25%          -0.30%
# 47    UTILITY  scatter    user_prompt_hardening     97.63%          -0.92%

# %% [markdown]
# ## 5. MAE for Ground Truth > 0 (Relevant Documents)

# %%
# Find highest metric and highest delta for MAE (GT>0)
highest_mae_gtpos = df.loc[df["mae_gt_positive"].idxmax()]
highest_delta_mae_gtpos = df[df["delta_mae_gt_positive"] != "NaN"].loc[
    df[df["delta_mae_gt_positive"] != "NaN"]["delta_mae_gt_positive"].idxmax()
]
print(f"Highest MAE (GT>0): {highest_mae_gtpos['mae_gt_positive']:.4f}")
print(
    f"  Experiment: {highest_mae_gtpos['prompt_type']}, {highest_mae_gtpos['attack_type']}, {highest_mae_gtpos['mitigation_type']}"
)
print(
    f"\nHighest Δ from Baseline: {highest_delta_mae_gtpos['delta_mae_gt_positive']:.4f}"
)
print(
    f"  Experiment: {highest_delta_mae_gtpos['prompt_type']}, {highest_delta_mae_gtpos['attack_type']}, {highest_delta_mae_gtpos['mitigation_type']}"
)
# Out:
# Highest MAE (GT>0): 1.2516
#   Experiment: UTILITY, prepend, user_prompt_hardening
#
# Highest Δ from Baseline: 0.3269
#   Experiment: UTILITY, prepend, user_prompt_hardening

# %%
# Create GT>0 MAE table
mae_gtpos_table = df[
    [
        "prompt_type",
        "attack_type",
        "mitigation_type",
        "mae_gt_positive",
        "delta_mae_gt_positive",
    ]
].copy()
mae_gtpos_table = mae_gtpos_table.sort_values(
    ["prompt_type", "attack_type", "mitigation_type"]
)

# Format the table
mae_gtpos_table["mae_gt_positive"] = mae_gtpos_table["mae_gt_positive"].apply(
    lambda x: f"{x:.4f}" if pd.notna(x) else "N/A"
)
mae_gtpos_table["delta_mae_gt_positive"] = mae_gtpos_table[
    "delta_mae_gt_positive"
].apply(lambda x: f"{x:+.4f}" if pd.notna(x) and x != "NaN" else "N/A")

# Rename columns for display
mae_gtpos_table_display = mae_gtpos_table.rename(
    columns={
        "prompt_type": "Prompt",
        "attack_type": "Attack",
        "mitigation_type": "Mitigation",
        "mae_gt_positive": "MAE (GT>0)",
        "delta_mae_gt_positive": "Δ from Baseline",
    }
)

print("MAE for Ground Truth > 0 (Relevant Documents)")
print("=" * 60)
display(mae_gtpos_table_display)
# Out:
# MAE for Ground Truth > 0 (Relevant Documents)
# ============================================================
#        Prompt   Attack               Mitigation MAE (GT>0) Δ from Baseline
# 1       BASIC   append                 few_shot     0.9881         +0.0634
# 2       BASIC   append                     none     1.0365         +0.1118
# 3       BASIC   append  system_prompt_hardening     0.9597         +0.0350
# 4       BASIC   append    user_prompt_hardening     1.1208         +0.1960
# 5       BASIC     none                 few_shot     0.8539         -0.0708
# 0       BASIC     none                     none     0.9247             N/A
# 6       BASIC     none  system_prompt_hardening     0.8763         -0.0485
# 7       BASIC     none    user_prompt_hardening     1.0615         +0.1368
# 8       BASIC  prepend                 few_shot     0.9057         -0.0190
# 9       BASIC  prepend                     none     0.9974         +0.0727
# 10      BASIC  prepend  system_prompt_hardening     0.9657         +0.0410
# 11      BASIC  prepend    user_prompt_hardening     1.1558         +0.2311
# 12      BASIC  scatter                 few_shot     0.9154         -0.0093
# 13      BASIC  scatter                     none     1.0130         +0.0883
# 14      BASIC  scatter  system_prompt_hardening     0.9366         +0.0119
# 15      BASIC  scatter    user_prompt_hardening     1.1480         +0.2233
# 16  RATIONALE   append                 few_shot     1.0891         +0.1644
# 17  RATIONALE   append                     none     1.1729         +0.2482
# 18  RATIONALE   append  system_prompt_hardening     1.1032         +0.1785
# 19  RATIONALE   append    user_prompt_hardening     1.1778         +0.2531
# 20  RATIONALE     none                 few_shot     0.9672         +0.0425
# 21  RATIONALE     none                     none     1.1539         +0.2292
# 22  RATIONALE     none  system_prompt_hardening     1.0168         +0.0921
# 23  RATIONALE     none    user_prompt_hardening     1.1260         +0.2013
# 24  RATIONALE  prepend                 few_shot     1.1301         +0.2054
# 25  RATIONALE  prepend                     none     1.2162         +0.2915
# 26  RATIONALE  prepend  system_prompt_hardening     1.1532         +0.2285
# 27  RATIONALE  prepend    user_prompt_hardening     1.2300         +0.3053
# 28  RATIONALE  scatter                 few_shot     1.0511         +0.1264
# 29  RATIONALE  scatter                     none     1.1871         +0.2624
# 30  RATIONALE  scatter  system_prompt_hardening     1.1025         +0.1778
# 31  RATIONALE  scatter    user_prompt_hardening     1.1871         +0.2624
# 32    UTILITY   append                 few_shot     1.1312         +0.2065
# 33    UTILITY   append                     none     1.1871         +0.2624
# 34    UTILITY   append  system_prompt_hardening     1.1480         +0.2233
# 35    UTILITY   append    user_prompt_hardening     1.2128         +0.2881
# 36    UTILITY     none                 few_shot     1.0030         +0.0783
# 37    UTILITY     none                     none     1.1763         +0.2516
# 38    UTILITY     none  system_prompt_hardening     1.0798         +0.1551
# 39    UTILITY     none    user_prompt_hardening     1.1759         +0.2512
# 40    UTILITY  prepend                 few_shot     1.1346         +0.2098
# 41    UTILITY  prepend                     none     1.2087         +0.2840
# 42    UTILITY  prepend  system_prompt_hardening     1.1726         +0.2479
# 43    UTILITY  prepend    user_prompt_hardening     1.2516         +0.3269
# 44    UTILITY  scatter                 few_shot     1.1047         +0.1800
# 45    UTILITY  scatter                     none     1.2024         +0.2777
# 46    UTILITY  scatter  system_prompt_hardening     1.1435         +0.2188
# 47    UTILITY  scatter    user_prompt_hardening     1.2154         +0.2907

# %% [markdown]
# ## 6. JER for Ground Truth > 0 (Relevant Documents)

# %%
# Find highest metric and highest delta for JER (GT>0)
highest_jer_gtpos = df.loc[df["jer_gt_positive"].idxmax()]
highest_delta_jer_gtpos = df[df["delta_jer_gt_positive"] != "NaN"].loc[
    df[df["delta_jer_gt_positive"] != "NaN"]["delta_jer_gt_positive"].idxmax()
]
print(f"Highest JER (GT>0): {highest_jer_gtpos['jer_gt_positive']:.2f}%")
print(
    f"  Experiment: {highest_jer_gtpos['prompt_type']}, {highest_jer_gtpos['attack_type']}, {highest_jer_gtpos['mitigation_type']}"
)
print(
    f"\nHighest Δ from Baseline: {highest_delta_jer_gtpos['delta_jer_gt_positive']:.2f}%"
)
print(
    f"  Experiment: {highest_delta_jer_gtpos['prompt_type']}, {highest_delta_jer_gtpos['attack_type']}, {highest_delta_jer_gtpos['mitigation_type']}"
)
# Out:
# Highest JER (GT>0): 77.56%
#   Experiment: BASIC, scatter, system_prompt_hardening
#
# Highest Δ from Baseline: 2.80%
#   Experiment: BASIC, scatter, system_prompt_hardening

# %%
# Create GT>0 JER table
jer_gtpos_table = df[
    [
        "prompt_type",
        "attack_type",
        "mitigation_type",
        "jer_gt_positive",
        "delta_jer_gt_positive",
    ]
].copy()
jer_gtpos_table = jer_gtpos_table.sort_values(
    ["prompt_type", "attack_type", "mitigation_type"]
)

# Format the table
jer_gtpos_table["jer_gt_positive"] = jer_gtpos_table["jer_gt_positive"].apply(
    lambda x: f"{x:.2f}%" if pd.notna(x) else "N/A"
)
jer_gtpos_table["delta_jer_gt_positive"] = jer_gtpos_table[
    "delta_jer_gt_positive"
].apply(lambda x: f"{x:+.2f}%" if pd.notna(x) and x != "NaN" else "N/A")

# Rename columns for display
jer_gtpos_table_display = jer_gtpos_table.rename(
    columns={
        "prompt_type": "Prompt",
        "attack_type": "Attack",
        "mitigation_type": "Mitigation",
        "jer_gt_positive": "JER (GT>0)",
        "delta_jer_gt_positive": "Δ from Baseline",
    }
)

print("JER for Ground Truth > 0 (Relevant Documents)")
print("=" * 60)
display(jer_gtpos_table_display)
# Out:
# JER for Ground Truth > 0 (Relevant Documents)
# ============================================================
#        Prompt   Attack               Mitigation JER (GT>0) Δ from Baseline
# 1       BASIC   append                 few_shot     76.30%          +1.53%
# 2       BASIC   append                     none     75.21%          +0.45%
# 3       BASIC   append  system_prompt_hardening     76.71%          +1.94%
# 4       BASIC   append    user_prompt_hardening     74.06%          -0.71%
# 5       BASIC     none                 few_shot     75.92%          +1.16%
# 0       BASIC     none                     none     74.77%             N/A
# 6       BASIC     none  system_prompt_hardening     76.41%          +1.64%
# 7       BASIC     none    user_prompt_hardening     74.47%          -0.30%
# 8       BASIC  prepend                 few_shot     74.10%          -0.67%
# 9       BASIC  prepend                     none     73.46%          -1.30%
# 10      BASIC  prepend  system_prompt_hardening     74.13%          -0.63%
# 11      BASIC  prepend    user_prompt_hardening     73.87%          -0.89%
# 12      BASIC  scatter                 few_shot     76.00%          +1.23%
# 13      BASIC  scatter                     none     76.11%          +1.34%
# 14      BASIC  scatter  system_prompt_hardening     77.56%          +2.80%
# 15      BASIC  scatter    user_prompt_hardening     74.84%          +0.07%
# 16  RATIONALE   append                 few_shot     75.44%          +0.67%
# 17  RATIONALE   append                     none     73.54%          -1.23%
# 18  RATIONALE   append  system_prompt_hardening     74.58%          -0.19%
# 19  RATIONALE   append    user_prompt_hardening     73.24%          -1.53%
# 20  RATIONALE     none                 few_shot     75.48%          +0.71%
# 21  RATIONALE     none                     none     73.76%          -1.01%
# 22  RATIONALE     none  system_prompt_hardening     74.62%          -0.15%
# 23  RATIONALE     none    user_prompt_hardening     73.69%          -1.08%
# 24  RATIONALE  prepend                 few_shot     73.28%          -1.49%
# 25  RATIONALE  prepend                     none     73.54%          -1.23%
# 26  RATIONALE  prepend  system_prompt_hardening     72.83%          -1.94%
# 27  RATIONALE  prepend    user_prompt_hardening     73.69%          -1.08%
# 28  RATIONALE  scatter                 few_shot     76.26%          +1.49%
# 29  RATIONALE  scatter                     none     74.02%          -0.75%
# 30  RATIONALE  scatter  system_prompt_hardening     75.62%          +0.86%
# 31  RATIONALE  scatter    user_prompt_hardening     74.02%          -0.75%
# 32    UTILITY   append                 few_shot     76.26%          +1.49%
# 33    UTILITY   append                     none     73.87%          -0.89%
# 34    UTILITY   append  system_prompt_hardening     74.62%          -0.15%
# 35    UTILITY   append    user_prompt_hardening     73.72%          -1.04%
# 36    UTILITY     none                 few_shot     76.44%          +1.68%
# 37    UTILITY     none                     none     73.69%          -1.08%
# 38    UTILITY     none  system_prompt_hardening     75.48%          +0.71%
# 39    UTILITY     none    user_prompt_hardening     73.28%          -1.49%
# 40    UTILITY  prepend                 few_shot     73.16%          -1.60%
# 41    UTILITY  prepend                     none     73.31%          -1.45%
# 42    UTILITY  prepend  system_prompt_hardening     72.90%          -1.86%
# 43    UTILITY  prepend    user_prompt_hardening     74.39%          -0.37%
# 44    UTILITY  scatter                 few_shot     76.56%          +1.79%
# 45    UTILITY  scatter                     none     73.91%          -0.86%
# 46    UTILITY  scatter  system_prompt_hardening     75.14%          +0.37%
# 47    UTILITY  scatter    user_prompt_hardening     73.91%          -0.86%

# %% [markdown]
# ## 7. Summary Statistics

# %%
# Summary statistics
print("Experiment Summary")
print("=" * 30)
print(f"Total experiments: {len(df)}")
print(f"Prompt types: {df['prompt_type'].unique().tolist()}")
print(f"Attack types: {df['attack_type'].unique().tolist()}")
print(f"Mitigation types: {df['mitigation_type'].unique().tolist()}")

# Find baseline
baseline = df[
    (df["prompt_type"] == "BASIC")
    & (df["attack_type"] == "none")
    & (df["mitigation_type"] == "none")
]
if not baseline.empty:
    print("\nBaseline (BASIC, none, none) metrics:")
    print(f"  Overall MAE: {baseline['overall_mae'].iloc[0]:.4f}")
    print(f"  Overall JER: {baseline['overall_jer'].iloc[0]:.2f}%")
    print(f"  MAE GT=0: {baseline['mae_gt_zero'].iloc[0]:.4f}")
    print(f"  JER GT=0: {baseline['jer_gt_zero'].iloc[0]:.2f}%")
    print(f"  MAE GT>0: {baseline['mae_gt_positive'].iloc[0]:.4f}")
    print(f"  JER GT>0: {baseline['jer_gt_positive'].iloc[0]:.2f}%")

# Best and worst performing experiments
print(f"\nBest Overall MAE: {df['overall_mae'].min():.4f}")
best_mae = df[df["overall_mae"] == df["overall_mae"].min()]
print(
    f"  Experiment: {best_mae['prompt_type'].iloc[0]}, {best_mae['attack_type'].iloc[0]}, {best_mae['mitigation_type'].iloc[0]}"
)

print(f"\nWorst Overall MAE: {df['overall_mae'].max():.4f}")
worst_mae = df[df["overall_mae"] == df["overall_mae"].max()]
print(
    f"  Experiment: {worst_mae['prompt_type'].iloc[0]}, {worst_mae['attack_type'].iloc[0]}, {worst_mae['mitigation_type'].iloc[0]}"
)

print(f"\nBest Overall JER: {df['overall_jer'].min():.2f}%")
best_jer = df[df["overall_jer"] == df["overall_jer"].min()]
print(
    f"  Experiment: {best_jer['prompt_type'].iloc[0]}, {best_jer['attack_type'].iloc[0]}, {best_jer['mitigation_type'].iloc[0]}"
)

print(f"\nWorst Overall JER: {df['overall_jer'].max():.2f}%")
worst_jer = df[df["overall_jer"] == df["overall_jer"].max()]
print(
    f"  Experiment: {worst_jer['prompt_type'].iloc[0]}, {worst_jer['attack_type'].iloc[0]}, {worst_jer['mitigation_type'].iloc[0]}"
)
# Out:
# Experiment Summary
# ==============================
# Total experiments: 48
# Prompt types: ['BASIC', 'RATIONALE', 'UTILITY']
# Attack types: ['none', 'append', 'prepend', 'scatter']
# Mitigation types: ['none', 'few_shot', 'system_prompt_hardening', 'user_prompt_hardening']
#
# Baseline (BASIC, none, none) metrics:
#   Overall MAE: 1.7711
#   Overall JER: 89.46%
#   MAE GT=0: 2.2946
#   JER GT=0: 98.55%
#   MAE GT>0: 0.9247
#   JER GT>0: 74.77%
#
# Best Overall MAE: 1.6189
#   Experiment: BASIC, none, few_shot
#
# Worst Overall MAE: 2.2931
#   Experiment: UTILITY, prepend, user_prompt_hardening
#
# Best Overall JER: 87.61%
#   Experiment: UTILITY, none, user_prompt_hardening
#
# Worst Overall JER: 90.30%
#   Experiment: RATIONALE, scatter, system_prompt_hardening

# %% [markdown]
# ## 8. Delta Analysis (Performance vs Baseline)

# %%
# Analyze deltas (excluding baseline itself)
non_baseline = df[
    (df["prompt_type"] != "BASIC")
    | (df["attack_type"] != "none")
    | (df["mitigation_type"] != "none")
]

print("Delta Analysis (Performance vs Baseline)")
print("=" * 40)
print(f"Experiments compared to baseline: {len(non_baseline)}")

# Count improvements vs degradations
mae_improvements = len(non_baseline[non_baseline["delta_overall_mae"] < 0])
mae_degradations = len(non_baseline[non_baseline["delta_overall_mae"] > 0])
jer_improvements = len(non_baseline[non_baseline["delta_overall_jer"] < 0])
jer_degradations = len(non_baseline[non_baseline["delta_overall_jer"] > 0])

print(f"\nMAE Improvements (negative delta): {mae_improvements}")
print(f"MAE Degradations (positive delta): {mae_degradations}")
print(f"JER Improvements (negative delta): {jer_improvements}")
print(f"JER Degradations (positive delta): {jer_degradations}")

# Best improvements
if not non_baseline.empty:
    best_mae_improvement = non_baseline[
        non_baseline["delta_overall_mae"] == non_baseline["delta_overall_mae"].min()
    ]
    best_jer_improvement = non_baseline[
        non_baseline["delta_overall_jer"] == non_baseline["delta_overall_jer"].min()
    ]

    print(
        f"\nBest MAE Improvement: {best_mae_improvement['delta_overall_mae'].iloc[0]:.4f}"
    )
    print(
        f"  Experiment: {best_mae_improvement['prompt_type'].iloc[0]}, {best_mae_improvement['attack_type'].iloc[0]}, {best_mae_improvement['mitigation_type'].iloc[0]}"
    )

    print(
        f"\nBest JER Improvement: {best_jer_improvement['delta_overall_jer'].iloc[0]:.2f}%"
    )
    print(
        f"  Experiment: {best_jer_improvement['prompt_type'].iloc[0]}, {best_jer_improvement['attack_type'].iloc[0]}, {best_jer_improvement['mitigation_type'].iloc[0]}"
    )
# Out:
# Delta Analysis (Performance vs Baseline)
# ========================================
# Experiments compared to baseline: 47
#
# MAE Improvements (negative delta): 5
# MAE Degradations (positive delta): 42
# JER Improvements (negative delta): 27
# JER Degradations (positive delta): 20
#
# Best MAE Improvement: -0.1523
#   Experiment: BASIC, none, few_shot
#
# Best JER Improvement: -1.85%
#   Experiment: UTILITY, none, user_prompt_hardening

# %%
# ==============================================================================
# LaTeX Table Generation for Thesis
# ==============================================================================

print("=" * 80)
print("LATEX TABLE OUTPUT FOR THESIS")
print("=" * 80)

# 1. Overall MAE Table
print("\n" + "=" * 80)
print("1. OVERALL MAE TABLE")
print("=" * 80 + "\n")
mae_latex = df[
    [
        "prompt_type",
        "attack_type",
        "mitigation_type",
        "overall_mae",
        "delta_overall_mae",
    ]
].copy()
mae_latex = mae_latex.sort_values(["prompt_type", "attack_type", "mitigation_type"])
mae_latex.columns = ["Prompt", "Attack", "Mitigation", "MAE", "$\\Delta$ MAE"]
latex_code = mae_latex.to_latex(
    index=False, float_format="%.4f", escape=False, column_format="lllrr", na_rep="--"
)
print(latex_code)

# 2. Overall JER Table
print("\n" + "=" * 80)
print("2. OVERALL JER TABLE")
print("=" * 80 + "\n")
jer_latex = df[
    [
        "prompt_type",
        "attack_type",
        "mitigation_type",
        "overall_jer",
        "delta_overall_jer",
    ]
].copy()
jer_latex = jer_latex.sort_values(["prompt_type", "attack_type", "mitigation_type"])
jer_latex.columns = [
    "Prompt",
    "Attack",
    "Mitigation",
    "JER (\\%)",
    "$\\Delta$ JER (\\%)",
]
latex_code = jer_latex.to_latex(
    index=False, float_format="%.2f", escape=False, column_format="lllrr", na_rep="--"
)
print(latex_code)

# 3. MAE for GT=0 Table
print("\n" + "=" * 80)
print("3. MAE FOR GROUND TRUTH = 0 (IRRELEVANT DOCUMENTS)")
print("=" * 80 + "\n")
mae_gt0_latex = df[
    [
        "prompt_type",
        "attack_type",
        "mitigation_type",
        "mae_gt_zero",
        "delta_mae_gt_zero",
    ]
].copy()
mae_gt0_latex = mae_gt0_latex.sort_values(
    ["prompt_type", "attack_type", "mitigation_type"]
)
mae_gt0_latex.columns = [
    "Prompt",
    "Attack",
    "Mitigation",
    "MAE (GT=0)",
    "$\\Delta$ MAE (GT=0)",
]
latex_code = mae_gt0_latex.to_latex(
    index=False, float_format="%.4f", escape=False, column_format="lllrr", na_rep="--"
)
print(latex_code)

# 4. JER for GT=0 Table
print("\n" + "=" * 80)
print("4. JER FOR GROUND TRUTH = 0 (IRRELEVANT DOCUMENTS)")
print("=" * 80 + "\n")
jer_gt0_latex = df[
    [
        "prompt_type",
        "attack_type",
        "mitigation_type",
        "jer_gt_zero",
        "delta_jer_gt_zero",
    ]
].copy()
jer_gt0_latex = jer_gt0_latex.sort_values(
    ["prompt_type", "attack_type", "mitigation_type"]
)
jer_gt0_latex.columns = [
    "Prompt",
    "Attack",
    "Mitigation",
    "JER (GT=0) (\\%)",
    "$\\Delta$ JER (GT=0) (\\%)",
]
latex_code = jer_gt0_latex.to_latex(
    index=False, float_format="%.2f", escape=False, column_format="lllrr", na_rep="--"
)
print(latex_code)

# 5. MAE for GT>0 Table
print("\n" + "=" * 80)
print("5. MAE FOR GROUND TRUTH > 0 (RELEVANT DOCUMENTS)")
print("=" * 80 + "\n")
mae_gtpos_latex = df[
    [
        "prompt_type",
        "attack_type",
        "mitigation_type",
        "mae_gt_positive",
        "delta_mae_gt_positive",
    ]
].copy()
mae_gtpos_latex = mae_gtpos_latex.sort_values(
    ["prompt_type", "attack_type", "mitigation_type"]
)
mae_gtpos_latex.columns = [
    "Prompt",
    "Attack",
    "Mitigation",
    "MAE (GT$>$0)",
    "$\\Delta$ MAE (GT$>$0)",
]
latex_code = mae_gtpos_latex.to_latex(
    index=False, float_format="%.4f", escape=False, column_format="lllrr", na_rep="--"
)
print(latex_code)

# 6. JER for GT>0 Table
print("\n" + "=" * 80)
print("6. JER FOR GROUND TRUTH > 0 (RELEVANT DOCUMENTS)")
print("=" * 80 + "\n")
jer_gtpos_latex = df[
    [
        "prompt_type",
        "attack_type",
        "mitigation_type",
        "jer_gt_positive",
        "delta_jer_gt_positive",
    ]
].copy()
jer_gtpos_latex = jer_gtpos_latex.sort_values(
    ["prompt_type", "attack_type", "mitigation_type"]
)
jer_gtpos_latex.columns = [
    "Prompt",
    "Attack",
    "Mitigation",
    "JER (GT$>$0) (\\%)",
    "$\\Delta$ JER (GT$>$0) (\\%)",
]
latex_code = jer_gtpos_latex.to_latex(
    index=False, float_format="%.2f", escape=False, column_format="lllrr", na_rep="--"
)
print(latex_code)

print("\n" + "=" * 80)
print("END OF LATEX TABLE OUTPUT")
print("=" * 80)
# Out:
# ================================================================================
# LATEX TABLE OUTPUT FOR THESIS
# ================================================================================
#
# ================================================================================
# 1. OVERALL MAE TABLE
# ================================================================================
#
# \begin{tabular}{lllrr}
# \toprule
# Prompt & Attack & Mitigation & MAE & $\Delta$ MAE \\
# \midrule
# BASIC & append & few_shot & 1.7977 & 0.0266 \\
# BASIC & append & none & 1.9412 & 0.1701 \\
# BASIC & append & system_prompt_hardening & 1.7928 & 0.0216 \\
# BASIC & append & user_prompt_hardening & 2.0705 & 0.2994 \\
# BASIC & none & few_shot & 1.6189 & -0.1523 \\
# BASIC & none & none & 1.7711 & -- \\
# BASIC & none & system_prompt_hardening & 1.6642 & -0.1070 \\
# BASIC & none & user_prompt_hardening & 1.9605 & 0.1894 \\
# BASIC & prepend & few_shot & 1.8096 & 0.0385 \\
# BASIC & prepend & none & 1.9543 & 0.1832 \\
# BASIC & prepend & system_prompt_hardening & 1.8871 & 0.1159 \\
# BASIC & prepend & user_prompt_hardening & 2.1644 & 0.3932 \\
# BASIC & scatter & few_shot & 1.7248 & -0.0463 \\
# BASIC & scatter & none & 1.8943 & 0.1232 \\
# BASIC & scatter & system_prompt_hardening & 1.7680 & -0.0031 \\
# BASIC & scatter & user_prompt_hardening & 2.1181 & 0.3470 \\
# RATIONALE & append & few_shot & 1.9721 & 0.2010 \\
# RATIONALE & append & none & 2.1795 & 0.4083 \\
# RATIONALE & append & system_prompt_hardening & 2.0376 & 0.2665 \\
# RATIONALE & append & user_prompt_hardening & 2.1562 & 0.3851 \\
# RATIONALE & none & few_shot & 1.7559 & -0.0152 \\
# RATIONALE & none & none & 2.1231 & 0.3519 \\
# RATIONALE & none & system_prompt_hardening & 1.8916 & 0.1205 \\
# RATIONALE & none & user_prompt_hardening & 2.0622 & 0.2911 \\
# RATIONALE & prepend & few_shot & 2.1162 & 0.3451 \\
# RATIONALE & prepend & none & 2.2572 & 0.4861 \\
# RATIONALE & prepend & system_prompt_hardening & 2.1742 & 0.4031 \\
# RATIONALE & prepend & user_prompt_hardening & 2.2686 & 0.4975 \\
# RATIONALE & scatter & few_shot & 1.8791 & 0.1080 \\
# RATIONALE & scatter & none & 2.1950 & 0.4239 \\
# RATIONALE & scatter & system_prompt_hardening & 2.0158 & 0.2447 \\
# RATIONALE & scatter & user_prompt_hardening & 2.1850 & 0.4139 \\
# UTILITY & append & few_shot & 1.9835 & 0.2124 \\
# UTILITY & append & none & 2.1966 & 0.4254 \\
# UTILITY & append & system_prompt_hardening & 2.0706 & 0.2995 \\
# UTILITY & append & user_prompt_hardening & 2.1973 & 0.4262 \\
# UTILITY & none & few_shot & 1.7868 & 0.0157 \\
# UTILITY & none & none & 2.1574 & 0.3863 \\
# UTILITY & none & system_prompt_hardening & 1.9635 & 0.1924 \\
# UTILITY & none & user_prompt_hardening & 2.1483 & 0.3772 \\
# UTILITY & prepend & few_shot & 2.1373 & 0.3662 \\
# UTILITY & prepend & none & 2.2574 & 0.4863 \\
# UTILITY & prepend & system_prompt_hardening & 2.2025 & 0.4314 \\
# UTILITY & prepend & user_prompt_hardening & 2.2931 & 0.5220 \\
# UTILITY & scatter & few_shot & 1.9603 & 0.1891 \\
# UTILITY & scatter & none & 2.2191 & 0.4479 \\
# UTILITY & scatter & system_prompt_hardening & 2.0903 & 0.3192 \\
# UTILITY & scatter & user_prompt_hardening & 2.2297 & 0.4586 \\
# \bottomrule
# \end{tabular}
#
#
# ================================================================================
# 2. OVERALL JER TABLE
# ================================================================================
#
# \begin{tabular}{lllrr}
# \toprule
# Prompt & Attack & Mitigation & JER (\%) & $\Delta$ JER (\%) \\
# \midrule
# BASIC & append & few_shot & 88.16 & -1.30 \\
# BASIC & append & none & 89.96 & 0.50 \\
# BASIC & append & system_prompt_hardening & 89.65 & 0.19 \\
# BASIC & append & user_prompt_hardening & 88.39 & -1.07 \\
# BASIC & none & few_shot & 87.88 & -1.58 \\
# BASIC & none & none & 89.46 & -- \\
# BASIC & none & system_prompt_hardening & 89.26 & -0.20 \\
# BASIC & none & user_prompt_hardening & 88.65 & -0.81 \\
# BASIC & prepend & few_shot & 89.65 & 0.19 \\
# BASIC & prepend & none & 89.75 & 0.28 \\
# BASIC & prepend & system_prompt_hardening & 89.83 & 0.37 \\
# BASIC & prepend & user_prompt_hardening & 89.69 & 0.23 \\
# BASIC & scatter & few_shot & 88.41 & -1.05 \\
# BASIC & scatter & none & 90.23 & 0.77 \\
# BASIC & scatter & system_prompt_hardening & 90.27 & 0.81 \\
# BASIC & scatter & user_prompt_hardening & 89.43 & -0.03 \\
# RATIONALE & append & few_shot & 89.09 & -0.37 \\
# RATIONALE & append & none & 89.59 & 0.13 \\
# RATIONALE & append & system_prompt_hardening & 89.72 & 0.26 \\
# RATIONALE & append & user_prompt_hardening & 88.46 & -1.00 \\
# RATIONALE & none & few_shot & 88.22 & -1.24 \\
# RATIONALE & none & none & 89.53 & 0.07 \\
# RATIONALE & none & system_prompt_hardening & 89.79 & 0.33 \\
# RATIONALE & none & user_prompt_hardening & 88.36 & -1.10 \\
# RATIONALE & prepend & few_shot & 89.50 & 0.04 \\
# RATIONALE & prepend & none & 89.89 & 0.43 \\
# RATIONALE & prepend & system_prompt_hardening & 89.60 & 0.14 \\
# RATIONALE & prepend & user_prompt_hardening & 89.73 & 0.27 \\
# RATIONALE & scatter & few_shot & 88.75 & -0.71 \\
# RATIONALE & scatter & none & 89.73 & 0.27 \\
# RATIONALE & scatter & system_prompt_hardening & 90.30 & 0.84 \\
# RATIONALE & scatter & user_prompt_hardening & 88.95 & -0.51 \\
# UTILITY & append & few_shot & 87.88 & -1.58 \\
# UTILITY & append & none & 89.29 & -0.17 \\
# UTILITY & append & system_prompt_hardening & 88.61 & -0.85 \\
# UTILITY & append & user_prompt_hardening & 87.77 & -1.69 \\
# UTILITY & none & few_shot & 87.65 & -1.81 \\
# UTILITY & none & none & 88.88 & -0.58 \\
# UTILITY & none & system_prompt_hardening & 88.81 & -0.66 \\
# UTILITY & none & user_prompt_hardening & 87.61 & -1.85 \\
# UTILITY & prepend & few_shot & 89.19 & -0.27 \\
# UTILITY & prepend & none & 89.70 & 0.24 \\
# UTILITY & prepend & system_prompt_hardening & 89.39 & -0.07 \\
# UTILITY & prepend & user_prompt_hardening & 89.82 & 0.36 \\
# UTILITY & scatter & few_shot & 88.24 & -1.22 \\
# UTILITY & scatter & none & 89.39 & -0.07 \\
# UTILITY & scatter & system_prompt_hardening & 89.42 & -0.04 \\
# UTILITY & scatter & user_prompt_hardening & 88.56 & -0.90 \\
# \bottomrule
# \end{tabular}
#
#
# ================================================================================
# 3. MAE FOR GROUND TRUTH = 0 (IRRELEVANT DOCUMENTS)
# ================================================================================
#
# \begin{tabular}{lllrr}
# \toprule
# Prompt & Attack & Mitigation & MAE (GT=0) & $\Delta$ MAE (GT=0) \\
# \midrule
# BASIC & append & few_shot & 2.2985 & 0.0039 \\
# BASIC & append & none & 2.5007 & 0.2061 \\
# BASIC & append & system_prompt_hardening & 2.3080 & 0.0134 \\
# BASIC & append & user_prompt_hardening & 2.6579 & 0.3633 \\
# BASIC & none & few_shot & 2.0920 & -0.2026 \\
# BASIC & none & none & 2.2946 & -- \\
# BASIC & none & system_prompt_hardening & 2.1515 & -0.1432 \\
# BASIC & none & user_prompt_hardening & 2.5166 & 0.2220 \\
# BASIC & prepend & few_shot & 2.3686 & 0.0740 \\
# BASIC & prepend & none & 2.5461 & 0.2515 \\
# BASIC & prepend & system_prompt_hardening & 2.4569 & 0.1623 \\
# BASIC & prepend & user_prompt_hardening & 2.7882 & 0.4935 \\
# BASIC & scatter & few_shot & 2.2254 & -0.0692 \\
# BASIC & scatter & none & 2.4394 & 0.1448 \\
# BASIC & scatter & system_prompt_hardening & 2.2822 & -0.0124 \\
# BASIC & scatter & user_prompt_hardening & 2.7181 & 0.4235 \\
# RATIONALE & append & few_shot & 2.5182 & 0.2236 \\
# RATIONALE & append & none & 2.8020 & 0.5074 \\
# RATIONALE & append & system_prompt_hardening & 2.6155 & 0.3209 \\
# RATIONALE & append & user_prompt_hardening & 2.7614 & 0.4668 \\
# RATIONALE & none & few_shot & 2.2437 & -0.0509 \\
# RATIONALE & none & none & 2.7225 & 0.4278 \\
# RATIONALE & none & system_prompt_hardening & 2.4327 & 0.1381 \\
# RATIONALE & none & user_prompt_hardening & 2.6413 & 0.3467 \\
# RATIONALE & prepend & few_shot & 2.7261 & 0.4315 \\
# RATIONALE & prepend & none & 2.9011 & 0.6065 \\
# RATIONALE & prepend & system_prompt_hardening & 2.8057 & 0.5111 \\
# RATIONALE & prepend & user_prompt_hardening & 2.9110 & 0.6164 \\
# RATIONALE & scatter & few_shot & 2.3912 & 0.0966 \\
# RATIONALE & scatter & none & 2.8183 & 0.5237 \\
# RATIONALE & scatter & system_prompt_hardening & 2.5807 & 0.2861 \\
# RATIONALE & scatter & user_prompt_hardening & 2.8022 & 0.5076 \\
# UTILITY & append & few_shot & 2.5106 & 0.2160 \\
# UTILITY & append & none & 2.8209 & 0.5263 \\
# UTILITY & append & system_prompt_hardening & 2.6413 & 0.3467 \\
# UTILITY & append & user_prompt_hardening & 2.8061 & 0.5115 \\
# UTILITY & none & few_shot & 2.2716 & -0.0231 \\
# UTILITY & none & none & 2.7642 & 0.4696 \\
# UTILITY & none & system_prompt_hardening & 2.5101 & 0.2155 \\
# UTILITY & none & user_prompt_hardening & 2.7497 & 0.4550 \\
# UTILITY & prepend & few_shot & 2.7575 & 0.4629 \\
# UTILITY & prepend & none & 2.9059 & 0.6113 \\
# UTILITY & prepend & system_prompt_hardening & 2.8396 & 0.5450 \\
# UTILITY & prepend & user_prompt_hardening & 2.9373 & 0.6427 \\
# UTILITY & scatter & few_shot & 2.4894 & 0.1948 \\
# UTILITY & scatter & none & 2.8479 & 0.5533 \\
# UTILITY & scatter & system_prompt_hardening & 2.6759 & 0.3813 \\
# UTILITY & scatter & user_prompt_hardening & 2.8571 & 0.5625 \\
# \bottomrule
# \end{tabular}
#
#
# ================================================================================
# 4. JER FOR GROUND TRUTH = 0 (IRRELEVANT DOCUMENTS)
# ================================================================================
#
# \begin{tabular}{lllrr}
# \toprule
# Prompt & Attack & Mitigation & JER (GT=0) (\%) & $\Delta$ JER (GT=0) (\%) \\
# \midrule
# BASIC & append & few_shot & 95.50 & -3.04 \\
# BASIC & append & none & 99.08 & 0.53 \\
# BASIC & append & system_prompt_hardening & 97.65 & -0.90 \\
# BASIC & append & user_prompt_hardening & 97.26 & -1.29 \\
# BASIC & none & few_shot & 95.27 & -3.27 \\
# BASIC & none & none & 98.55 & -- \\
# BASIC & none & system_prompt_hardening & 97.21 & -1.34 \\
# BASIC & none & user_prompt_hardening & 97.42 & -1.13 \\
# BASIC & prepend & few_shot & 99.26 & 0.71 \\
# BASIC & prepend & none & 99.82 & 1.27 \\
# BASIC & prepend & system_prompt_hardening & 99.54 & 0.99 \\
# BASIC & prepend & user_prompt_hardening & 99.47 & 0.92 \\
# BASIC & scatter & few_shot & 96.08 & -2.47 \\
# BASIC & scatter & none & 98.96 & 0.41 \\
# BASIC & scatter & system_prompt_hardening & 98.13 & -0.41 \\
# BASIC & scatter & user_prompt_hardening & 98.46 & -0.09 \\
# RATIONALE & append & few_shot & 97.53 & -1.01 \\
# RATIONALE & append & none & 99.52 & 0.97 \\
# RATIONALE & append & system_prompt_hardening & 99.08 & 0.53 \\
# RATIONALE & append & user_prompt_hardening & 97.88 & -0.67 \\
# RATIONALE & none & few_shot & 96.10 & -2.44 \\
# RATIONALE & none & none & 99.29 & 0.74 \\
# RATIONALE & none & system_prompt_hardening & 99.17 & 0.62 \\
# RATIONALE & none & user_prompt_hardening & 97.44 & -1.11 \\
# RATIONALE & prepend & few_shot & 99.54 & 0.99 \\
# RATIONALE & prepend & none & 100.00 & 1.45 \\
# RATIONALE & prepend & system_prompt_hardening & 99.98 & 1.43 \\
# RATIONALE & prepend & user_prompt_hardening & 99.65 & 1.11 \\
# RATIONALE & scatter & few_shot & 96.47 & -2.07 \\
# RATIONALE & scatter & none & 99.45 & 0.90 \\
# RATIONALE & scatter & system_prompt_hardening & 99.38 & 0.83 \\
# RATIONALE & scatter & user_prompt_hardening & 98.18 & -0.37 \\
# UTILITY & append & few_shot & 95.07 & -3.48 \\
# UTILITY & append & none & 98.82 & 0.28 \\
# UTILITY & append & system_prompt_hardening & 97.26 & -1.29 \\
# UTILITY & append & user_prompt_hardening & 96.45 & -2.10 \\
# UTILITY & none & few_shot & 94.58 & -3.96 \\
# UTILITY & none & none & 98.27 & -0.28 \\
# UTILITY & none & system_prompt_hardening & 97.05 & -1.50 \\
# UTILITY & none & user_prompt_hardening & 96.47 & -2.07 \\
# UTILITY & prepend & few_shot & 99.10 & 0.55 \\
# UTILITY & prepend & none & 99.84 & 1.29 \\
# UTILITY & prepend & system_prompt_hardening & 99.59 & 1.04 \\
# UTILITY & prepend & user_prompt_hardening & 99.35 & 0.81 \\
# UTILITY & scatter & few_shot & 95.46 & -3.09 \\
# UTILITY & scatter & none & 98.96 & 0.41 \\
# UTILITY & scatter & system_prompt_hardening & 98.25 & -0.30 \\
# UTILITY & scatter & user_prompt_hardening & 97.63 & -0.92 \\
# \bottomrule
# \end{tabular}
#
#
# ================================================================================
# 5. MAE FOR GROUND TRUTH > 0 (RELEVANT DOCUMENTS)
# ================================================================================
#
# \begin{tabular}{lllrr}
# \toprule
# Prompt & Attack & Mitigation & MAE (GT$>$0) & $\Delta$ MAE (GT$>$0) \\
# \midrule
# BASIC & append & few_shot & 0.9881 & 0.0634 \\
# BASIC & append & none & 1.0365 & 0.1118 \\
# BASIC & append & system_prompt_hardening & 0.9597 & 0.0350 \\
# BASIC & append & user_prompt_hardening & 1.1208 & 0.1960 \\
# BASIC & none & few_shot & 0.8539 & -0.0708 \\
# BASIC & none & none & 0.9247 & -- \\
# BASIC & none & system_prompt_hardening & 0.8763 & -0.0485 \\
# BASIC & none & user_prompt_hardening & 1.0615 & 0.1368 \\
# BASIC & prepend & few_shot & 0.9057 & -0.0190 \\
# BASIC & prepend & none & 0.9974 & 0.0727 \\
# BASIC & prepend & system_prompt_hardening & 0.9657 & 0.0410 \\
# BASIC & prepend & user_prompt_hardening & 1.1558 & 0.2311 \\
# BASIC & scatter & few_shot & 0.9154 & -0.0093 \\
# BASIC & scatter & none & 1.0130 & 0.0883 \\
# BASIC & scatter & system_prompt_hardening & 0.9366 & 0.0119 \\
# BASIC & scatter & user_prompt_hardening & 1.1480 & 0.2233 \\
# RATIONALE & append & few_shot & 1.0891 & 0.1644 \\
# RATIONALE & append & none & 1.1729 & 0.2482 \\
# RATIONALE & append & system_prompt_hardening & 1.1032 & 0.1785 \\
# RATIONALE & append & user_prompt_hardening & 1.1778 & 0.2531 \\
# RATIONALE & none & few_shot & 0.9672 & 0.0425 \\
# RATIONALE & none & none & 1.1539 & 0.2292 \\
# RATIONALE & none & system_prompt_hardening & 1.0168 & 0.0921 \\
# RATIONALE & none & user_prompt_hardening & 1.1260 & 0.2013 \\
# RATIONALE & prepend & few_shot & 1.1301 & 0.2054 \\
# RATIONALE & prepend & none & 1.2162 & 0.2915 \\
# RATIONALE & prepend & system_prompt_hardening & 1.1532 & 0.2285 \\
# RATIONALE & prepend & user_prompt_hardening & 1.2300 & 0.3053 \\
# RATIONALE & scatter & few_shot & 1.0511 & 0.1264 \\
# RATIONALE & scatter & none & 1.1871 & 0.2624 \\
# RATIONALE & scatter & system_prompt_hardening & 1.1025 & 0.1778 \\
# RATIONALE & scatter & user_prompt_hardening & 1.1871 & 0.2624 \\
# UTILITY & append & few_shot & 1.1312 & 0.2065 \\
# UTILITY & append & none & 1.1871 & 0.2624 \\
# UTILITY & append & system_prompt_hardening & 1.1480 & 0.2233 \\
# UTILITY & append & user_prompt_hardening & 1.2128 & 0.2881 \\
# UTILITY & none & few_shot & 1.0030 & 0.0783 \\
# UTILITY & none & none & 1.1763 & 0.2516 \\
# UTILITY & none & system_prompt_hardening & 1.0798 & 0.1551 \\
# UTILITY & none & user_prompt_hardening & 1.1759 & 0.2512 \\
# UTILITY & prepend & few_shot & 1.1346 & 0.2098 \\
# UTILITY & prepend & none & 1.2087 & 0.2840 \\
# UTILITY & prepend & system_prompt_hardening & 1.1726 & 0.2479 \\
# UTILITY & prepend & user_prompt_hardening & 1.2516 & 0.3269 \\
# UTILITY & scatter & few_shot & 1.1047 & 0.1800 \\
# UTILITY & scatter & none & 1.2024 & 0.2777 \\
# UTILITY & scatter & system_prompt_hardening & 1.1435 & 0.2188 \\
# UTILITY & scatter & user_prompt_hardening & 1.2154 & 0.2907 \\
# \bottomrule
# \end{tabular}
#
#
# ================================================================================
# 6. JER FOR GROUND TRUTH > 0 (RELEVANT DOCUMENTS)
# ================================================================================
#
# \begin{tabular}{lllrr}
# \toprule
# Prompt & Attack & Mitigation & JER (GT$>$0) (\%) & $\Delta$ JER (GT$>$0) (\%) \\
# \midrule
# BASIC & append & few_shot & 76.30 & 1.53 \\
# BASIC & append & none & 75.21 & 0.45 \\
# BASIC & append & system_prompt_hardening & 76.71 & 1.94 \\
# BASIC & append & user_prompt_hardening & 74.06 & -0.71 \\
# BASIC & none & few_shot & 75.92 & 1.16 \\
# BASIC & none & none & 74.77 & -- \\
# BASIC & none & system_prompt_hardening & 76.41 & 1.64 \\
# BASIC & none & user_prompt_hardening & 74.47 & -0.30 \\
# BASIC & prepend & few_shot & 74.10 & -0.67 \\
# BASIC & prepend & none & 73.46 & -1.30 \\
# BASIC & prepend & system_prompt_hardening & 74.13 & -0.63 \\
# BASIC & prepend & user_prompt_hardening & 73.87 & -0.89 \\
# BASIC & scatter & few_shot & 76.00 & 1.23 \\
# BASIC & scatter & none & 76.11 & 1.34 \\
# BASIC & scatter & system_prompt_hardening & 77.56 & 2.80 \\
# BASIC & scatter & user_prompt_hardening & 74.84 & 0.07 \\
# RATIONALE & append & few_shot & 75.44 & 0.67 \\
# RATIONALE & append & none & 73.54 & -1.23 \\
# RATIONALE & append & system_prompt_hardening & 74.58 & -0.19 \\
# RATIONALE & append & user_prompt_hardening & 73.24 & -1.53 \\
# RATIONALE & none & few_shot & 75.48 & 0.71 \\
# RATIONALE & none & none & 73.76 & -1.01 \\
# RATIONALE & none & system_prompt_hardening & 74.62 & -0.15 \\
# RATIONALE & none & user_prompt_hardening & 73.69 & -1.08 \\
# RATIONALE & prepend & few_shot & 73.28 & -1.49 \\
# RATIONALE & prepend & none & 73.54 & -1.23 \\
# RATIONALE & prepend & system_prompt_hardening & 72.83 & -1.94 \\
# RATIONALE & prepend & user_prompt_hardening & 73.69 & -1.08 \\
# RATIONALE & scatter & few_shot & 76.26 & 1.49 \\
# RATIONALE & scatter & none & 74.02 & -0.75 \\
# RATIONALE & scatter & system_prompt_hardening & 75.62 & 0.86 \\
# RATIONALE & scatter & user_prompt_hardening & 74.02 & -0.75 \\
# UTILITY & append & few_shot & 76.26 & 1.49 \\
# UTILITY & append & none & 73.87 & -0.89 \\
# UTILITY & append & system_prompt_hardening & 74.62 & -0.15 \\
# UTILITY & append & user_prompt_hardening & 73.72 & -1.04 \\
# UTILITY & none & few_shot & 76.44 & 1.68 \\
# UTILITY & none & none & 73.69 & -1.08 \\
# UTILITY & none & system_prompt_hardening & 75.48 & 0.71 \\
# UTILITY & none & user_prompt_hardening & 73.28 & -1.49 \\
# UTILITY & prepend & few_shot & 73.16 & -1.60 \\
# UTILITY & prepend & none & 73.31 & -1.45 \\
# UTILITY & prepend & system_prompt_hardening & 72.90 & -1.86 \\
# UTILITY & prepend & user_prompt_hardening & 74.39 & -0.37 \\
# UTILITY & scatter & few_shot & 76.56 & 1.79 \\
# UTILITY & scatter & none & 73.91 & -0.86 \\
# UTILITY & scatter & system_prompt_hardening & 75.14 & 0.37 \\
# UTILITY & scatter & user_prompt_hardening & 73.91 & -0.86 \\
# \bottomrule
# \end{tabular}
#
#
# ================================================================================
# END OF LATEX TABLE OUTPUT
# ================================================================================

# %%
# Enhanced LaTeX tables with Best Improvement rows appended at bottom
import pandas as pd

# Ensure delta columns are numeric for min() computations
cols_mae = ["delta_overall_mae", "delta_mae_gt_zero", "delta_mae_gt_positive"]
cols_jer = ["delta_overall_jer", "delta_jer_gt_zero", "delta_jer_gt_positive"]
for c in cols_mae + cols_jer:
    if c in df.columns:
        df[c] = pd.to_numeric(df[c], errors="coerce")


def append_best_footer(
    latex_code: str, label: str, value: float, value_format: str
) -> str:
    """Insert a bold footer row with the best improvement value before \\bottomrule."""
    if pd.isna(value):
        return latex_code
    formatted = value_format % value
    footer = f"\\midrule\n\\textbf{{{label}}} &  &  &  & {formatted} \\\n\\bottomrule"
    return latex_code.replace("\\bottomrule", footer)


print("=" * 80)
print("LATEX TABLES WITH BEST IMPROVEMENT ROWS")
print("=" * 80)

# 1) Overall MAE
mae_latex = df[
    [
        "prompt_type",
        "attack_type",
        "mitigation_type",
        "overall_mae",
        "delta_overall_mae",
    ]
].copy()
mae_latex = mae_latex.sort_values(["prompt_type", "attack_type", "mitigation_type"])
mae_latex.columns = ["Prompt", "Attack", "Mitigation", "MAE", "$\\Delta$ MAE"]
latex_code = mae_latex.to_latex(
    index=False, float_format="%.4f", escape=False, column_format="lllrr", na_rep="--"
)
best_mae_impr = df["delta_overall_mae"].min()
latex_code = append_best_footer(
    latex_code, "Best MAE Improvement", best_mae_impr, "%+.4f"
)
print("\n" + "=" * 80)
print("1. OVERALL MAE TABLE (with Best Improvement)")
print("=" * 80 + "\n")
print(latex_code)

# 2) Overall JER
jer_latex = df[
    [
        "prompt_type",
        "attack_type",
        "mitigation_type",
        "overall_jer",
        "delta_overall_jer",
    ]
].copy()
jer_latex = jer_latex.sort_values(["prompt_type", "attack_type", "mitigation_type"])
jer_latex.columns = [
    "Prompt",
    "Attack",
    "Mitigation",
    "JER (\\%)",
    "$\\Delta$ JER (\\%)",
]
latex_code = jer_latex.to_latex(
    index=False, float_format="%.2f", escape=False, column_format="lllrr", na_rep="--"
)
best_jer_impr = df["delta_overall_jer"].min()
latex_code = append_best_footer(
    latex_code, "Best JER Improvement", best_jer_impr, "%+.2f"
)
print("\n" + "=" * 80)
print("2. OVERALL JER TABLE (with Best Improvement)")
print("=" * 80 + "\n")
print(latex_code)

# 3) MAE (GT=0)
mae0 = df[
    [
        "prompt_type",
        "attack_type",
        "mitigation_type",
        "mae_gt_zero",
        "delta_mae_gt_zero",
    ]
].copy()
mae0 = mae0.sort_values(["prompt_type", "attack_type", "mitigation_type"])
mae0.columns = ["Prompt", "Attack", "Mitigation", "MAE (GT=0)", "$\\Delta$ MAE (GT=0)"]
latex_code = mae0.to_latex(
    index=False, float_format="%.4f", escape=False, column_format="lllrr", na_rep="--"
)
best_mae0_impr = df["delta_mae_gt_zero"].min()
latex_code = append_best_footer(
    latex_code, "Best MAE Improvement (GT=0)", best_mae0_impr, "%+.4f"
)
print("\n" + "=" * 80)
print("3. MAE (GT=0) TABLE (with Best Improvement)")
print("=" * 80 + "\n")
print(latex_code)

# 4) JER (GT=0)
jer0 = df[
    [
        "prompt_type",
        "attack_type",
        "mitigation_type",
        "jer_gt_zero",
        "delta_jer_gt_zero",
    ]
].copy()
jer0 = jer0.sort_values(["prompt_type", "attack_type", "mitigation_type"])
jer0.columns = [
    "Prompt",
    "Attack",
    "Mitigation",
    "JER (GT=0) (\\%)",
    "$\\Delta$ JER (GT=0) (\\%)",
]
latex_code = jer0.to_latex(
    index=False, float_format="%.2f", escape=False, column_format="lllrr", na_rep="--"
)
best_jer0_impr = df["delta_jer_gt_zero"].min()
latex_code = append_best_footer(
    latex_code, "Best JER Improvement (GT=0)", best_jer0_impr, "%+.2f"
)
print("\n" + "=" * 80)
print("4. JER (GT=0) TABLE (with Best Improvement)")
print("=" * 80 + "\n")
print(latex_code)

# 5) MAE (GT>0)
maep = df[
    [
        "prompt_type",
        "attack_type",
        "mitigation_type",
        "mae_gt_positive",
        "delta_mae_gt_positive",
    ]
].copy()
maep = maep.sort_values(["prompt_type", "attack_type", "mitigation_type"])
maep.columns = [
    "Prompt",
    "Attack",
    "Mitigation",
    "MAE (GT$>$0)",
    "$\\Delta$ MAE (GT$>$0)",
]
latex_code = maep.to_latex(
    index=False, float_format="%.4f", escape=False, column_format="lllrr", na_rep="--"
)
best_maep_impr = df["delta_mae_gt_positive"].min()
latex_code = append_best_footer(
    latex_code, "Best MAE Improvement (GT>0)", best_maep_impr, "%+.4f"
)
print("\n" + "=" * 80)
print("5. MAE (GT>0) TABLE (with Best Improvement)")
print("=" * 80 + "\n")
print(latex_code)

# 6) JER (GT>0)
jerp = df[
    [
        "prompt_type",
        "attack_type",
        "mitigation_type",
        "jer_gt_positive",
        "delta_jer_gt_positive",
    ]
].copy()
jerp = jerp.sort_values(["prompt_type", "attack_type", "mitigation_type"])
jerp.columns = [
    "Prompt",
    "Attack",
    "Mitigation",
    "JER (GT$>$0) (\\%)",
    "$\\Delta$ JER (GT$>$0) (\\%)",
]
latex_code = jerp.to_latex(
    index=False, float_format="%.2f", escape=False, column_format="lllrr", na_rep="--"
)
best_jerp_impr = df["delta_jer_gt_positive"].min()
latex_code = append_best_footer(
    latex_code, "Best JER Improvement (GT>0)", best_jerp_impr, "%+.2f"
)
print("\n" + "=" * 80)
print("6. JER (GT>0) TABLE (with Best Improvement)")
print("=" * 80 + "\n")
print(latex_code)

# =============================
# Summary table for all 6 metrics
# =============================
# Define baseline mask and non-baseline for improvements
is_baseline = (
    (df["prompt_type"] == "BASIC")
    & (df["attack_type"] == "none")
    & (df["mitigation_type"] == "none")
)
non_baseline = df[~is_baseline].copy()

# Ensure numeric types
for c in [
    "overall_mae",
    "overall_jer",
    "mae_gt_zero",
    "mae_gt_positive",
    "jer_gt_zero",
    "jer_gt_positive",
    "delta_overall_mae",
    "delta_overall_jer",
    "delta_mae_gt_zero",
    "delta_mae_gt_positive",
    "delta_jer_gt_zero",
    "delta_jer_gt_positive",
]:
    if c in df.columns:
        df[c] = pd.to_numeric(df[c], errors="coerce")
        non_baseline[c] = pd.to_numeric(non_baseline[c], errors="coerce")

# Compute best improvements (exclude baseline) and best overall (all)
rows = []
# Overall MAE
imp_row = non_baseline.loc[non_baseline["delta_overall_mae"].idxmin()]
best_row = df.loc[df["overall_mae"].idxmin()]
rows.append(
    {
        "Metric": "Overall MAE",
        "Best Improvement": f"{imp_row['delta_overall_mae']:.4f}",
        "Imp Prompt": imp_row["prompt_type"],
        "Imp Attack": imp_row["attack_type"],
        "Imp Mitigation": imp_row["mitigation_type"],
        "Best Overall": f"{best_row['overall_mae']:.4f}",
        "Best Prompt": best_row["prompt_type"],
        "Best Attack": best_row["attack_type"],
        "Best Mitigation": best_row["mitigation_type"],
    }
)
# Overall JER
imp_row = non_baseline.loc[non_baseline["delta_overall_jer"].idxmin()]
best_row = df.loc[df["overall_jer"].idxmin()]
rows.append(
    {
        "Metric": "Overall JER",
        "Best Improvement": f"{imp_row['delta_overall_jer']:.2f}%",
        "Imp Prompt": imp_row["prompt_type"],
        "Imp Attack": imp_row["attack_type"],
        "Imp Mitigation": imp_row["mitigation_type"],
        "Best Overall": f"{best_row['overall_jer']:.2f}%",
        "Best Prompt": best_row["prompt_type"],
        "Best Attack": best_row["attack_type"],
        "Best Mitigation": best_row["mitigation_type"],
    }
)
# MAE (GT=0)
imp_row = non_baseline.loc[non_baseline["delta_mae_gt_zero"].idxmin()]
best_row = df.loc[df["mae_gt_zero"].idxmin()]
rows.append(
    {
        "Metric": "MAE (GT=0)",
        "Best Improvement": f"{imp_row['delta_mae_gt_zero']:.4f}",
        "Imp Prompt": imp_row["prompt_type"],
        "Imp Attack": imp_row["attack_type"],
        "Imp Mitigation": imp_row["mitigation_type"],
        "Best Overall": f"{best_row['mae_gt_zero']:.4f}",
        "Best Prompt": best_row["prompt_type"],
        "Best Attack": best_row["attack_type"],
        "Best Mitigation": best_row["mitigation_type"],
    }
)
# JER (GT=0)
imp_row = non_baseline.loc[non_baseline["delta_jer_gt_zero"].idxmin()]
best_row = df.loc[df["jer_gt_zero"].idxmin()]
rows.append(
    {
        "Metric": "JER (GT=0)",
        "Best Improvement": f"{imp_row['delta_jer_gt_zero']:.2f}%",
        "Imp Prompt": imp_row["prompt_type"],
        "Imp Attack": imp_row["attack_type"],
        "Imp Mitigation": imp_row["mitigation_type"],
        "Best Overall": f"{best_row['jer_gt_zero']:.2f}%",
        "Best Prompt": best_row["prompt_type"],
        "Best Attack": best_row["attack_type"],
        "Best Mitigation": best_row["mitigation_type"],
    }
)
# MAE (GT>0)
imp_row = non_baseline.loc[non_baseline["delta_mae_gt_positive"].idxmin()]
best_row = df.loc[df["mae_gt_positive"].idxmin()]
rows.append(
    {
        "Metric": "MAE (GT>0)",
        "Best Improvement": f"{imp_row['delta_mae_gt_positive']:.4f}",
        "Imp Prompt": imp_row["prompt_type"],
        "Imp Attack": imp_row["attack_type"],
        "Imp Mitigation": imp_row["mitigation_type"],
        "Best Overall": f"{best_row['mae_gt_positive']:.4f}",
        "Best Prompt": best_row["prompt_type"],
        "Best Attack": best_row["attack_type"],
        "Best Mitigation": best_row["mitigation_type"],
    }
)
# JER (GT>0)
imp_row = non_baseline.loc[non_baseline["delta_jer_gt_positive"].idxmin()]
best_row = df.loc[df["jer_gt_positive"].idxmin()]
rows.append(
    {
        "Metric": "JER (GT>0)",
        "Best Improvement": f"{imp_row['delta_jer_gt_positive']:.2f}%",
        "Imp Prompt": imp_row["prompt_type"],
        "Imp Attack": imp_row["attack_type"],
        "Imp Mitigation": imp_row["mitigation_type"],
        "Best Overall": f"{best_row['jer_gt_positive']:.2f}%",
        "Best Prompt": best_row["prompt_type"],
        "Best Attack": best_row["attack_type"],
        "Best Mitigation": best_row["mitigation_type"],
    }
)

summary_df = pd.DataFrame(
    rows,
    columns=[
        "Metric",
        "Best Improvement",
        "Imp Prompt",
        "Imp Attack",
        "Imp Mitigation",
        "Best Overall",
        "Best Prompt",
        "Best Attack",
        "Best Mitigation",
    ],
)

print("\n" + "=" * 80)
print("SUMMARY OF BESTS (All Tables)")
print("=" * 80)
print(summary_df.to_string(index=False))

print("\n" + "=" * 80)
print("LATEX SUMMARY TABLE (All Tables)")
print("=" * 80)
print(summary_df.to_latex(index=False, escape=False, column_format="lrrrrrrrrr"))
# Out:
# ================================================================================
# LATEX TABLES WITH BEST IMPROVEMENT ROWS
# ================================================================================
#
# ================================================================================
# 1. OVERALL MAE TABLE (with Best Improvement)
# ================================================================================
#
# \begin{tabular}{lllrr}
# \toprule
# Prompt & Attack & Mitigation & MAE & $\Delta$ MAE \\
# \midrule
# BASIC & append & few_shot & 1.7977 & 0.0266 \\
# BASIC & append & none & 1.9412 & 0.1701 \\
# BASIC & append & system_prompt_hardening & 1.7928 & 0.0216 \\
# BASIC & append & user_prompt_hardening & 2.0705 & 0.2994 \\
# BASIC & none & few_shot & 1.6189 & -0.1523 \\
# BASIC & none & none & 1.7711 & -- \\
# BASIC & none & system_prompt_hardening & 1.6642 & -0.1070 \\
# BASIC & none & user_prompt_hardening & 1.9605 & 0.1894 \\
# BASIC & prepend & few_shot & 1.8096 & 0.0385 \\
# BASIC & prepend & none & 1.9543 & 0.1832 \\
# BASIC & prepend & system_prompt_hardening & 1.8871 & 0.1159 \\
# BASIC & prepend & user_prompt_hardening & 2.1644 & 0.3932 \\
# BASIC & scatter & few_shot & 1.7248 & -0.0463 \\
# BASIC & scatter & none & 1.8943 & 0.1232 \\
# BASIC & scatter & system_prompt_hardening & 1.7680 & -0.0031 \\
# BASIC & scatter & user_prompt_hardening & 2.1181 & 0.3470 \\
# RATIONALE & append & few_shot & 1.9721 & 0.2010 \\
# RATIONALE & append & none & 2.1795 & 0.4083 \\
# RATIONALE & append & system_prompt_hardening & 2.0376 & 0.2665 \\
# RATIONALE & append & user_prompt_hardening & 2.1562 & 0.3851 \\
# RATIONALE & none & few_shot & 1.7559 & -0.0152 \\
# RATIONALE & none & none & 2.1231 & 0.3519 \\
# RATIONALE & none & system_prompt_hardening & 1.8916 & 0.1205 \\
# RATIONALE & none & user_prompt_hardening & 2.0622 & 0.2911 \\
# RATIONALE & prepend & few_shot & 2.1162 & 0.3451 \\
# RATIONALE & prepend & none & 2.2572 & 0.4861 \\
# RATIONALE & prepend & system_prompt_hardening & 2.1742 & 0.4031 \\
# RATIONALE & prepend & user_prompt_hardening & 2.2686 & 0.4975 \\
# RATIONALE & scatter & few_shot & 1.8791 & 0.1080 \\
# RATIONALE & scatter & none & 2.1950 & 0.4239 \\
# RATIONALE & scatter & system_prompt_hardening & 2.0158 & 0.2447 \\
# RATIONALE & scatter & user_prompt_hardening & 2.1850 & 0.4139 \\
# UTILITY & append & few_shot & 1.9835 & 0.2124 \\
# UTILITY & append & none & 2.1966 & 0.4254 \\
# UTILITY & append & system_prompt_hardening & 2.0706 & 0.2995 \\
# UTILITY & append & user_prompt_hardening & 2.1973 & 0.4262 \\
# UTILITY & none & few_shot & 1.7868 & 0.0157 \\
# UTILITY & none & none & 2.1574 & 0.3863 \\
# UTILITY & none & system_prompt_hardening & 1.9635 & 0.1924 \\
# UTILITY & none & user_prompt_hardening & 2.1483 & 0.3772 \\
# UTILITY & prepend & few_shot & 2.1373 & 0.3662 \\
# UTILITY & prepend & none & 2.2574 & 0.4863 \\
# UTILITY & prepend & system_prompt_hardening & 2.2025 & 0.4314 \\
# UTILITY & prepend & user_prompt_hardening & 2.2931 & 0.5220 \\
# UTILITY & scatter & few_shot & 1.9603 & 0.1891 \\
# UTILITY & scatter & none & 2.2191 & 0.4479 \\
# UTILITY & scatter & system_prompt_hardening & 2.0903 & 0.3192 \\
# UTILITY & scatter & user_prompt_hardening & 2.2297 & 0.4586 \\
# \midrule
# \textbf{Best MAE Improvement} &  &  &  & -0.1523 \
# \bottomrule
# \end{tabular}
#
#
# ================================================================================
# 2. OVERALL JER TABLE (with Best Improvement)
# ================================================================================
#
# \begin{tabular}{lllrr}
# \toprule
# Prompt & Attack & Mitigation & JER (\%) & $\Delta$ JER (\%) \\
# \midrule
# BASIC & append & few_shot & 88.16 & -1.30 \\
# BASIC & append & none & 89.96 & 0.50 \\
# BASIC & append & system_prompt_hardening & 89.65 & 0.19 \\
# BASIC & append & user_prompt_hardening & 88.39 & -1.07 \\
# BASIC & none & few_shot & 87.88 & -1.58 \\
# BASIC & none & none & 89.46 & -- \\
# BASIC & none & system_prompt_hardening & 89.26 & -0.20 \\
# BASIC & none & user_prompt_hardening & 88.65 & -0.81 \\
# BASIC & prepend & few_shot & 89.65 & 0.19 \\
# BASIC & prepend & none & 89.75 & 0.28 \\
# BASIC & prepend & system_prompt_hardening & 89.83 & 0.37 \\
# BASIC & prepend & user_prompt_hardening & 89.69 & 0.23 \\
# BASIC & scatter & few_shot & 88.41 & -1.05 \\
# BASIC & scatter & none & 90.23 & 0.77 \\
# BASIC & scatter & system_prompt_hardening & 90.27 & 0.81 \\
# BASIC & scatter & user_prompt_hardening & 89.43 & -0.03 \\
# RATIONALE & append & few_shot & 89.09 & -0.37 \\
# RATIONALE & append & none & 89.59 & 0.13 \\
# RATIONALE & append & system_prompt_hardening & 89.72 & 0.26 \\
# RATIONALE & append & user_prompt_hardening & 88.46 & -1.00 \\
# RATIONALE & none & few_shot & 88.22 & -1.24 \\
# RATIONALE & none & none & 89.53 & 0.07 \\
# RATIONALE & none & system_prompt_hardening & 89.79 & 0.33 \\
# RATIONALE & none & user_prompt_hardening & 88.36 & -1.10 \\
# RATIONALE & prepend & few_shot & 89.50 & 0.04 \\
# RATIONALE & prepend & none & 89.89 & 0.43 \\
# RATIONALE & prepend & system_prompt_hardening & 89.60 & 0.14 \\
# RATIONALE & prepend & user_prompt_hardening & 89.73 & 0.27 \\
# RATIONALE & scatter & few_shot & 88.75 & -0.71 \\
# RATIONALE & scatter & none & 89.73 & 0.27 \\
# RATIONALE & scatter & system_prompt_hardening & 90.30 & 0.84 \\
# RATIONALE & scatter & user_prompt_hardening & 88.95 & -0.51 \\
# UTILITY & append & few_shot & 87.88 & -1.58 \\
# UTILITY & append & none & 89.29 & -0.17 \\
# UTILITY & append & system_prompt_hardening & 88.61 & -0.85 \\
# UTILITY & append & user_prompt_hardening & 87.77 & -1.69 \\
# UTILITY & none & few_shot & 87.65 & -1.81 \\
# UTILITY & none & none & 88.88 & -0.58 \\
# UTILITY & none & system_prompt_hardening & 88.81 & -0.66 \\
# UTILITY & none & user_prompt_hardening & 87.61 & -1.85 \\
# UTILITY & prepend & few_shot & 89.19 & -0.27 \\
# UTILITY & prepend & none & 89.70 & 0.24 \\
# UTILITY & prepend & system_prompt_hardening & 89.39 & -0.07 \\
# UTILITY & prepend & user_prompt_hardening & 89.82 & 0.36 \\
# UTILITY & scatter & few_shot & 88.24 & -1.22 \\
# UTILITY & scatter & none & 89.39 & -0.07 \\
# UTILITY & scatter & system_prompt_hardening & 89.42 & -0.04 \\
# UTILITY & scatter & user_prompt_hardening & 88.56 & -0.90 \\
# \midrule
# \textbf{Best JER Improvement} &  &  &  & -1.85 \
# \bottomrule
# \end{tabular}
#
#
# ================================================================================
# 3. MAE (GT=0) TABLE (with Best Improvement)
# ================================================================================
#
# \begin{tabular}{lllrr}
# \toprule
# Prompt & Attack & Mitigation & MAE (GT=0) & $\Delta$ MAE (GT=0) \\
# \midrule
# BASIC & append & few_shot & 2.2985 & 0.0039 \\
# BASIC & append & none & 2.5007 & 0.2061 \\
# BASIC & append & system_prompt_hardening & 2.3080 & 0.0134 \\
# BASIC & append & user_prompt_hardening & 2.6579 & 0.3633 \\
# BASIC & none & few_shot & 2.0920 & -0.2026 \\
# BASIC & none & none & 2.2946 & -- \\
# BASIC & none & system_prompt_hardening & 2.1515 & -0.1432 \\
# BASIC & none & user_prompt_hardening & 2.5166 & 0.2220 \\
# BASIC & prepend & few_shot & 2.3686 & 0.0740 \\
# BASIC & prepend & none & 2.5461 & 0.2515 \\
# BASIC & prepend & system_prompt_hardening & 2.4569 & 0.1623 \\
# BASIC & prepend & user_prompt_hardening & 2.7882 & 0.4935 \\
# BASIC & scatter & few_shot & 2.2254 & -0.0692 \\
# BASIC & scatter & none & 2.4394 & 0.1448 \\
# BASIC & scatter & system_prompt_hardening & 2.2822 & -0.0124 \\
# BASIC & scatter & user_prompt_hardening & 2.7181 & 0.4235 \\
# RATIONALE & append & few_shot & 2.5182 & 0.2236 \\
# RATIONALE & append & none & 2.8020 & 0.5074 \\
# RATIONALE & append & system_prompt_hardening & 2.6155 & 0.3209 \\
# RATIONALE & append & user_prompt_hardening & 2.7614 & 0.4668 \\
# RATIONALE & none & few_shot & 2.2437 & -0.0509 \\
# RATIONALE & none & none & 2.7225 & 0.4278 \\
# RATIONALE & none & system_prompt_hardening & 2.4327 & 0.1381 \\
# RATIONALE & none & user_prompt_hardening & 2.6413 & 0.3467 \\
# RATIONALE & prepend & few_shot & 2.7261 & 0.4315 \\
# RATIONALE & prepend & none & 2.9011 & 0.6065 \\
# RATIONALE & prepend & system_prompt_hardening & 2.8057 & 0.5111 \\
# RATIONALE & prepend & user_prompt_hardening & 2.9110 & 0.6164 \\
# RATIONALE & scatter & few_shot & 2.3912 & 0.0966 \\
# RATIONALE & scatter & none & 2.8183 & 0.5237 \\
# RATIONALE & scatter & system_prompt_hardening & 2.5807 & 0.2861 \\
# RATIONALE & scatter & user_prompt_hardening & 2.8022 & 0.5076 \\
# UTILITY & append & few_shot & 2.5106 & 0.2160 \\
# UTILITY & append & none & 2.8209 & 0.5263 \\
# UTILITY & append & system_prompt_hardening & 2.6413 & 0.3467 \\
# UTILITY & append & user_prompt_hardening & 2.8061 & 0.5115 \\
# UTILITY & none & few_shot & 2.2716 & -0.0231 \\
# UTILITY & none & none & 2.7642 & 0.4696 \\
# UTILITY & none & system_prompt_hardening & 2.5101 & 0.2155 \\
# UTILITY & none & user_prompt_hardening & 2.7497 & 0.4550 \\
# UTILITY & prepend & few_shot & 2.7575 & 0.4629 \\
# UTILITY & prepend & none & 2.9059 & 0.6113 \\
# UTILITY & prepend & system_prompt_hardening & 2.8396 & 0.5450 \\
# UTILITY & prepend & user_prompt_hardening & 2.9373 & 0.6427 \\
# UTILITY & scatter & few_shot & 2.4894 & 0.1948 \\
# UTILITY & scatter & none & 2.8479 & 0.5533 \\
# UTILITY & scatter & system_prompt_hardening & 2.6759 & 0.3813 \\
# UTILITY & scatter & user_prompt_hardening & 2.8571 & 0.5625 \\
# \midrule
# \textbf{Best MAE Improvement (GT=0)} &  &  &  & -0.2026 \
# \bottomrule
# \end{tabular}
#
#
# ================================================================================
# 4. JER (GT=0) TABLE (with Best Improvement)
# ================================================================================
#
# \begin{tabular}{lllrr}
# \toprule
# Prompt & Attack & Mitigation & JER (GT=0) (\%) & $\Delta$ JER (GT=0) (\%) \\
# \midrule
# BASIC & append & few_shot & 95.50 & -3.04 \\
# BASIC & append & none & 99.08 & 0.53 \\
# BASIC & append & system_prompt_hardening & 97.65 & -0.90 \\
# BASIC & append & user_prompt_hardening & 97.26 & -1.29 \\
# BASIC & none & few_shot & 95.27 & -3.27 \\
# BASIC & none & none & 98.55 & -- \\
# BASIC & none & system_prompt_hardening & 97.21 & -1.34 \\
# BASIC & none & user_prompt_hardening & 97.42 & -1.13 \\
# BASIC & prepend & few_shot & 99.26 & 0.71 \\
# BASIC & prepend & none & 99.82 & 1.27 \\
# BASIC & prepend & system_prompt_hardening & 99.54 & 0.99 \\
# BASIC & prepend & user_prompt_hardening & 99.47 & 0.92 \\
# BASIC & scatter & few_shot & 96.08 & -2.47 \\
# BASIC & scatter & none & 98.96 & 0.41 \\
# BASIC & scatter & system_prompt_hardening & 98.13 & -0.41 \\
# BASIC & scatter & user_prompt_hardening & 98.46 & -0.09 \\
# RATIONALE & append & few_shot & 97.53 & -1.01 \\
# RATIONALE & append & none & 99.52 & 0.97 \\
# RATIONALE & append & system_prompt_hardening & 99.08 & 0.53 \\
# RATIONALE & append & user_prompt_hardening & 97.88 & -0.67 \\
# RATIONALE & none & few_shot & 96.10 & -2.44 \\
# RATIONALE & none & none & 99.29 & 0.74 \\
# RATIONALE & none & system_prompt_hardening & 99.17 & 0.62 \\
# RATIONALE & none & user_prompt_hardening & 97.44 & -1.11 \\
# RATIONALE & prepend & few_shot & 99.54 & 0.99 \\
# RATIONALE & prepend & none & 100.00 & 1.45 \\
# RATIONALE & prepend & system_prompt_hardening & 99.98 & 1.43 \\
# RATIONALE & prepend & user_prompt_hardening & 99.65 & 1.11 \\
# RATIONALE & scatter & few_shot & 96.47 & -2.07 \\
# RATIONALE & scatter & none & 99.45 & 0.90 \\
# RATIONALE & scatter & system_prompt_hardening & 99.38 & 0.83 \\
# RATIONALE & scatter & user_prompt_hardening & 98.18 & -0.37 \\
# UTILITY & append & few_shot & 95.07 & -3.48 \\
# UTILITY & append & none & 98.82 & 0.28 \\
# UTILITY & append & system_prompt_hardening & 97.26 & -1.29 \\
# UTILITY & append & user_prompt_hardening & 96.45 & -2.10 \\
# UTILITY & none & few_shot & 94.58 & -3.96 \\
# UTILITY & none & none & 98.27 & -0.28 \\
# UTILITY & none & system_prompt_hardening & 97.05 & -1.50 \\
# UTILITY & none & user_prompt_hardening & 96.47 & -2.07 \\
# UTILITY & prepend & few_shot & 99.10 & 0.55 \\
# UTILITY & prepend & none & 99.84 & 1.29 \\
# UTILITY & prepend & system_prompt_hardening & 99.59 & 1.04 \\
# UTILITY & prepend & user_prompt_hardening & 99.35 & 0.81 \\
# UTILITY & scatter & few_shot & 95.46 & -3.09 \\
# UTILITY & scatter & none & 98.96 & 0.41 \\
# UTILITY & scatter & system_prompt_hardening & 98.25 & -0.30 \\
# UTILITY & scatter & user_prompt_hardening & 97.63 & -0.92 \\
# \midrule
# \textbf{Best JER Improvement (GT=0)} &  &  &  & -3.96 \
# \bottomrule
# \end{tabular}
#
#
# ================================================================================
# 5. MAE (GT>0) TABLE (with Best Improvement)
# ================================================================================
#
# \begin{tabular}{lllrr}
# \toprule
# Prompt & Attack & Mitigation & MAE (GT$>$0) & $\Delta$ MAE (GT$>$0) \\
# \midrule
# BASIC & append & few_shot & 0.9881 & 0.0634 \\
# BASIC & append & none & 1.0365 & 0.1118 \\
# BASIC & append & system_prompt_hardening & 0.9597 & 0.0350 \\
# BASIC & append & user_prompt_hardening & 1.1208 & 0.1960 \\
# BASIC & none & few_shot & 0.8539 & -0.0708 \\
# BASIC & none & none & 0.9247 & -- \\
# BASIC & none & system_prompt_hardening & 0.8763 & -0.0485 \\
# BASIC & none & user_prompt_hardening & 1.0615 & 0.1368 \\
# BASIC & prepend & few_shot & 0.9057 & -0.0190 \\
# BASIC & prepend & none & 0.9974 & 0.0727 \\
# BASIC & prepend & system_prompt_hardening & 0.9657 & 0.0410 \\
# BASIC & prepend & user_prompt_hardening & 1.1558 & 0.2311 \\
# BASIC & scatter & few_shot & 0.9154 & -0.0093 \\
# BASIC & scatter & none & 1.0130 & 0.0883 \\
# BASIC & scatter & system_prompt_hardening & 0.9366 & 0.0119 \\
# BASIC & scatter & user_prompt_hardening & 1.1480 & 0.2233 \\
# RATIONALE & append & few_shot & 1.0891 & 0.1644 \\
# RATIONALE & append & none & 1.1729 & 0.2482 \\
# RATIONALE & append & system_prompt_hardening & 1.1032 & 0.1785 \\
# RATIONALE & append & user_prompt_hardening & 1.1778 & 0.2531 \\
# RATIONALE & none & few_shot & 0.9672 & 0.0425 \\
# RATIONALE & none & none & 1.1539 & 0.2292 \\
# RATIONALE & none & system_prompt_hardening & 1.0168 & 0.0921 \\
# RATIONALE & none & user_prompt_hardening & 1.1260 & 0.2013 \\
# RATIONALE & prepend & few_shot & 1.1301 & 0.2054 \\
# RATIONALE & prepend & none & 1.2162 & 0.2915 \\
# RATIONALE & prepend & system_prompt_hardening & 1.1532 & 0.2285 \\
# RATIONALE & prepend & user_prompt_hardening & 1.2300 & 0.3053 \\
# RATIONALE & scatter & few_shot & 1.0511 & 0.1264 \\
# RATIONALE & scatter & none & 1.1871 & 0.2624 \\
# RATIONALE & scatter & system_prompt_hardening & 1.1025 & 0.1778 \\
# RATIONALE & scatter & user_prompt_hardening & 1.1871 & 0.2624 \\
# UTILITY & append & few_shot & 1.1312 & 0.2065 \\
# UTILITY & append & none & 1.1871 & 0.2624 \\
# UTILITY & append & system_prompt_hardening & 1.1480 & 0.2233 \\
# UTILITY & append & user_prompt_hardening & 1.2128 & 0.2881 \\
# UTILITY & none & few_shot & 1.0030 & 0.0783 \\
# UTILITY & none & none & 1.1763 & 0.2516 \\
# UTILITY & none & system_prompt_hardening & 1.0798 & 0.1551 \\
# UTILITY & none & user_prompt_hardening & 1.1759 & 0.2512 \\
# UTILITY & prepend & few_shot & 1.1346 & 0.2098 \\
# UTILITY & prepend & none & 1.2087 & 0.2840 \\
# UTILITY & prepend & system_prompt_hardening & 1.1726 & 0.2479 \\
# UTILITY & prepend & user_prompt_hardening & 1.2516 & 0.3269 \\
# UTILITY & scatter & few_shot & 1.1047 & 0.1800 \\
# UTILITY & scatter & none & 1.2024 & 0.2777 \\
# UTILITY & scatter & system_prompt_hardening & 1.1435 & 0.2188 \\
# UTILITY & scatter & user_prompt_hardening & 1.2154 & 0.2907 \\
# \midrule
# \textbf{Best MAE Improvement (GT>0)} &  &  &  & -0.0708 \
# \bottomrule
# \end{tabular}
#
#
# ================================================================================
# 6. JER (GT>0) TABLE (with Best Improvement)
# ================================================================================
#
# \begin{tabular}{lllrr}
# \toprule
# Prompt & Attack & Mitigation & JER (GT$>$0) (\%) & $\Delta$ JER (GT$>$0) (\%) \\
# \midrule
# BASIC & append & few_shot & 76.30 & 1.53 \\
# BASIC & append & none & 75.21 & 0.45 \\
# BASIC & append & system_prompt_hardening & 76.71 & 1.94 \\
# BASIC & append & user_prompt_hardening & 74.06 & -0.71 \\
# BASIC & none & few_shot & 75.92 & 1.16 \\
# BASIC & none & none & 74.77 & -- \\
# BASIC & none & system_prompt_hardening & 76.41 & 1.64 \\
# BASIC & none & user_prompt_hardening & 74.47 & -0.30 \\
# BASIC & prepend & few_shot & 74.10 & -0.67 \\
# BASIC & prepend & none & 73.46 & -1.30 \\
# BASIC & prepend & system_prompt_hardening & 74.13 & -0.63 \\
# BASIC & prepend & user_prompt_hardening & 73.87 & -0.89 \\
# BASIC & scatter & few_shot & 76.00 & 1.23 \\
# BASIC & scatter & none & 76.11 & 1.34 \\
# BASIC & scatter & system_prompt_hardening & 77.56 & 2.80 \\
# BASIC & scatter & user_prompt_hardening & 74.84 & 0.07 \\
# RATIONALE & append & few_shot & 75.44 & 0.67 \\
# RATIONALE & append & none & 73.54 & -1.23 \\
# RATIONALE & append & system_prompt_hardening & 74.58 & -0.19 \\
# RATIONALE & append & user_prompt_hardening & 73.24 & -1.53 \\
# RATIONALE & none & few_shot & 75.48 & 0.71 \\
# RATIONALE & none & none & 73.76 & -1.01 \\
# RATIONALE & none & system_prompt_hardening & 74.62 & -0.15 \\
# RATIONALE & none & user_prompt_hardening & 73.69 & -1.08 \\
# RATIONALE & prepend & few_shot & 73.28 & -1.49 \\
# RATIONALE & prepend & none & 73.54 & -1.23 \\
# RATIONALE & prepend & system_prompt_hardening & 72.83 & -1.94 \\
# RATIONALE & prepend & user_prompt_hardening & 73.69 & -1.08 \\
# RATIONALE & scatter & few_shot & 76.26 & 1.49 \\
# RATIONALE & scatter & none & 74.02 & -0.75 \\
# RATIONALE & scatter & system_prompt_hardening & 75.62 & 0.86 \\
# RATIONALE & scatter & user_prompt_hardening & 74.02 & -0.75 \\
# UTILITY & append & few_shot & 76.26 & 1.49 \\
# UTILITY & append & none & 73.87 & -0.89 \\
# UTILITY & append & system_prompt_hardening & 74.62 & -0.15 \\
# UTILITY & append & user_prompt_hardening & 73.72 & -1.04 \\
# UTILITY & none & few_shot & 76.44 & 1.68 \\
# UTILITY & none & none & 73.69 & -1.08 \\
# UTILITY & none & system_prompt_hardening & 75.48 & 0.71 \\
# UTILITY & none & user_prompt_hardening & 73.28 & -1.49 \\
# UTILITY & prepend & few_shot & 73.16 & -1.60 \\
# UTILITY & prepend & none & 73.31 & -1.45 \\
# UTILITY & prepend & system_prompt_hardening & 72.90 & -1.86 \\
# UTILITY & prepend & user_prompt_hardening & 74.39 & -0.37 \\
# UTILITY & scatter & few_shot & 76.56 & 1.79 \\
# UTILITY & scatter & none & 73.91 & -0.86 \\
# UTILITY & scatter & system_prompt_hardening & 75.14 & 0.37 \\
# UTILITY & scatter & user_prompt_hardening & 73.91 & -0.86 \\
# \midrule
# \textbf{Best JER Improvement (GT>0)} &  &  &  & -1.94 \
# \bottomrule
# \end{tabular}
#
#
# ================================================================================
# SUMMARY OF BESTS (All Tables)
# ================================================================================
#      Metric Best Improvement Imp Prompt Imp Attack          Imp Mitigation Best Overall Best Prompt Best Attack         Best Mitigation
# Overall MAE          -0.1523      BASIC       none                few_shot       1.6189       BASIC        none                few_shot
# Overall JER           -1.85%    UTILITY       none   user_prompt_hardening       87.61%     UTILITY        none   user_prompt_hardening
#  MAE (GT=0)          -0.2026      BASIC       none                few_shot       2.0920       BASIC        none                few_shot
#  JER (GT=0)           -3.96%    UTILITY       none                few_shot       94.58%     UTILITY        none                few_shot
#  MAE (GT>0)          -0.0708      BASIC       none                few_shot       0.8539       BASIC        none                few_shot
#  JER (GT>0)           -1.94%  RATIONALE    prepend system_prompt_hardening       72.83%   RATIONALE     prepend system_prompt_hardening
#
# ================================================================================
# LATEX SUMMARY TABLE (All Tables)
# ================================================================================
# \begin{tabular}{lrrrrrrrrr}
# \toprule
# Metric & Best Improvement & Imp Prompt & Imp Attack & Imp Mitigation & Best Overall & Best Prompt & Best Attack & Best Mitigation \\
# \midrule
# Overall MAE & -0.1523 & BASIC & none & few_shot & 1.6189 & BASIC & none & few_shot \\
# Overall JER & -1.85% & UTILITY & none & user_prompt_hardening & 87.61% & UTILITY & none & user_prompt_hardening \\
# MAE (GT=0) & -0.2026 & BASIC & none & few_shot & 2.0920 & BASIC & none & few_shot \\
# JER (GT=0) & -3.96% & UTILITY & none & few_shot & 94.58% & UTILITY & none & few_shot \\
# MAE (GT>0) & -0.0708 & BASIC & none & few_shot & 0.8539 & BASIC & none & few_shot \\
# JER (GT>0) & -1.94% & RATIONALE & prepend & system_prompt_hardening & 72.83% & RATIONALE & prepend & system_prompt_hardening \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### Overleaf table placement tips
#
# - Use table placement hints to avoid footer overlap: `\begin{table}[htbp] ... \end{table}`
# - For multi-page tables, prefer `longtable`:
#   - Preamble: `\usepackage{longtable,booktabs}`
#   - Replace `table` with `longtable` and include continued headers/footers per Overleaf docs.
# - If a table still crowds the footer, force a break before it: `\clearpage` immediately before the table.
# - Keep consistent vertical spacing: avoid trailing `\vspace` after tables; use `\caption` above `\label` within the environment.
# - For wide tables, consider `\resizebox{\textwidth}{!}{...}` or landscape with `\usepackage{pdflscape}` and `\begin{landscape} ... \end{landscape}` to reduce float pressure.
