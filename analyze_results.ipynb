# %% [markdown]
# # LLM Query Injection Experiment Results Analysis
#
# This notebook analyzes the results from the LLM query injection experiments, comparing performance across different prompt types, attack types, and mitigation strategies.
#
# **Baseline**: BASIC prompt, no attack, no mitigation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# Load the results

CSV_FILENAME = 'qwen3_0.6b_results.csv'
#CSV_FILENAME = 'gemma3_1b_results.csv'
df = pd.read_csv(CSV_FILENAME)

print(f"Loaded {len(df)} experiment results")
print(f"Columns: {list(df.columns)}")
df.head()
# Out:
# Loaded 48 experiment results
# Columns: ['filename', 'prompt_type', 'attack_type', 'mitigation_type', 'overall_mae', 'mae_gt_zero', 'mae_gt_positive', 'overall_jer', 'jer_gt_zero', 'jer_gt_positive', 'delta_overall_mae', 'delta_mae_gt_zero', 'delta_mae_gt_positive', 'delta_overall_jer', 'delta_jer_gt_zero', 'delta_jer_gt_positive', 'valid_experiments', 'gt_zero_count', 'gt_positive_count', 'failed_experiments', 'total_experiments']
#                                             filename prompt_type attack_type  \
# 0                       results_BASIC_none_none.json       BASIC        none
# 1                 results_BASIC_append_few_shot.json       BASIC      append
# 2                     results_BASIC_append_none.json       BASIC      append
# 3  results_BASIC_append_system_prompt_hardening.json       BASIC      append
# 4    results_BASIC_append_user_prompt_hardening.json       BASIC      append
#
#            mitigation_type  overall_mae  mae_gt_zero  mae_gt_positive  \
# 0                     none       0.9208       0.7849           1.1405
# 1                 few_shot       1.2645       1.3193           1.1759
# 2                     none       1.1122       1.0970           1.1368
# 3  system_prompt_hardening       1.1139       1.1063           1.1264
# 4    user_prompt_hardening       0.9561       0.7824           1.2370
#
#    overall_jer  jer_gt_zero  jer_gt_positive  delta_overall_mae  \
# 0        50.43        32.96            78.68                NaN
# 1        58.52        46.75            77.56             0.3437
# 2        56.23        43.20            77.30             0.1914
# 3        56.32        43.48            77.08             0.1931
# 4        48.60        27.99            81.92             0.0353
#
#    delta_mae_gt_zero  delta_mae_gt_positive  delta_overall_jer  \
# 0                NaN                    NaN                NaN
# 1             0.5343                 0.0354               8.09
# 2             0.3121                -0.0037               5.80
# 3             0.3213                -0.0142               5.88
# 4            -0.0025                 0.0965              -1.84
#
#    delta_jer_gt_zero  delta_jer_gt_positive  valid_experiments  gt_zero_count  \
# 0                NaN                    NaN               7021           4338
# 1              13.79                  -1.12               7021           4338
# 2              10.24                  -1.38               7021           4338
# 3              10.51                  -1.60               7021           4338
# 4              -4.98                   3.24               7021           4338
#
#    gt_positive_count  failed_experiments  total_experiments
# 0               2683                   0               7021
# 1               2683                   0               7021
# 2               2683                   0               7021
# 3               2683                   0               7021
# 4               2683                   0               7021

# %% [markdown]
# ## 1. Overall MAE Results

# %%
# Find highest metric and highest delta for Overall MAE
highest_mae = df.loc[df['overall_mae'].idxmax()]
highest_delta_mae = df[df['delta_overall_mae'] != 'NaN'].loc[df[df['delta_overall_mae'] != 'NaN']['delta_overall_mae'].idxmax()]
print(f"Highest MAE: {highest_mae['overall_mae']:.4f}")
print(f"  Experiment: {highest_mae['prompt_type']}, {highest_mae['attack_type']}, {highest_mae['mitigation_type']}")
print(f"\nHighest Δ from Baseline: {highest_delta_mae['delta_overall_mae']:.4f}")
print(f"  Experiment: {highest_delta_mae['prompt_type']}, {highest_delta_mae['attack_type']}, {highest_delta_mae['mitigation_type']}")
# Out:
# Highest MAE: 2.2124
#   Experiment: RATIONALE, append, few_shot
#
# Highest Δ from Baseline: 1.2916
#   Experiment: RATIONALE, append, few_shot

# %%
# Create overall MAE table
mae_table = df[['prompt_type', 'attack_type', 'mitigation_type', 'overall_mae', 'delta_overall_mae']].copy()
mae_table = mae_table.sort_values(['prompt_type', 'attack_type', 'mitigation_type'])

# Format the table
mae_table['overall_mae'] = mae_table['overall_mae'].apply(lambda x: f"{x:.4f}" if pd.notna(x) else "N/A")
mae_table['delta_overall_mae'] = mae_table['delta_overall_mae'].apply(lambda x: f"{x:+.4f}" if pd.notna(x) and x != 'NaN' else "N/A")

# Rename columns for display
mae_table_display = mae_table.rename(columns={
    'prompt_type': 'Prompt',
    'attack_type': 'Attack',
    'mitigation_type': 'Mitigation',
    'overall_mae': 'MAE',
    'delta_overall_mae': 'Δ from Baseline'
})

print("Overall MAE Results (Mean Absolute Error)")
print("=" * 60)
display(mae_table_display)
# Out:
# Overall MAE Results (Mean Absolute Error)
# ============================================================
#        Prompt   Attack               Mitigation     MAE Δ from Baseline
# 1       BASIC   append                 few_shot  1.2645         +0.3437
# 2       BASIC   append                     none  1.1122         +0.1914
# 3       BASIC   append  system_prompt_hardening  1.1139         +0.1931
# 4       BASIC   append    user_prompt_hardening  0.9561         +0.0353
# 5       BASIC     none                 few_shot  0.9504         +0.0296
# 0       BASIC     none                     none  0.9208             N/A
# 6       BASIC     none  system_prompt_hardening  0.9153         -0.0056
# 7       BASIC     none    user_prompt_hardening  0.8547         -0.0661
# 8       BASIC  prepend                 few_shot  1.5817         +0.6609
# 9       BASIC  prepend                     none  1.4898         +0.5690
# 10      BASIC  prepend  system_prompt_hardening  1.5402         +0.6194
# 11      BASIC  prepend    user_prompt_hardening  1.3396         +0.4187
# 12      BASIC  scatter                 few_shot  1.3883         +0.4675
# 13      BASIC  scatter                     none  1.3104         +0.3895
# 14      BASIC  scatter  system_prompt_hardening  1.3242         +0.4034
# 15      BASIC  scatter    user_prompt_hardening  1.1971         +0.2763
# 16  RATIONALE   append                 few_shot  2.2124         +1.2916
# 17  RATIONALE   append                     none  2.0853         +1.1645
# 18  RATIONALE   append  system_prompt_hardening  2.1910         +1.2702
# 19  RATIONALE   append    user_prompt_hardening  1.1762         +0.2554
# 20  RATIONALE     none                 few_shot  2.0075         +1.0867
# 21  RATIONALE     none                     none  1.8654         +0.9446
# 22  RATIONALE     none  system_prompt_hardening  2.0802         +1.1594
# 23  RATIONALE     none    user_prompt_hardening  1.0226         +0.1018
# 24  RATIONALE  prepend                 few_shot  2.1844         +1.2636
# 25  RATIONALE  prepend                     none  2.0947         +1.1739
# 26  RATIONALE  prepend  system_prompt_hardening  2.1926         +1.2718
# 27  RATIONALE  prepend    user_prompt_hardening  1.5357         +0.6149
# 28  RATIONALE  scatter                 few_shot  2.1674         +1.2465
# 29  RATIONALE  scatter                     none  2.0575         +1.1367
# 30  RATIONALE  scatter  system_prompt_hardening  2.1460         +1.2252
# 31  RATIONALE  scatter    user_prompt_hardening  1.4212         +0.5004
# 32    UTILITY   append                 few_shot  1.7637         +0.8429
# 33    UTILITY   append                     none  1.6317         +0.7109
# 34    UTILITY   append  system_prompt_hardening  1.7300         +0.8091
# 35    UTILITY   append    user_prompt_hardening  1.0406         +0.1198
# 36    UTILITY     none                 few_shot  1.3772         +0.4563
# 37    UTILITY     none                     none  1.3662         +0.4454
# 38    UTILITY     none  system_prompt_hardening  1.4546         +0.5338
# 39    UTILITY     none    user_prompt_hardening  0.9231         +0.0023
# 40    UTILITY  prepend                 few_shot  1.8769         +0.9561
# 41    UTILITY  prepend                     none  1.8187         +0.8979
# 42    UTILITY  prepend  system_prompt_hardening  1.9483         +1.0275
# 43    UTILITY  prepend    user_prompt_hardening  1.4273         +0.5065
# 44    UTILITY  scatter                 few_shot  1.7784         +0.8576
# 45    UTILITY  scatter                     none  1.7301         +0.8093
# 46    UTILITY  scatter  system_prompt_hardening  1.8392         +0.9184
# 47    UTILITY  scatter    user_prompt_hardening  1.3300         +0.4092

# %% [markdown]
# ## 2. Overall JER Results

# %%
# Find highest metric and highest delta for Overall JER
highest_jer = df.loc[df['overall_jer'].idxmax()]
highest_delta_jer = df[df['delta_overall_jer'] != 'NaN'].loc[df[df['delta_overall_jer'] != 'NaN']['delta_overall_jer'].idxmax()]
print(f"Highest JER: {highest_jer['overall_jer']:.2f}%")
print(f"  Experiment: {highest_jer['prompt_type']}, {highest_jer['attack_type']}, {highest_jer['mitigation_type']}")
print(f"\nHighest Δ from Baseline: {highest_delta_jer['delta_overall_jer']:.2f}%")
print(f"  Experiment: {highest_delta_jer['prompt_type']}, {highest_delta_jer['attack_type']}, {highest_delta_jer['mitigation_type']}")
# Out:
# Highest JER: 88.33%
#   Experiment: RATIONALE, prepend, system_prompt_hardening
#
# Highest Δ from Baseline: 37.90%
#   Experiment: RATIONALE, prepend, system_prompt_hardening

# %%
# Create overall JER table
jer_table = df[['prompt_type', 'attack_type', 'mitigation_type', 'overall_jer', 'delta_overall_jer']].copy()
jer_table = jer_table.sort_values(['prompt_type', 'attack_type', 'mitigation_type'])

# Format the table
jer_table['overall_jer'] = jer_table['overall_jer'].apply(lambda x: f"{x:.2f}%" if pd.notna(x) else "N/A")
jer_table['delta_overall_jer'] = jer_table['delta_overall_jer'].apply(lambda x: f"{x:+.2f}%" if pd.notna(x) and x != 'NaN' else "N/A")

# Rename columns for display
jer_table_display = jer_table.rename(columns={
    'prompt_type': 'Prompt',
    'attack_type': 'Attack',
    'mitigation_type': 'Mitigation',
    'overall_jer': 'JER',
    'delta_overall_jer': 'Δ from Baseline'
})

print("Overall JER Results (Judgment Error Rate)")
print("=" * 60)
display(jer_table_display)
# Out:
# Overall JER Results (Judgment Error Rate)
# ============================================================
#        Prompt   Attack               Mitigation     JER Δ from Baseline
# 1       BASIC   append                 few_shot  58.52%          +8.09%
# 2       BASIC   append                     none  56.23%          +5.80%
# 3       BASIC   append  system_prompt_hardening  56.32%          +5.88%
# 4       BASIC   append    user_prompt_hardening  48.60%          -1.84%
# 5       BASIC     none                 few_shot  49.35%          -1.08%
# 0       BASIC     none                     none  50.43%             N/A
# 6       BASIC     none  system_prompt_hardening  50.61%          +0.17%
# 7       BASIC     none    user_prompt_hardening  46.30%          -4.13%
# 8       BASIC  prepend                 few_shot  68.32%         +17.89%
# 9       BASIC  prepend                     none  68.30%         +17.86%
# 10      BASIC  prepend  system_prompt_hardening  69.16%         +18.73%
# 11      BASIC  prepend    user_prompt_hardening  60.69%         +10.25%
# 12      BASIC  scatter                 few_shot  63.79%         +13.36%
# 13      BASIC  scatter                     none  65.56%         +15.13%
# 14      BASIC  scatter  system_prompt_hardening  66.17%         +15.74%
# 15      BASIC  scatter    user_prompt_hardening  58.01%          +7.58%
# 16  RATIONALE   append                 few_shot  87.42%         +36.99%
# 17  RATIONALE   append                     none  84.85%         +34.41%
# 18  RATIONALE   append  system_prompt_hardening  87.55%         +37.12%
# 19  RATIONALE   append    user_prompt_hardening  55.11%          +4.67%
# 20  RATIONALE     none                 few_shot  81.54%         +31.11%
# 21  RATIONALE     none                     none  78.51%         +28.07%
# 22  RATIONALE     none  system_prompt_hardening  84.79%         +34.35%
# 23  RATIONALE     none    user_prompt_hardening  50.72%          +0.28%
# 24  RATIONALE  prepend                 few_shot  86.50%         +36.06%
# 25  RATIONALE  prepend                     none  85.43%         +35.00%
# 26  RATIONALE  prepend  system_prompt_hardening  88.33%         +37.90%
# 27  RATIONALE  prepend    user_prompt_hardening  66.44%         +16.01%
# 28  RATIONALE  scatter                 few_shot  87.31%         +36.88%
# 29  RATIONALE  scatter                     none  85.94%         +35.51%
# 30  RATIONALE  scatter  system_prompt_hardening  87.89%         +37.46%
# 31  RATIONALE  scatter    user_prompt_hardening  64.31%         +13.87%
# 32    UTILITY   append                 few_shot  73.81%         +23.37%
# 33    UTILITY   append                     none  71.64%         +21.21%
# 34    UTILITY   append  system_prompt_hardening  73.91%         +23.47%
# 35    UTILITY   append    user_prompt_hardening  50.85%          +0.41%
# 36    UTILITY     none                 few_shot  61.91%         +11.48%
# 37    UTILITY     none                     none  63.31%         +12.88%
# 38    UTILITY     none  system_prompt_hardening  65.46%         +15.03%
# 39    UTILITY     none    user_prompt_hardening  47.77%          -2.66%
# 40    UTILITY  prepend                 few_shot  77.17%         +26.73%
# 41    UTILITY  prepend                     none  76.84%         +26.41%
# 42    UTILITY  prepend  system_prompt_hardening  80.49%         +30.05%
# 43    UTILITY  prepend    user_prompt_hardening  62.90%         +12.46%
# 44    UTILITY  scatter                 few_shot  75.30%         +24.87%
# 45    UTILITY  scatter                     none  76.36%         +25.92%
# 46    UTILITY  scatter  system_prompt_hardening  78.92%         +28.49%
# 47    UTILITY  scatter    user_prompt_hardening  61.43%         +11.00%

# %% [markdown]
# ## 3. MAE for Ground Truth = 0 (Irrelevant Documents)

# %%
# Find highest metric and highest delta for MAE (GT=0)
highest_mae_gt0 = df.loc[df['mae_gt_zero'].idxmax()]
highest_delta_mae_gt0 = df[df['delta_mae_gt_zero'] != 'NaN'].loc[df[df['delta_mae_gt_zero'] != 'NaN']['delta_mae_gt_zero'].idxmax()]
print(f"Highest MAE (GT=0): {highest_mae_gt0['mae_gt_zero']:.4f}")
print(f"  Experiment: {highest_mae_gt0['prompt_type']}, {highest_mae_gt0['attack_type']}, {highest_mae_gt0['mitigation_type']}")
print(f"\nHighest Δ from Baseline: {highest_delta_mae_gt0['delta_mae_gt_zero']:.4f}")
print(f"  Experiment: {highest_delta_mae_gt0['prompt_type']}, {highest_delta_mae_gt0['attack_type']}, {highest_delta_mae_gt0['mitigation_type']}")
# Out:
# Highest MAE (GT=0): 2.8163
#   Experiment: RATIONALE, append, few_shot
#
# Highest Δ from Baseline: 2.0314
#   Experiment: RATIONALE, append, few_shot

# %%
# Create GT=0 MAE table
mae_gt0_table = df[['prompt_type', 'attack_type', 'mitigation_type', 'mae_gt_zero', 'delta_mae_gt_zero']].copy()
mae_gt0_table = mae_gt0_table.sort_values(['prompt_type', 'attack_type', 'mitigation_type'])

# Format the table
mae_gt0_table['mae_gt_zero'] = mae_gt0_table['mae_gt_zero'].apply(lambda x: f"{x:.4f}" if pd.notna(x) else "N/A")
mae_gt0_table['delta_mae_gt_zero'] = mae_gt0_table['delta_mae_gt_zero'].apply(lambda x: f"{x:+.4f}" if pd.notna(x) and x != 'NaN' else "N/A")

# Rename columns for display
mae_gt0_table_display = mae_gt0_table.rename(columns={
    'prompt_type': 'Prompt',
    'attack_type': 'Attack',
    'mitigation_type': 'Mitigation',
    'mae_gt_zero': 'MAE (GT=0)',
    'delta_mae_gt_zero': 'Δ from Baseline'
})

print("MAE for Ground Truth = 0 (Irrelevant Documents)")
print("=" * 60)
display(mae_gt0_table_display)
# Out:
# MAE for Ground Truth = 0 (Irrelevant Documents)
# ============================================================
#        Prompt   Attack               Mitigation MAE (GT=0) Δ from Baseline
# 1       BASIC   append                 few_shot     1.3193         +0.5343
# 2       BASIC   append                     none     1.0970         +0.3121
# 3       BASIC   append  system_prompt_hardening     1.1063         +0.3213
# 4       BASIC   append    user_prompt_hardening     0.7824         -0.0025
# 5       BASIC     none                 few_shot     0.7497         -0.0353
# 0       BASIC     none                     none     0.7849             N/A
# 6       BASIC     none  system_prompt_hardening     0.7743         -0.0106
# 7       BASIC     none    user_prompt_hardening     0.5844         -0.2006
# 8       BASIC  prepend                 few_shot     1.8306         +1.0456
# 9       BASIC  prepend                     none     1.7324         +0.9474
# 10      BASIC  prepend  system_prompt_hardening     1.8059         +1.0210
# 11      BASIC  prepend    user_prompt_hardening     1.4534         +0.6685
# 12      BASIC  scatter                 few_shot     1.5371         +0.7522
# 13      BASIC  scatter                     none     1.4689         +0.6840
# 14      BASIC  scatter  system_prompt_hardening     1.4846         +0.6996
# 15      BASIC  scatter    user_prompt_hardening     1.2137         +0.4288
# 16  RATIONALE   append                 few_shot     2.8163         +2.0314
# 17  RATIONALE   append                     none     2.6349         +1.8499
# 18  RATIONALE   append  system_prompt_hardening     2.8031         +2.0182
# 19  RATIONALE   append    user_prompt_hardening     1.1321         +0.3472
# 20  RATIONALE     none                 few_shot     2.4885         +1.7036
# 21  RATIONALE     none                     none     2.2803         +1.4954
# 22  RATIONALE     none  system_prompt_hardening     2.6266         +1.8416
# 23  RATIONALE     none    user_prompt_hardening     0.8704         +0.0855
# 24  RATIONALE  prepend                 few_shot     2.7785         +1.9935
# 25  RATIONALE  prepend                     none     2.6616         +1.8767
# 26  RATIONALE  prepend  system_prompt_hardening     2.7974         +2.0124
# 27  RATIONALE  prepend    user_prompt_hardening     1.7524         +0.9675
# 28  RATIONALE  scatter                 few_shot     2.7621         +1.9772
# 29  RATIONALE  scatter                     none     2.6194         +1.8345
# 30  RATIONALE  scatter  system_prompt_hardening     2.7487         +1.9638
# 31  RATIONALE  scatter    user_prompt_hardening     1.5613         +0.7764
# 32    UTILITY   append                 few_shot     2.1132         +1.3283
# 33    UTILITY   append                     none     1.9147         +1.1298
# 34    UTILITY   append  system_prompt_hardening     2.0726         +1.2877
# 35    UTILITY   append    user_prompt_hardening     0.9182         +0.1332
# 36    UTILITY     none                 few_shot     1.4643         +0.6793
# 37    UTILITY     none                     none     1.5014         +0.7165
# 38    UTILITY     none  system_prompt_hardening     1.6296         +0.8446
# 39    UTILITY     none    user_prompt_hardening     0.6955         -0.0894
# 40    UTILITY  prepend                 few_shot     2.2909         +1.5060
# 41    UTILITY  prepend                     none     2.2303         +1.4454
# 42    UTILITY  prepend  system_prompt_hardening     2.4108         +1.6259
# 43    UTILITY  prepend    user_prompt_hardening     1.5957         +0.8107
# 44    UTILITY  scatter                 few_shot     2.1307         +1.3458
# 45    UTILITY  scatter                     none     2.1093         +1.3243
# 46    UTILITY  scatter  system_prompt_hardening     2.2755         +1.4905
# 47    UTILITY  scatter    user_prompt_hardening     1.3935         +0.6086

# %% [markdown]
# ## 4. JER for Ground Truth = 0 (Irrelevant Documents)

# %%
# Find highest metric and highest delta for JER (GT=0)
highest_jer_gt0 = df.loc[df['jer_gt_zero'].idxmax()]
highest_delta_jer_gt0 = df[df['delta_jer_gt_zero'] != 'NaN'].loc[df[df['delta_jer_gt_zero'] != 'NaN']['delta_jer_gt_zero'].idxmax()]
print(f"Highest JER (GT=0): {highest_jer_gt0['jer_gt_zero']:.2f}%")
print(f"  Experiment: {highest_jer_gt0['prompt_type']}, {highest_jer_gt0['attack_type']}, {highest_jer_gt0['mitigation_type']}")
print(f"\nHighest Δ from Baseline: {highest_delta_jer_gt0['delta_jer_gt_zero']:.2f}%")
print(f"  Experiment: {highest_delta_jer_gt0['prompt_type']}, {highest_delta_jer_gt0['attack_type']}, {highest_delta_jer_gt0['mitigation_type']}")
# Out:
# Highest JER (GT=0): 96.52%
#   Experiment: RATIONALE, prepend, system_prompt_hardening
#
# Highest Δ from Baseline: 63.55%
#   Experiment: RATIONALE, prepend, system_prompt_hardening

# %%
# Create GT=0 JER table
jer_gt0_table = df[['prompt_type', 'attack_type', 'mitigation_type', 'jer_gt_zero', 'delta_jer_gt_zero']].copy()
jer_gt0_table = jer_gt0_table.sort_values(['prompt_type', 'attack_type', 'mitigation_type'])

# Format the table
jer_gt0_table['jer_gt_zero'] = jer_gt0_table['jer_gt_zero'].apply(lambda x: f"{x:.2f}%" if pd.notna(x) else "N/A")
jer_gt0_table['delta_jer_gt_zero'] = jer_gt0_table['delta_jer_gt_zero'].apply(lambda x: f"{x:+.2f}%" if pd.notna(x) and x != 'NaN' else "N/A")

# Rename columns for display
jer_gt0_table_display = jer_gt0_table.rename(columns={
    'prompt_type': 'Prompt',
    'attack_type': 'Attack',
    'mitigation_type': 'Mitigation',
    'jer_gt_zero': 'JER (GT=0)',
    'delta_jer_gt_zero': 'Δ from Baseline'
})

print("JER for Ground Truth = 0 (Irrelevant Documents)")
print("=" * 60)
display(jer_gt0_table_display)
# Out:
# JER for Ground Truth = 0 (Irrelevant Documents)
# ============================================================
#        Prompt   Attack               Mitigation JER (GT=0) Δ from Baseline
# 1       BASIC   append                 few_shot     46.75%         +13.79%
# 2       BASIC   append                     none     43.20%         +10.24%
# 3       BASIC   append  system_prompt_hardening     43.48%         +10.51%
# 4       BASIC   append    user_prompt_hardening     27.99%          -4.98%
# 5       BASIC     none                 few_shot     28.88%          -4.08%
# 0       BASIC     none                     none     32.96%             N/A
# 6       BASIC     none  system_prompt_hardening     33.40%          +0.44%
# 7       BASIC     none    user_prompt_hardening     22.41%         -10.56%
# 8       BASIC  prepend                 few_shot     64.22%         +31.26%
# 9       BASIC  prepend                     none     65.08%         +32.11%
# 10      BASIC  prepend  system_prompt_hardening     66.57%         +33.61%
# 11      BASIC  prepend    user_prompt_hardening     51.36%         +18.40%
# 12      BASIC  scatter                 few_shot     56.78%         +23.81%
# 13      BASIC  scatter                     none     60.44%         +27.48%
# 14      BASIC  scatter  system_prompt_hardening     61.60%         +28.63%
# 15      BASIC  scatter    user_prompt_hardening     45.67%         +12.70%
# 16  RATIONALE   append                 few_shot     95.16%         +62.19%
# 17  RATIONALE   append                     none     90.62%         +57.65%
# 18  RATIONALE   append  system_prompt_hardening     95.57%         +62.61%
# 19  RATIONALE   append    user_prompt_hardening     38.96%          +5.99%
# 20  RATIONALE     none                 few_shot     84.53%         +51.57%
# 21  RATIONALE     none                     none     79.02%         +46.06%
# 22  RATIONALE     none  system_prompt_hardening     90.13%         +57.17%
# 23  RATIONALE     none    user_prompt_hardening     30.61%          -2.35%
# 24  RATIONALE  prepend                 few_shot     93.96%         +61.00%
# 25  RATIONALE  prepend                     none     92.46%         +59.50%
# 26  RATIONALE  prepend  system_prompt_hardening     96.52%         +63.55%
# 27  RATIONALE  prepend    user_prompt_hardening     60.33%         +27.36%
# 28  RATIONALE  scatter                 few_shot     94.95%         +61.99%
# 29  RATIONALE  scatter                     none     92.83%         +59.87%
# 30  RATIONALE  scatter  system_prompt_hardening     96.04%         +63.07%
# 31  RATIONALE  scatter    user_prompt_hardening     55.51%         +22.54%
# 32    UTILITY   append                 few_shot     72.18%         +39.21%
# 33    UTILITY   append                     none     68.37%         +35.41%
# 34    UTILITY   append  system_prompt_hardening     72.71%         +39.74%
# 35    UTILITY   append    user_prompt_hardening     31.90%          -1.06%
# 36    UTILITY     none                 few_shot     51.18%         +18.21%
# 37    UTILITY     none                     none     54.77%         +21.81%
# 38    UTILITY     none  system_prompt_hardening     57.91%         +24.94%
# 39    UTILITY     none    user_prompt_hardening     24.97%          -8.00%
# 40    UTILITY  prepend                 few_shot     78.26%         +45.30%
# 41    UTILITY  prepend                     none     78.79%         +45.83%
# 42    UTILITY  prepend  system_prompt_hardening     83.73%         +50.76%
# 43    UTILITY  prepend    user_prompt_hardening     55.16%         +22.20%
# 44    UTILITY  scatter                 few_shot     75.03%         +42.07%
# 45    UTILITY  scatter                     none     77.57%         +44.61%
# 46    UTILITY  scatter  system_prompt_hardening     81.95%         +48.99%
# 47    UTILITY  scatter    user_prompt_hardening     50.00%         +17.04%

# %% [markdown]
# ## 5. MAE for Ground Truth > 0 (Relevant Documents)

# %%
# Find highest metric and highest delta for MAE (GT>0)
highest_mae_gtpos = df.loc[df['mae_gt_positive'].idxmax()]
highest_delta_mae_gtpos = df[df['delta_mae_gt_positive'] != 'NaN'].loc[df[df['delta_mae_gt_positive'] != 'NaN']['delta_mae_gt_positive'].idxmax()]
print(f"Highest MAE (GT>0): {highest_mae_gtpos['mae_gt_positive']:.4f}")
print(f"  Experiment: {highest_mae_gtpos['prompt_type']}, {highest_mae_gtpos['attack_type']}, {highest_mae_gtpos['mitigation_type']}")
print(f"\nHighest Δ from Baseline: {highest_delta_mae_gtpos['delta_mae_gt_positive']:.4f}")
print(f"  Experiment: {highest_delta_mae_gtpos['prompt_type']}, {highest_delta_mae_gtpos['attack_type']}, {highest_delta_mae_gtpos['mitigation_type']}")
# Out:
# Highest MAE (GT>0): 1.2918
#   Experiment: BASIC, none, user_prompt_hardening
#
# Highest Δ from Baseline: 0.1513
#   Experiment: BASIC, none, user_prompt_hardening

# %%
# Create GT>0 MAE table
mae_gtpos_table = df[['prompt_type', 'attack_type', 'mitigation_type', 'mae_gt_positive', 'delta_mae_gt_positive']].copy()
mae_gtpos_table = mae_gtpos_table.sort_values(['prompt_type', 'attack_type', 'mitigation_type'])

# Format the table
mae_gtpos_table['mae_gt_positive'] = mae_gtpos_table['mae_gt_positive'].apply(lambda x: f"{x:.4f}" if pd.notna(x) else "N/A")
mae_gtpos_table['delta_mae_gt_positive'] = mae_gtpos_table['delta_mae_gt_positive'].apply(lambda x: f"{x:+.4f}" if pd.notna(x) and x != 'NaN' else "N/A")

# Rename columns for display
mae_gtpos_table_display = mae_gtpos_table.rename(columns={
    'prompt_type': 'Prompt',
    'attack_type': 'Attack',
    'mitigation_type': 'Mitigation',
    'mae_gt_positive': 'MAE (GT>0)',
    'delta_mae_gt_positive': 'Δ from Baseline'
})

print("MAE for Ground Truth > 0 (Relevant Documents)")
print("=" * 60)
display(mae_gtpos_table_display)
# Out:
# MAE for Ground Truth > 0 (Relevant Documents)
# ============================================================
#        Prompt   Attack               Mitigation MAE (GT>0) Δ from Baseline
# 1       BASIC   append                 few_shot     1.1759         +0.0354
# 2       BASIC   append                     none     1.1368         -0.0037
# 3       BASIC   append  system_prompt_hardening     1.1264         -0.0142
# 4       BASIC   append    user_prompt_hardening     1.2370         +0.0965
# 5       BASIC     none                 few_shot     1.2751         +0.1346
# 0       BASIC     none                     none     1.1405             N/A
# 6       BASIC     none  system_prompt_hardening     1.1431         +0.0026
# 7       BASIC     none    user_prompt_hardening     1.2918         +0.1513
# 8       BASIC  prepend                 few_shot     1.1793         +0.0388
# 9       BASIC  prepend                     none     1.0977         -0.0429
# 10      BASIC  prepend  system_prompt_hardening     1.1107         -0.0298
# 11      BASIC  prepend    user_prompt_hardening     1.1554         +0.0149
# 12      BASIC  scatter                 few_shot     1.1476         +0.0071
# 13      BASIC  scatter                     none     1.0540         -0.0865
# 14      BASIC  scatter  system_prompt_hardening     1.0649         -0.0757
# 15      BASIC  scatter    user_prompt_hardening     1.1703         +0.0298
# 16  RATIONALE   append                 few_shot     1.2359         +0.0954
# 17  RATIONALE   append                     none     1.1968         +0.0563
# 18  RATIONALE   append  system_prompt_hardening     1.2013         +0.0608
# 19  RATIONALE   append    user_prompt_hardening     1.2475         +0.1070
# 20  RATIONALE     none                 few_shot     1.2300         +0.0895
# 21  RATIONALE     none                     none     1.1946         +0.0540
# 22  RATIONALE     none  system_prompt_hardening     1.1968         +0.0563
# 23  RATIONALE     none    user_prompt_hardening     1.2687         +0.1282
# 24  RATIONALE  prepend                 few_shot     1.2240         +0.0835
# 25  RATIONALE  prepend                     none     1.1782         +0.0376
# 26  RATIONALE  prepend  system_prompt_hardening     1.2147         +0.0742
# 27  RATIONALE  prepend    user_prompt_hardening     1.1852         +0.0447
# 28  RATIONALE  scatter                 few_shot     1.2057         +0.0652
# 29  RATIONALE  scatter                     none     1.1491         +0.0086
# 30  RATIONALE  scatter  system_prompt_hardening     1.1714         +0.0309
# 31  RATIONALE  scatter    user_prompt_hardening     1.1946         +0.0540
# 32    UTILITY   append                 few_shot     1.1987         +0.0581
# 33    UTILITY   append                     none     1.1741         +0.0335
# 34    UTILITY   append  system_prompt_hardening     1.1759         +0.0354
# 35    UTILITY   append    user_prompt_hardening     1.2385         +0.0980
# 36    UTILITY     none                 few_shot     1.2363         +0.0958
# 37    UTILITY     none                     none     1.1476         +0.0071
# 38    UTILITY     none  system_prompt_hardening     1.1718         +0.0313
# 39    UTILITY     none    user_prompt_hardening     1.2911         +0.1506
# 40    UTILITY  prepend                 few_shot     1.2076         +0.0671
# 41    UTILITY  prepend                     none     1.1532         +0.0127
# 42    UTILITY  prepend  system_prompt_hardening     1.2005         +0.0600
# 43    UTILITY  prepend    user_prompt_hardening     1.1551         +0.0145
# 44    UTILITY  scatter                 few_shot     1.2087         +0.0682
# 45    UTILITY  scatter                     none     1.1170         -0.0235
# 46    UTILITY  scatter  system_prompt_hardening     1.1338         -0.0067
# 47    UTILITY  scatter    user_prompt_hardening     1.2274         +0.0868

# %% [markdown]
# ## 6. JER for Ground Truth > 0 (Relevant Documents)

# %%
# Find highest metric and highest delta for JER (GT>0)
highest_jer_gtpos = df.loc[df['jer_gt_positive'].idxmax()]
highest_delta_jer_gtpos = df[df['delta_jer_gt_positive'] != 'NaN'].loc[df[df['delta_jer_gt_positive'] != 'NaN']['delta_jer_gt_positive'].idxmax()]
print(f"Highest JER (GT>0): {highest_jer_gtpos['jer_gt_positive']:.2f}%")
print(f"  Experiment: {highest_jer_gtpos['prompt_type']}, {highest_jer_gtpos['attack_type']}, {highest_jer_gtpos['mitigation_type']}")
print(f"\nHighest Δ from Baseline: {highest_delta_jer_gtpos['delta_jer_gt_positive']:.2f}%")
print(f"  Experiment: {highest_delta_jer_gtpos['prompt_type']}, {highest_delta_jer_gtpos['attack_type']}, {highest_delta_jer_gtpos['mitigation_type']}")
# Out:
# Highest JER (GT>0): 84.94%
#   Experiment: BASIC, none, user_prompt_hardening
#
# Highest Δ from Baseline: 6.26%
#   Experiment: BASIC, none, user_prompt_hardening

# %%
# Create GT>0 JER table
jer_gtpos_table = df[['prompt_type', 'attack_type', 'mitigation_type', 'jer_gt_positive', 'delta_jer_gt_positive']].copy()
jer_gtpos_table = jer_gtpos_table.sort_values(['prompt_type', 'attack_type', 'mitigation_type'])

# Format the table
jer_gtpos_table['jer_gt_positive'] = jer_gtpos_table['jer_gt_positive'].apply(lambda x: f"{x:.2f}%" if pd.notna(x) else "N/A")
jer_gtpos_table['delta_jer_gt_positive'] = jer_gtpos_table['delta_jer_gt_positive'].apply(lambda x: f"{x:+.2f}%" if pd.notna(x) and x != 'NaN' else "N/A")

# Rename columns for display
jer_gtpos_table_display = jer_gtpos_table.rename(columns={
    'prompt_type': 'Prompt',
    'attack_type': 'Attack',
    'mitigation_type': 'Mitigation',
    'jer_gt_positive': 'JER (GT>0)',
    'delta_jer_gt_positive': 'Δ from Baseline'
})

print("JER for Ground Truth > 0 (Relevant Documents)")
print("=" * 60)
display(jer_gtpos_table_display)
# Out:
# JER for Ground Truth > 0 (Relevant Documents)
# ============================================================
#        Prompt   Attack               Mitigation JER (GT>0) Δ from Baseline
# 1       BASIC   append                 few_shot     77.56%          -1.12%
# 2       BASIC   append                     none     77.30%          -1.38%
# 3       BASIC   append  system_prompt_hardening     77.08%          -1.60%
# 4       BASIC   append    user_prompt_hardening     81.92%          +3.24%
# 5       BASIC     none                 few_shot     82.45%          +3.76%
# 0       BASIC     none                     none     78.68%             N/A
# 6       BASIC     none  system_prompt_hardening     78.42%          -0.26%
# 7       BASIC     none    user_prompt_hardening     84.94%          +6.26%
# 8       BASIC  prepend                 few_shot     74.95%          -3.73%
# 9       BASIC  prepend                     none     73.50%          -5.18%
# 10      BASIC  prepend  system_prompt_hardening     73.35%          -5.33%
# 11      BASIC  prepend    user_prompt_hardening     75.77%          -2.91%
# 12      BASIC  scatter                 few_shot     75.14%          -3.54%
# 13      BASIC  scatter                     none     73.84%          -4.85%
# 14      BASIC  scatter  system_prompt_hardening     73.57%          -5.11%
# 15      BASIC  scatter    user_prompt_hardening     77.97%          -0.71%
# 16  RATIONALE   append                 few_shot     74.92%          -3.76%
# 17  RATIONALE   append                     none     75.51%          -3.17%
# 18  RATIONALE   append  system_prompt_hardening     74.58%          -4.10%
# 19  RATIONALE   append    user_prompt_hardening     81.22%          +2.53%
# 20  RATIONALE     none                 few_shot     76.71%          -1.98%
# 21  RATIONALE     none                     none     77.67%          -1.01%
# 22  RATIONALE     none  system_prompt_hardening     76.15%          -2.53%
# 23  RATIONALE     none    user_prompt_hardening     83.23%          +4.55%
# 24  RATIONALE  prepend                 few_shot     74.43%          -4.25%
# 25  RATIONALE  prepend                     none     74.06%          -4.62%
# 26  RATIONALE  prepend  system_prompt_hardening     75.10%          -3.58%
# 27  RATIONALE  prepend    user_prompt_hardening     76.33%          -2.35%
# 28  RATIONALE  scatter                 few_shot     74.95%          -3.73%
# 29  RATIONALE  scatter                     none     74.80%          -3.88%
# 30  RATIONALE  scatter  system_prompt_hardening     74.73%          -3.95%
# 31  RATIONALE  scatter    user_prompt_hardening     78.53%          -0.15%
# 32    UTILITY   append                 few_shot     76.44%          -2.24%
# 33    UTILITY   append                     none     76.93%          -1.75%
# 34    UTILITY   append  system_prompt_hardening     75.85%          -2.83%
# 35    UTILITY   append    user_prompt_hardening     81.48%          +2.80%
# 36    UTILITY     none                 few_shot     79.28%          +0.60%
# 37    UTILITY     none                     none     77.12%          -1.57%
# 38    UTILITY     none  system_prompt_hardening     77.67%          -1.01%
# 39    UTILITY     none    user_prompt_hardening     84.64%          +5.96%
# 40    UTILITY  prepend                 few_shot     75.40%          -3.28%
# 41    UTILITY  prepend                     none     73.69%          -4.99%
# 42    UTILITY  prepend  system_prompt_hardening     75.25%          -3.43%
# 43    UTILITY  prepend    user_prompt_hardening     75.40%          -3.28%
# 44    UTILITY  scatter                 few_shot     75.74%          -2.94%
# 45    UTILITY  scatter                     none     74.39%          -4.29%
# 46    UTILITY  scatter  system_prompt_hardening     74.02%          -4.66%
# 47    UTILITY  scatter    user_prompt_hardening     79.91%          +1.23%

# %% [markdown]
# ## 7. Summary Statistics

# %%
# Summary statistics
print("Experiment Summary")
print("=" * 30)
print(f"Total experiments: {len(df)}")
print(f"Prompt types: {df['prompt_type'].unique().tolist()}")
print(f"Attack types: {df['attack_type'].unique().tolist()}")
print(f"Mitigation types: {df['mitigation_type'].unique().tolist()}")

# Find baseline
baseline = df[(df['prompt_type'] == 'BASIC') & (df['attack_type'] == 'none') & (df['mitigation_type'] == 'none')]
if not baseline.empty:
    print(f"\nBaseline (BASIC, none, none) metrics:")
    print(f"  Overall MAE: {baseline['overall_mae'].iloc[0]:.4f}")
    print(f"  Overall JER: {baseline['overall_jer'].iloc[0]:.2f}%")
    print(f"  MAE GT=0: {baseline['mae_gt_zero'].iloc[0]:.4f}")
    print(f"  JER GT=0: {baseline['jer_gt_zero'].iloc[0]:.2f}%")
    print(f"  MAE GT>0: {baseline['mae_gt_positive'].iloc[0]:.4f}")
    print(f"  JER GT>0: {baseline['jer_gt_positive'].iloc[0]:.2f}%")

# Best and worst performing experiments
print(f"\nBest Overall MAE: {df['overall_mae'].min():.4f}")
best_mae = df[df['overall_mae'] == df['overall_mae'].min()]
print(f"  Experiment: {best_mae['prompt_type'].iloc[0]}, {best_mae['attack_type'].iloc[0]}, {best_mae['mitigation_type'].iloc[0]}")

print(f"\nWorst Overall MAE: {df['overall_mae'].max():.4f}")
worst_mae = df[df['overall_mae'] == df['overall_mae'].max()]
print(f"  Experiment: {worst_mae['prompt_type'].iloc[0]}, {worst_mae['attack_type'].iloc[0]}, {worst_mae['mitigation_type'].iloc[0]}")

print(f"\nBest Overall JER: {df['overall_jer'].min():.2f}%")
best_jer = df[df['overall_jer'] == df['overall_jer'].min()]
print(f"  Experiment: {best_jer['prompt_type'].iloc[0]}, {best_jer['attack_type'].iloc[0]}, {best_jer['mitigation_type'].iloc[0]}")

print(f"\nWorst Overall JER: {df['overall_jer'].max():.2f}%")
worst_jer = df[df['overall_jer'] == df['overall_jer'].max()]
print(f"  Experiment: {worst_jer['prompt_type'].iloc[0]}, {worst_jer['attack_type'].iloc[0]}, {worst_jer['mitigation_type'].iloc[0]}")
# Out:
# Experiment Summary
# ==============================
# Total experiments: 48
# Prompt types: ['BASIC', 'RATIONALE', 'UTILITY']
# Attack types: ['none', 'append', 'prepend', 'scatter']
# Mitigation types: ['none', 'few_shot', 'system_prompt_hardening', 'user_prompt_hardening']
#
# Baseline (BASIC, none, none) metrics:
#   Overall MAE: 0.9208
#   Overall JER: 50.43%
#   MAE GT=0: 0.7849
#   JER GT=0: 32.96%
#   MAE GT>0: 1.1405
#   JER GT>0: 78.68%
#
# Best Overall MAE: 0.8547
#   Experiment: BASIC, none, user_prompt_hardening
#
# Worst Overall MAE: 2.2124
#   Experiment: RATIONALE, append, few_shot
#
# Best Overall JER: 46.30%
#   Experiment: BASIC, none, user_prompt_hardening
#
# Worst Overall JER: 88.33%
#   Experiment: RATIONALE, prepend, system_prompt_hardening

# %% [markdown]
# ## 8. Delta Analysis (Performance vs Baseline)

# %%
# Analyze deltas (excluding baseline itself)
non_baseline = df[(df['prompt_type'] != 'BASIC') | (df['attack_type'] != 'none') | (df['mitigation_type'] != 'none')]

print("Delta Analysis (Performance vs Baseline)")
print("=" * 40)
print(f"Experiments compared to baseline: {len(non_baseline)}")

# Count improvements vs degradations
mae_improvements = len(non_baseline[non_baseline['delta_overall_mae'] < 0])
mae_degradations = len(non_baseline[non_baseline['delta_overall_mae'] > 0])
jer_improvements = len(non_baseline[non_baseline['delta_overall_jer'] < 0])
jer_degradations = len(non_baseline[non_baseline['delta_overall_jer'] > 0])

print(f"\nMAE Improvements (negative delta): {mae_improvements}")
print(f"MAE Degradations (positive delta): {mae_degradations}")
print(f"JER Improvements (negative delta): {jer_improvements}")
print(f"JER Degradations (positive delta): {jer_degradations}")

# Best improvements
if not non_baseline.empty:
    best_mae_improvement = non_baseline[non_baseline['delta_overall_mae'] == non_baseline['delta_overall_mae'].min()]
    best_jer_improvement = non_baseline[non_baseline['delta_overall_jer'] == non_baseline['delta_overall_jer'].min()]
    
    print(f"\nBest MAE Improvement: {best_mae_improvement['delta_overall_mae'].iloc[0]:.4f}")
    print(f"  Experiment: {best_mae_improvement['prompt_type'].iloc[0]}, {best_mae_improvement['attack_type'].iloc[0]}, {best_mae_improvement['mitigation_type'].iloc[0]}")
    
    print(f"\nBest JER Improvement: {best_jer_improvement['delta_overall_jer'].iloc[0]:.2f}%")
    print(f"  Experiment: {best_jer_improvement['prompt_type'].iloc[0]}, {best_jer_improvement['attack_type'].iloc[0]}, {best_jer_improvement['mitigation_type'].iloc[0]}")
# Out:
# Delta Analysis (Performance vs Baseline)
# ========================================
# Experiments compared to baseline: 47
#
# MAE Improvements (negative delta): 2
# MAE Degradations (positive delta): 45
# JER Improvements (negative delta): 4
# JER Degradations (positive delta): 43
#
# Best MAE Improvement: -0.0661
#   Experiment: BASIC, none, user_prompt_hardening
#
# Best JER Improvement: -4.13%
#   Experiment: BASIC, none, user_prompt_hardening

# %%
# ==============================================================================
# LaTeX Table Generation for Thesis
# ==============================================================================

print("=" * 80)
print("LATEX TABLE OUTPUT FOR THESIS")
print("=" * 80)

# 1. Overall MAE Table
print("\n" + "=" * 80)
print("1. OVERALL MAE TABLE")
print("=" * 80 + "\n")
mae_latex = df[['prompt_type', 'attack_type', 'mitigation_type', 'overall_mae', 'delta_overall_mae']].copy()
mae_latex = mae_latex.sort_values(['prompt_type', 'attack_type', 'mitigation_type'])
mae_latex.columns = ['Prompt', 'Attack', 'Mitigation', 'MAE', '$\\Delta$ MAE']
latex_code = mae_latex.to_latex(index=False, float_format="%.4f", escape=False, 
                                  column_format='lllrr', na_rep='--')
print(latex_code)

# 2. Overall JER Table
print("\n" + "=" * 80)
print("2. OVERALL JER TABLE")
print("=" * 80 + "\n")
jer_latex = df[['prompt_type', 'attack_type', 'mitigation_type', 'overall_jer', 'delta_overall_jer']].copy()
jer_latex = jer_latex.sort_values(['prompt_type', 'attack_type', 'mitigation_type'])
jer_latex.columns = ['Prompt', 'Attack', 'Mitigation', 'JER (\\%)', '$\\Delta$ JER (\\%)']
latex_code = jer_latex.to_latex(index=False, float_format="%.2f", escape=False,
                                  column_format='lllrr', na_rep='--')
print(latex_code)

# 3. MAE for GT=0 Table
print("\n" + "=" * 80)
print("3. MAE FOR GROUND TRUTH = 0 (IRRELEVANT DOCUMENTS)")
print("=" * 80 + "\n")
mae_gt0_latex = df[['prompt_type', 'attack_type', 'mitigation_type', 'mae_gt_zero', 'delta_mae_gt_zero']].copy()
mae_gt0_latex = mae_gt0_latex.sort_values(['prompt_type', 'attack_type', 'mitigation_type'])
mae_gt0_latex.columns = ['Prompt', 'Attack', 'Mitigation', 'MAE (GT=0)', '$\\Delta$ MAE (GT=0)']
latex_code = mae_gt0_latex.to_latex(index=False, float_format="%.4f", escape=False,
                                      column_format='lllrr', na_rep='--')
print(latex_code)

# 4. JER for GT=0 Table
print("\n" + "=" * 80)
print("4. JER FOR GROUND TRUTH = 0 (IRRELEVANT DOCUMENTS)")
print("=" * 80 + "\n")
jer_gt0_latex = df[['prompt_type', 'attack_type', 'mitigation_type', 'jer_gt_zero', 'delta_jer_gt_zero']].copy()
jer_gt0_latex = jer_gt0_latex.sort_values(['prompt_type', 'attack_type', 'mitigation_type'])
jer_gt0_latex.columns = ['Prompt', 'Attack', 'Mitigation', 'JER (GT=0) (\\%)', '$\\Delta$ JER (GT=0) (\\%)']
latex_code = jer_gt0_latex.to_latex(index=False, float_format="%.2f", escape=False,
                                      column_format='lllrr', na_rep='--')
print(latex_code)

# 5. MAE for GT>0 Table
print("\n" + "=" * 80)
print("5. MAE FOR GROUND TRUTH > 0 (RELEVANT DOCUMENTS)")
print("=" * 80 + "\n")
mae_gtpos_latex = df[['prompt_type', 'attack_type', 'mitigation_type', 'mae_gt_positive', 'delta_mae_gt_positive']].copy()
mae_gtpos_latex = mae_gtpos_latex.sort_values(['prompt_type', 'attack_type', 'mitigation_type'])
mae_gtpos_latex.columns = ['Prompt', 'Attack', 'Mitigation', 'MAE (GT$>$0)', '$\\Delta$ MAE (GT$>$0)']
latex_code = mae_gtpos_latex.to_latex(index=False, float_format="%.4f", escape=False,
                                        column_format='lllrr', na_rep='--')
print(latex_code)

# 6. JER for GT>0 Table
print("\n" + "=" * 80)
print("6. JER FOR GROUND TRUTH > 0 (RELEVANT DOCUMENTS)")
print("=" * 80 + "\n")
jer_gtpos_latex = df[['prompt_type', 'attack_type', 'mitigation_type', 'jer_gt_positive', 'delta_jer_gt_positive']].copy()
jer_gtpos_latex = jer_gtpos_latex.sort_values(['prompt_type', 'attack_type', 'mitigation_type'])
jer_gtpos_latex.columns = ['Prompt', 'Attack', 'Mitigation', 'JER (GT$>$0) (\\%)', '$\\Delta$ JER (GT$>$0) (\\%)']
latex_code = jer_gtpos_latex.to_latex(index=False, float_format="%.2f", escape=False,
                                        column_format='lllrr', na_rep='--')
print(latex_code)

print("\n" + "=" * 80)
print("END OF LATEX TABLE OUTPUT")
print("=" * 80)
# Out:
# ================================================================================
# LATEX TABLE OUTPUT FOR THESIS
# ================================================================================
#
# ================================================================================
# 1. OVERALL MAE TABLE
# ================================================================================
#
# \begin{tabular}{lllrr}
# \toprule
# Prompt & Attack & Mitigation & MAE & $\Delta$ MAE \\
# \midrule
# BASIC & append & few_shot & 1.2645 & 0.3437 \\
# BASIC & append & none & 1.1122 & 0.1914 \\
# BASIC & append & system_prompt_hardening & 1.1139 & 0.1931 \\
# BASIC & append & user_prompt_hardening & 0.9561 & 0.0353 \\
# BASIC & none & few_shot & 0.9504 & 0.0296 \\
# BASIC & none & none & 0.9208 & -- \\
# BASIC & none & system_prompt_hardening & 0.9153 & -0.0056 \\
# BASIC & none & user_prompt_hardening & 0.8547 & -0.0661 \\
# BASIC & prepend & few_shot & 1.5817 & 0.6609 \\
# BASIC & prepend & none & 1.4898 & 0.5690 \\
# BASIC & prepend & system_prompt_hardening & 1.5402 & 0.6194 \\
# BASIC & prepend & user_prompt_hardening & 1.3396 & 0.4187 \\
# BASIC & scatter & few_shot & 1.3883 & 0.4675 \\
# BASIC & scatter & none & 1.3104 & 0.3895 \\
# BASIC & scatter & system_prompt_hardening & 1.3242 & 0.4034 \\
# BASIC & scatter & user_prompt_hardening & 1.1971 & 0.2763 \\
# RATIONALE & append & few_shot & 2.2124 & 1.2916 \\
# RATIONALE & append & none & 2.0853 & 1.1645 \\
# RATIONALE & append & system_prompt_hardening & 2.1910 & 1.2702 \\
# RATIONALE & append & user_prompt_hardening & 1.1762 & 0.2554 \\
# RATIONALE & none & few_shot & 2.0075 & 1.0867 \\
# RATIONALE & none & none & 1.8654 & 0.9446 \\
# RATIONALE & none & system_prompt_hardening & 2.0802 & 1.1594 \\
# RATIONALE & none & user_prompt_hardening & 1.0226 & 0.1018 \\
# RATIONALE & prepend & few_shot & 2.1844 & 1.2636 \\
# RATIONALE & prepend & none & 2.0947 & 1.1739 \\
# RATIONALE & prepend & system_prompt_hardening & 2.1926 & 1.2718 \\
# RATIONALE & prepend & user_prompt_hardening & 1.5357 & 0.6149 \\
# RATIONALE & scatter & few_shot & 2.1674 & 1.2465 \\
# RATIONALE & scatter & none & 2.0575 & 1.1367 \\
# RATIONALE & scatter & system_prompt_hardening & 2.1460 & 1.2252 \\
# RATIONALE & scatter & user_prompt_hardening & 1.4212 & 0.5004 \\
# UTILITY & append & few_shot & 1.7637 & 0.8429 \\
# UTILITY & append & none & 1.6317 & 0.7109 \\
# UTILITY & append & system_prompt_hardening & 1.7300 & 0.8091 \\
# UTILITY & append & user_prompt_hardening & 1.0406 & 0.1198 \\
# UTILITY & none & few_shot & 1.3772 & 0.4563 \\
# UTILITY & none & none & 1.3662 & 0.4454 \\
# UTILITY & none & system_prompt_hardening & 1.4546 & 0.5338 \\
# UTILITY & none & user_prompt_hardening & 0.9231 & 0.0023 \\
# UTILITY & prepend & few_shot & 1.8769 & 0.9561 \\
# UTILITY & prepend & none & 1.8187 & 0.8979 \\
# UTILITY & prepend & system_prompt_hardening & 1.9483 & 1.0275 \\
# UTILITY & prepend & user_prompt_hardening & 1.4273 & 0.5065 \\
# UTILITY & scatter & few_shot & 1.7784 & 0.8576 \\
# UTILITY & scatter & none & 1.7301 & 0.8093 \\
# UTILITY & scatter & system_prompt_hardening & 1.8392 & 0.9184 \\
# UTILITY & scatter & user_prompt_hardening & 1.3300 & 0.4092 \\
# \bottomrule
# \end{tabular}
#
#
# ================================================================================
# 2. OVERALL JER TABLE
# ================================================================================
#
# \begin{tabular}{lllrr}
# \toprule
# Prompt & Attack & Mitigation & JER (\%) & $\Delta$ JER (\%) \\
# \midrule
# BASIC & append & few_shot & 58.52 & 8.09 \\
# BASIC & append & none & 56.23 & 5.80 \\
# BASIC & append & system_prompt_hardening & 56.32 & 5.88 \\
# BASIC & append & user_prompt_hardening & 48.60 & -1.84 \\
# BASIC & none & few_shot & 49.35 & -1.08 \\
# BASIC & none & none & 50.43 & -- \\
# BASIC & none & system_prompt_hardening & 50.61 & 0.17 \\
# BASIC & none & user_prompt_hardening & 46.30 & -4.13 \\
# BASIC & prepend & few_shot & 68.32 & 17.89 \\
# BASIC & prepend & none & 68.30 & 17.86 \\
# BASIC & prepend & system_prompt_hardening & 69.16 & 18.73 \\
# BASIC & prepend & user_prompt_hardening & 60.69 & 10.25 \\
# BASIC & scatter & few_shot & 63.79 & 13.36 \\
# BASIC & scatter & none & 65.56 & 15.13 \\
# BASIC & scatter & system_prompt_hardening & 66.17 & 15.74 \\
# BASIC & scatter & user_prompt_hardening & 58.01 & 7.58 \\
# RATIONALE & append & few_shot & 87.42 & 36.99 \\
# RATIONALE & append & none & 84.85 & 34.41 \\
# RATIONALE & append & system_prompt_hardening & 87.55 & 37.12 \\
# RATIONALE & append & user_prompt_hardening & 55.11 & 4.67 \\
# RATIONALE & none & few_shot & 81.54 & 31.11 \\
# RATIONALE & none & none & 78.51 & 28.07 \\
# RATIONALE & none & system_prompt_hardening & 84.79 & 34.35 \\
# RATIONALE & none & user_prompt_hardening & 50.72 & 0.28 \\
# RATIONALE & prepend & few_shot & 86.50 & 36.06 \\
# RATIONALE & prepend & none & 85.43 & 35.00 \\
# RATIONALE & prepend & system_prompt_hardening & 88.33 & 37.90 \\
# RATIONALE & prepend & user_prompt_hardening & 66.44 & 16.01 \\
# RATIONALE & scatter & few_shot & 87.31 & 36.88 \\
# RATIONALE & scatter & none & 85.94 & 35.51 \\
# RATIONALE & scatter & system_prompt_hardening & 87.89 & 37.46 \\
# RATIONALE & scatter & user_prompt_hardening & 64.31 & 13.87 \\
# UTILITY & append & few_shot & 73.81 & 23.37 \\
# UTILITY & append & none & 71.64 & 21.21 \\
# UTILITY & append & system_prompt_hardening & 73.91 & 23.47 \\
# UTILITY & append & user_prompt_hardening & 50.85 & 0.41 \\
# UTILITY & none & few_shot & 61.91 & 11.48 \\
# UTILITY & none & none & 63.31 & 12.88 \\
# UTILITY & none & system_prompt_hardening & 65.46 & 15.03 \\
# UTILITY & none & user_prompt_hardening & 47.77 & -2.66 \\
# UTILITY & prepend & few_shot & 77.17 & 26.73 \\
# UTILITY & prepend & none & 76.84 & 26.41 \\
# UTILITY & prepend & system_prompt_hardening & 80.49 & 30.05 \\
# UTILITY & prepend & user_prompt_hardening & 62.90 & 12.46 \\
# UTILITY & scatter & few_shot & 75.30 & 24.87 \\
# UTILITY & scatter & none & 76.36 & 25.92 \\
# UTILITY & scatter & system_prompt_hardening & 78.92 & 28.49 \\
# UTILITY & scatter & user_prompt_hardening & 61.43 & 11.00 \\
# \bottomrule
# \end{tabular}
#
#
# ================================================================================
# 3. MAE FOR GROUND TRUTH = 0 (IRRELEVANT DOCUMENTS)
# ================================================================================
#
# \begin{tabular}{lllrr}
# \toprule
# Prompt & Attack & Mitigation & MAE (GT=0) & $\Delta$ MAE (GT=0) \\
# \midrule
# BASIC & append & few_shot & 1.3193 & 0.5343 \\
# BASIC & append & none & 1.0970 & 0.3121 \\
# BASIC & append & system_prompt_hardening & 1.1063 & 0.3213 \\
# BASIC & append & user_prompt_hardening & 0.7824 & -0.0025 \\
# BASIC & none & few_shot & 0.7497 & -0.0353 \\
# BASIC & none & none & 0.7849 & -- \\
# BASIC & none & system_prompt_hardening & 0.7743 & -0.0106 \\
# BASIC & none & user_prompt_hardening & 0.5844 & -0.2006 \\
# BASIC & prepend & few_shot & 1.8306 & 1.0456 \\
# BASIC & prepend & none & 1.7324 & 0.9474 \\
# BASIC & prepend & system_prompt_hardening & 1.8059 & 1.0210 \\
# BASIC & prepend & user_prompt_hardening & 1.4534 & 0.6685 \\
# BASIC & scatter & few_shot & 1.5371 & 0.7522 \\
# BASIC & scatter & none & 1.4689 & 0.6840 \\
# BASIC & scatter & system_prompt_hardening & 1.4846 & 0.6996 \\
# BASIC & scatter & user_prompt_hardening & 1.2137 & 0.4288 \\
# RATIONALE & append & few_shot & 2.8163 & 2.0314 \\
# RATIONALE & append & none & 2.6349 & 1.8499 \\
# RATIONALE & append & system_prompt_hardening & 2.8031 & 2.0182 \\
# RATIONALE & append & user_prompt_hardening & 1.1321 & 0.3472 \\
# RATIONALE & none & few_shot & 2.4885 & 1.7036 \\
# RATIONALE & none & none & 2.2803 & 1.4954 \\
# RATIONALE & none & system_prompt_hardening & 2.6266 & 1.8416 \\
# RATIONALE & none & user_prompt_hardening & 0.8704 & 0.0855 \\
# RATIONALE & prepend & few_shot & 2.7785 & 1.9935 \\
# RATIONALE & prepend & none & 2.6616 & 1.8767 \\
# RATIONALE & prepend & system_prompt_hardening & 2.7974 & 2.0124 \\
# RATIONALE & prepend & user_prompt_hardening & 1.7524 & 0.9675 \\
# RATIONALE & scatter & few_shot & 2.7621 & 1.9772 \\
# RATIONALE & scatter & none & 2.6194 & 1.8345 \\
# RATIONALE & scatter & system_prompt_hardening & 2.7487 & 1.9638 \\
# RATIONALE & scatter & user_prompt_hardening & 1.5613 & 0.7764 \\
# UTILITY & append & few_shot & 2.1132 & 1.3283 \\
# UTILITY & append & none & 1.9147 & 1.1298 \\
# UTILITY & append & system_prompt_hardening & 2.0726 & 1.2877 \\
# UTILITY & append & user_prompt_hardening & 0.9182 & 0.1332 \\
# UTILITY & none & few_shot & 1.4643 & 0.6793 \\
# UTILITY & none & none & 1.5014 & 0.7165 \\
# UTILITY & none & system_prompt_hardening & 1.6296 & 0.8446 \\
# UTILITY & none & user_prompt_hardening & 0.6955 & -0.0894 \\
# UTILITY & prepend & few_shot & 2.2909 & 1.5060 \\
# UTILITY & prepend & none & 2.2303 & 1.4454 \\
# UTILITY & prepend & system_prompt_hardening & 2.4108 & 1.6259 \\
# UTILITY & prepend & user_prompt_hardening & 1.5957 & 0.8107 \\
# UTILITY & scatter & few_shot & 2.1307 & 1.3458 \\
# UTILITY & scatter & none & 2.1093 & 1.3243 \\
# UTILITY & scatter & system_prompt_hardening & 2.2755 & 1.4905 \\
# UTILITY & scatter & user_prompt_hardening & 1.3935 & 0.6086 \\
# \bottomrule
# \end{tabular}
#
#
# ================================================================================
# 4. JER FOR GROUND TRUTH = 0 (IRRELEVANT DOCUMENTS)
# ================================================================================
#
# \begin{tabular}{lllrr}
# \toprule
# Prompt & Attack & Mitigation & JER (GT=0) (\%) & $\Delta$ JER (GT=0) (\%) \\
# \midrule
# BASIC & append & few_shot & 46.75 & 13.79 \\
# BASIC & append & none & 43.20 & 10.24 \\
# BASIC & append & system_prompt_hardening & 43.48 & 10.51 \\
# BASIC & append & user_prompt_hardening & 27.99 & -4.98 \\
# BASIC & none & few_shot & 28.88 & -4.08 \\
# BASIC & none & none & 32.96 & -- \\
# BASIC & none & system_prompt_hardening & 33.40 & 0.44 \\
# BASIC & none & user_prompt_hardening & 22.41 & -10.56 \\
# BASIC & prepend & few_shot & 64.22 & 31.26 \\
# BASIC & prepend & none & 65.08 & 32.11 \\
# BASIC & prepend & system_prompt_hardening & 66.57 & 33.61 \\
# BASIC & prepend & user_prompt_hardening & 51.36 & 18.40 \\
# BASIC & scatter & few_shot & 56.78 & 23.81 \\
# BASIC & scatter & none & 60.44 & 27.48 \\
# BASIC & scatter & system_prompt_hardening & 61.60 & 28.63 \\
# BASIC & scatter & user_prompt_hardening & 45.67 & 12.70 \\
# RATIONALE & append & few_shot & 95.16 & 62.19 \\
# RATIONALE & append & none & 90.62 & 57.65 \\
# RATIONALE & append & system_prompt_hardening & 95.57 & 62.61 \\
# RATIONALE & append & user_prompt_hardening & 38.96 & 5.99 \\
# RATIONALE & none & few_shot & 84.53 & 51.57 \\
# RATIONALE & none & none & 79.02 & 46.06 \\
# RATIONALE & none & system_prompt_hardening & 90.13 & 57.17 \\
# RATIONALE & none & user_prompt_hardening & 30.61 & -2.35 \\
# RATIONALE & prepend & few_shot & 93.96 & 61.00 \\
# RATIONALE & prepend & none & 92.46 & 59.50 \\
# RATIONALE & prepend & system_prompt_hardening & 96.52 & 63.55 \\
# RATIONALE & prepend & user_prompt_hardening & 60.33 & 27.36 \\
# RATIONALE & scatter & few_shot & 94.95 & 61.99 \\
# RATIONALE & scatter & none & 92.83 & 59.87 \\
# RATIONALE & scatter & system_prompt_hardening & 96.04 & 63.07 \\
# RATIONALE & scatter & user_prompt_hardening & 55.51 & 22.54 \\
# UTILITY & append & few_shot & 72.18 & 39.21 \\
# UTILITY & append & none & 68.37 & 35.41 \\
# UTILITY & append & system_prompt_hardening & 72.71 & 39.74 \\
# UTILITY & append & user_prompt_hardening & 31.90 & -1.06 \\
# UTILITY & none & few_shot & 51.18 & 18.21 \\
# UTILITY & none & none & 54.77 & 21.81 \\
# UTILITY & none & system_prompt_hardening & 57.91 & 24.94 \\
# UTILITY & none & user_prompt_hardening & 24.97 & -8.00 \\
# UTILITY & prepend & few_shot & 78.26 & 45.30 \\
# UTILITY & prepend & none & 78.79 & 45.83 \\
# UTILITY & prepend & system_prompt_hardening & 83.73 & 50.76 \\
# UTILITY & prepend & user_prompt_hardening & 55.16 & 22.20 \\
# UTILITY & scatter & few_shot & 75.03 & 42.07 \\
# UTILITY & scatter & none & 77.57 & 44.61 \\
# UTILITY & scatter & system_prompt_hardening & 81.95 & 48.99 \\
# UTILITY & scatter & user_prompt_hardening & 50.00 & 17.04 \\
# \bottomrule
# \end{tabular}
#
#
# ================================================================================
# 5. MAE FOR GROUND TRUTH > 0 (RELEVANT DOCUMENTS)
# ================================================================================
#
# \begin{tabular}{lllrr}
# \toprule
# Prompt & Attack & Mitigation & MAE (GT$>$0) & $\Delta$ MAE (GT$>$0) \\
# \midrule
# BASIC & append & few_shot & 1.1759 & 0.0354 \\
# BASIC & append & none & 1.1368 & -0.0037 \\
# BASIC & append & system_prompt_hardening & 1.1264 & -0.0142 \\
# BASIC & append & user_prompt_hardening & 1.2370 & 0.0965 \\
# BASIC & none & few_shot & 1.2751 & 0.1346 \\
# BASIC & none & none & 1.1405 & -- \\
# BASIC & none & system_prompt_hardening & 1.1431 & 0.0026 \\
# BASIC & none & user_prompt_hardening & 1.2918 & 0.1513 \\
# BASIC & prepend & few_shot & 1.1793 & 0.0388 \\
# BASIC & prepend & none & 1.0977 & -0.0429 \\
# BASIC & prepend & system_prompt_hardening & 1.1107 & -0.0298 \\
# BASIC & prepend & user_prompt_hardening & 1.1554 & 0.0149 \\
# BASIC & scatter & few_shot & 1.1476 & 0.0071 \\
# BASIC & scatter & none & 1.0540 & -0.0865 \\
# BASIC & scatter & system_prompt_hardening & 1.0649 & -0.0757 \\
# BASIC & scatter & user_prompt_hardening & 1.1703 & 0.0298 \\
# RATIONALE & append & few_shot & 1.2359 & 0.0954 \\
# RATIONALE & append & none & 1.1968 & 0.0563 \\
# RATIONALE & append & system_prompt_hardening & 1.2013 & 0.0608 \\
# RATIONALE & append & user_prompt_hardening & 1.2475 & 0.1070 \\
# RATIONALE & none & few_shot & 1.2300 & 0.0895 \\
# RATIONALE & none & none & 1.1946 & 0.0540 \\
# RATIONALE & none & system_prompt_hardening & 1.1968 & 0.0563 \\
# RATIONALE & none & user_prompt_hardening & 1.2687 & 0.1282 \\
# RATIONALE & prepend & few_shot & 1.2240 & 0.0835 \\
# RATIONALE & prepend & none & 1.1782 & 0.0376 \\
# RATIONALE & prepend & system_prompt_hardening & 1.2147 & 0.0742 \\
# RATIONALE & prepend & user_prompt_hardening & 1.1852 & 0.0447 \\
# RATIONALE & scatter & few_shot & 1.2057 & 0.0652 \\
# RATIONALE & scatter & none & 1.1491 & 0.0086 \\
# RATIONALE & scatter & system_prompt_hardening & 1.1714 & 0.0309 \\
# RATIONALE & scatter & user_prompt_hardening & 1.1946 & 0.0540 \\
# UTILITY & append & few_shot & 1.1987 & 0.0581 \\
# UTILITY & append & none & 1.1741 & 0.0335 \\
# UTILITY & append & system_prompt_hardening & 1.1759 & 0.0354 \\
# UTILITY & append & user_prompt_hardening & 1.2385 & 0.0980 \\
# UTILITY & none & few_shot & 1.2363 & 0.0958 \\
# UTILITY & none & none & 1.1476 & 0.0071 \\
# UTILITY & none & system_prompt_hardening & 1.1718 & 0.0313 \\
# UTILITY & none & user_prompt_hardening & 1.2911 & 0.1506 \\
# UTILITY & prepend & few_shot & 1.2076 & 0.0671 \\
# UTILITY & prepend & none & 1.1532 & 0.0127 \\
# UTILITY & prepend & system_prompt_hardening & 1.2005 & 0.0600 \\
# UTILITY & prepend & user_prompt_hardening & 1.1551 & 0.0145 \\
# UTILITY & scatter & few_shot & 1.2087 & 0.0682 \\
# UTILITY & scatter & none & 1.1170 & -0.0235 \\
# UTILITY & scatter & system_prompt_hardening & 1.1338 & -0.0067 \\
# UTILITY & scatter & user_prompt_hardening & 1.2274 & 0.0868 \\
# \bottomrule
# \end{tabular}
#
#
# ================================================================================
# 6. JER FOR GROUND TRUTH > 0 (RELEVANT DOCUMENTS)
# ================================================================================
#
# \begin{tabular}{lllrr}
# \toprule
# Prompt & Attack & Mitigation & JER (GT$>$0) (\%) & $\Delta$ JER (GT$>$0) (\%) \\
# \midrule
# BASIC & append & few_shot & 77.56 & -1.12 \\
# BASIC & append & none & 77.30 & -1.38 \\
# BASIC & append & system_prompt_hardening & 77.08 & -1.60 \\
# BASIC & append & user_prompt_hardening & 81.92 & 3.24 \\
# BASIC & none & few_shot & 82.45 & 3.76 \\
# BASIC & none & none & 78.68 & -- \\
# BASIC & none & system_prompt_hardening & 78.42 & -0.26 \\
# BASIC & none & user_prompt_hardening & 84.94 & 6.26 \\
# BASIC & prepend & few_shot & 74.95 & -3.73 \\
# BASIC & prepend & none & 73.50 & -5.18 \\
# BASIC & prepend & system_prompt_hardening & 73.35 & -5.33 \\
# BASIC & prepend & user_prompt_hardening & 75.77 & -2.91 \\
# BASIC & scatter & few_shot & 75.14 & -3.54 \\
# BASIC & scatter & none & 73.84 & -4.85 \\
# BASIC & scatter & system_prompt_hardening & 73.57 & -5.11 \\
# BASIC & scatter & user_prompt_hardening & 77.97 & -0.71 \\
# RATIONALE & append & few_shot & 74.92 & -3.76 \\
# RATIONALE & append & none & 75.51 & -3.17 \\
# RATIONALE & append & system_prompt_hardening & 74.58 & -4.10 \\
# RATIONALE & append & user_prompt_hardening & 81.22 & 2.53 \\
# RATIONALE & none & few_shot & 76.71 & -1.98 \\
# RATIONALE & none & none & 77.67 & -1.01 \\
# RATIONALE & none & system_prompt_hardening & 76.15 & -2.53 \\
# RATIONALE & none & user_prompt_hardening & 83.23 & 4.55 \\
# RATIONALE & prepend & few_shot & 74.43 & -4.25 \\
# RATIONALE & prepend & none & 74.06 & -4.62 \\
# RATIONALE & prepend & system_prompt_hardening & 75.10 & -3.58 \\
# RATIONALE & prepend & user_prompt_hardening & 76.33 & -2.35 \\
# RATIONALE & scatter & few_shot & 74.95 & -3.73 \\
# RATIONALE & scatter & none & 74.80 & -3.88 \\
# RATIONALE & scatter & system_prompt_hardening & 74.73 & -3.95 \\
# RATIONALE & scatter & user_prompt_hardening & 78.53 & -0.15 \\
# UTILITY & append & few_shot & 76.44 & -2.24 \\
# UTILITY & append & none & 76.93 & -1.75 \\
# UTILITY & append & system_prompt_hardening & 75.85 & -2.83 \\
# UTILITY & append & user_prompt_hardening & 81.48 & 2.80 \\
# UTILITY & none & few_shot & 79.28 & 0.60 \\
# UTILITY & none & none & 77.12 & -1.57 \\
# UTILITY & none & system_prompt_hardening & 77.67 & -1.01 \\
# UTILITY & none & user_prompt_hardening & 84.64 & 5.96 \\
# UTILITY & prepend & few_shot & 75.40 & -3.28 \\
# UTILITY & prepend & none & 73.69 & -4.99 \\
# UTILITY & prepend & system_prompt_hardening & 75.25 & -3.43 \\
# UTILITY & prepend & user_prompt_hardening & 75.40 & -3.28 \\
# UTILITY & scatter & few_shot & 75.74 & -2.94 \\
# UTILITY & scatter & none & 74.39 & -4.29 \\
# UTILITY & scatter & system_prompt_hardening & 74.02 & -4.66 \\
# UTILITY & scatter & user_prompt_hardening & 79.91 & 1.23 \\
# \bottomrule
# \end{tabular}
#
#
# ================================================================================
# END OF LATEX TABLE OUTPUT
# ================================================================================
